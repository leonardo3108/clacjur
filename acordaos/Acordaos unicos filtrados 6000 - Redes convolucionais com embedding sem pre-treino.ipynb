# %% [markdown]
# # Importação e preparação dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/acordaos-unicos-filtrados-6000.csv', sep = '|')
df['filtrado_6000']=df['filtrado_6000'].astype(str)
df.head()
# Out:
#       acordao               areas  \
# 0  297/2016-P    Responsabilidade
# 1  366/2016-P   Finanças Públicas
# 2  944/2016-P    Responsabilidade
# 3   30/2016-P  Direito Processual
# 4   55/2016-P             Pessoal
#
#                                        filtrado_6000
# 0  tribunal conta união tc grupo classe plenário ...
# 1  tribunal conta união tc grupo classe ii plenár...
# 2  tribunal conta união tc grupo classe plenário ...
# 3  tribunal conta união tc grupo classe plenário ...
# 4  wania lucia pasquarelli nascimentotcuwania luc...

# %%
df.shape
# Out:
# (9739, 3)

# %%
from sklearn.preprocessing import LabelBinarizer

areas = df.groupby(['areas']).groups.keys()
lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
y = lbArea.transform(df['areas'])
y.shape
# Out:
# (9739, 10)

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

vocabulario = 100000
limite_texto = 6000
dim_vetor = 100

tokenizer = Tokenizer(num_words=vocabulario)
tokenizer.fit_on_texts(df['filtrado_6000'])

sequences = tokenizer.texts_to_sequences(df['filtrado_6000'])

word_index = tokenizer.word_index
vocabulario = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 95423 unique tokens.

# %%
from keras.preprocessing.sequence import pad_sequences

x = pad_sequences(sequences, maxlen=limite_texto)

print('Shape of data tensor:', x.shape)
# Out:
# Shape of data tensor: (9739, 6000)

# %%
x.shape, y.shape
# Out:
# ((9739, 6000), (9739, 10))

# %% [markdown]
# # Treinamento

# %%
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, GlobalMaxPooling1D, Flatten
from keras.optimizers import RMSprop
from keras.layers.core import Dropout

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# W0312 21:07:36.308642 139822967846720 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0312 21:07:36.315032 139822967846720 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0312 21:07:36.575509 139822967846720 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0312 21:07:36.582077 139822967846720 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0312 21:07:36.662798 139822967846720 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 5994, 32)          22432
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1198, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 38336)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               9814272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 19,381,674
# Trainable params: 19,381,674
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 15s 2ms/step - loss: 1.2531 - categorical_accuracy: 0.5959 - val_loss: 1.1418 - val_categorical_accuracy: 0.6371
# Epoch 2/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.6821 - categorical_accuracy: 0.7715 - val_loss: 1.1827 - val_categorical_accuracy: 0.6340
# Epoch 3/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.2717 - categorical_accuracy: 0.9139 - val_loss: 1.5892 - val_categorical_accuracy: 0.6314
# Epoch 4/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0701 - categorical_accuracy: 0.9816 - val_loss: 2.3306 - val_categorical_accuracy: 0.6068
# Epoch 5/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0240 - categorical_accuracy: 0.9933 - val_loss: 2.4307 - val_categorical_accuracy: 0.6463
# Epoch 6/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0153 - categorical_accuracy: 0.9965 - val_loss: 2.7655 - val_categorical_accuracy: 0.6453
# Epoch 7/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0044 - categorical_accuracy: 0.9983 - val_loss: 3.1617 - val_categorical_accuracy: 0.6170
# Epoch 8/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0054 - categorical_accuracy: 0.9987 - val_loss: 3.4425 - val_categorical_accuracy: 0.6176
# Epoch 9/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.0037 - categorical_accuracy: 0.9987 - val_loss: 3.6816 - val_categorical_accuracy: 0.6145
# Epoch 10/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0080 - categorical_accuracy: 0.9981 - val_loss: 3.6122 - val_categorical_accuracy: 0.6201
# Epoch 11/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0037 - categorical_accuracy: 0.9992 - val_loss: 3.3177 - val_categorical_accuracy: 0.6530
# Epoch 12/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0023 - categorical_accuracy: 0.9991 - val_loss: 3.6679 - val_categorical_accuracy: 0.6350
# Epoch 13/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.0038 - categorical_accuracy: 0.9985 - val_loss: 3.6877 - val_categorical_accuracy: 0.6283
# Epoch 14/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0023 - categorical_accuracy: 0.9990 - val_loss: 3.6757 - val_categorical_accuracy: 0.6407
# Epoch 15/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 9.9873e-04 - categorical_accuracy: 0.9997 - val_loss: 3.9685 - val_categorical_accuracy: 0.6360
# Epoch 16/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0036 - categorical_accuracy: 0.9990 - val_loss: 3.9519 - val_categorical_accuracy: 0.6422
# Epoch 17/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0033 - categorical_accuracy: 0.9991 - val_loss: 3.8888 - val_categorical_accuracy: 0.6319
# Epoch 18/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0020 - categorical_accuracy: 0.9997 - val_loss: 3.6754 - val_categorical_accuracy: 0.6612
# Epoch 19/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0012 - categorical_accuracy: 0.9996 - val_loss: 4.0981 - val_categorical_accuracy: 0.6150
# Epoch 20/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 0.0011 - categorical_accuracy: 0.9997 - val_loss: 3.9686 - val_categorical_accuracy: 0.6622

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 5994, 32)          22432
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 1198, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 38336)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               19628544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 29,198,506
# Trainable params: 29,198,506
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 1.2406 - categorical_accuracy: 0.6047 - val_loss: 1.2089 - val_categorical_accuracy: 0.5955
# Epoch 2/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.6341 - categorical_accuracy: 0.7890 - val_loss: 1.2853 - val_categorical_accuracy: 0.6145
# Epoch 3/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.1978 - categorical_accuracy: 0.9430 - val_loss: 1.8806 - val_categorical_accuracy: 0.5811
# Epoch 4/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0429 - categorical_accuracy: 0.9886 - val_loss: 2.3140 - val_categorical_accuracy: 0.6119
# Epoch 5/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0175 - categorical_accuracy: 0.9959 - val_loss: 2.8194 - val_categorical_accuracy: 0.5945
# Epoch 6/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0076 - categorical_accuracy: 0.9976 - val_loss: 3.3708 - val_categorical_accuracy: 0.5852
# Epoch 7/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0032 - categorical_accuracy: 0.9986 - val_loss: 3.3276 - val_categorical_accuracy: 0.6350
# Epoch 8/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0074 - categorical_accuracy: 0.9982 - val_loss: 3.6076 - val_categorical_accuracy: 0.6063
# Epoch 9/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0028 - categorical_accuracy: 0.9994 - val_loss: 3.8129 - val_categorical_accuracy: 0.5970
# Epoch 10/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0093 - categorical_accuracy: 0.9988 - val_loss: 3.6283 - val_categorical_accuracy: 0.6176
# Epoch 11/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 7.5814e-04 - categorical_accuracy: 0.9999 - val_loss: 3.8283 - val_categorical_accuracy: 0.6201
# Epoch 12/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0101 - categorical_accuracy: 0.9981 - val_loss: 3.8814 - val_categorical_accuracy: 0.6314
# Epoch 13/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0016 - categorical_accuracy: 0.9995 - val_loss: 3.9782 - val_categorical_accuracy: 0.6124
# Epoch 14/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0025 - categorical_accuracy: 0.9995 - val_loss: 4.1409 - val_categorical_accuracy: 0.6022
# Epoch 15/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 8.3869e-04 - categorical_accuracy: 0.9996 - val_loss: 4.1555 - val_categorical_accuracy: 0.6140
# Epoch 16/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0020 - categorical_accuracy: 0.9996 - val_loss: 4.1108 - val_categorical_accuracy: 0.6129
# Epoch 17/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0012 - categorical_accuracy: 0.9996 - val_loss: 4.2599 - val_categorical_accuracy: 0.6109
# Epoch 18/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0148 - categorical_accuracy: 0.9985 - val_loss: 4.3453 - val_categorical_accuracy: 0.6134
# Epoch 19/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 0.0018 - categorical_accuracy: 0.9997 - val_loss: 4.5244 - val_categorical_accuracy: 0.6016
# Epoch 20/20
# 7791/7791 [==============================] - 10s 1ms/step - loss: 7.4705e-04 - categorical_accuracy: 0.9997 - val_loss: 4.3550 - val_categorical_accuracy: 0.6324

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(64, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 5994, 64)          44864
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 1198, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 76672)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               19628288
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 29,218,122
# Trainable params: 29,218,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 1.2935 - categorical_accuracy: 0.6067 - val_loss: 1.1884 - val_categorical_accuracy: 0.6278
# Epoch 2/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.6887 - categorical_accuracy: 0.7667 - val_loss: 1.2554 - val_categorical_accuracy: 0.6099
# Epoch 3/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.2671 - categorical_accuracy: 0.9186 - val_loss: 1.4608 - val_categorical_accuracy: 0.6484
# Epoch 4/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0691 - categorical_accuracy: 0.9802 - val_loss: 2.1797 - val_categorical_accuracy: 0.6109
# Epoch 5/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0241 - categorical_accuracy: 0.9942 - val_loss: 2.5961 - val_categorical_accuracy: 0.6453
# Epoch 6/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0117 - categorical_accuracy: 0.9967 - val_loss: 3.2329 - val_categorical_accuracy: 0.5796
# Epoch 7/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0085 - categorical_accuracy: 0.9974 - val_loss: 3.3993 - val_categorical_accuracy: 0.5975
# Epoch 8/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0079 - categorical_accuracy: 0.9983 - val_loss: 3.2724 - val_categorical_accuracy: 0.6283
# Epoch 9/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0058 - categorical_accuracy: 0.9985 - val_loss: 3.3451 - val_categorical_accuracy: 0.6330
# Epoch 10/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0024 - categorical_accuracy: 0.9995 - val_loss: 3.8462 - val_categorical_accuracy: 0.6078
# Epoch 11/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0024 - categorical_accuracy: 0.9995 - val_loss: 3.8625 - val_categorical_accuracy: 0.6237
# Epoch 12/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0028 - categorical_accuracy: 0.9994 - val_loss: 4.0712 - val_categorical_accuracy: 0.6073
# Epoch 13/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0034 - categorical_accuracy: 0.9992 - val_loss: 3.7629 - val_categorical_accuracy: 0.6525
# Epoch 14/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 8.6329e-04 - categorical_accuracy: 0.9997 - val_loss: 4.2439 - val_categorical_accuracy: 0.6191
# Epoch 15/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0025 - categorical_accuracy: 0.9994 - val_loss: 3.9058 - val_categorical_accuracy: 0.6412
# Epoch 16/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 6.6070e-04 - categorical_accuracy: 0.9997 - val_loss: 3.8640 - val_categorical_accuracy: 0.6591
# Epoch 17/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0036 - categorical_accuracy: 0.9994 - val_loss: 4.4397 - val_categorical_accuracy: 0.6093
# Epoch 18/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0049 - categorical_accuracy: 0.9987 - val_loss: 4.1097 - val_categorical_accuracy: 0.6360
# Epoch 19/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0030 - categorical_accuracy: 0.9995 - val_loss: 4.3082 - val_categorical_accuracy: 0.6109
# Epoch 20/20
# 7791/7791 [==============================] - 13s 2ms/step - loss: 0.0023 - categorical_accuracy: 0.9994 - val_loss: 4.2909 - val_categorical_accuracy: 0.6078

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 5994, 32)          22432
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1198, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 38336)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              39257088
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 48,954,410
# Trainable params: 48,954,410
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 15s 2ms/step - loss: 1.3289 - categorical_accuracy: 0.5967 - val_loss: 1.1293 - val_categorical_accuracy: 0.6509
# Epoch 2/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.7232 - categorical_accuracy: 0.7530 - val_loss: 1.1888 - val_categorical_accuracy: 0.6489
# Epoch 3/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.2797 - categorical_accuracy: 0.9082 - val_loss: 2.2020 - val_categorical_accuracy: 0.5585
# Epoch 4/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0753 - categorical_accuracy: 0.9800 - val_loss: 2.5207 - val_categorical_accuracy: 0.5939
# Epoch 5/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0397 - categorical_accuracy: 0.9902 - val_loss: 3.1401 - val_categorical_accuracy: 0.5898
# Epoch 6/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0177 - categorical_accuracy: 0.9959 - val_loss: 3.7851 - val_categorical_accuracy: 0.5826
# Epoch 7/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0149 - categorical_accuracy: 0.9969 - val_loss: 5.4384 - val_categorical_accuracy: 0.4872
# Epoch 8/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0110 - categorical_accuracy: 0.9972 - val_loss: 3.5757 - val_categorical_accuracy: 0.6155
# Epoch 9/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0172 - categorical_accuracy: 0.9963 - val_loss: 3.8363 - val_categorical_accuracy: 0.5986
# Epoch 10/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0038 - categorical_accuracy: 0.9990 - val_loss: 4.1048 - val_categorical_accuracy: 0.6119
# Epoch 11/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0115 - categorical_accuracy: 0.9978 - val_loss: 3.9791 - val_categorical_accuracy: 0.6217
# Epoch 12/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0061 - categorical_accuracy: 0.9985 - val_loss: 4.7188 - val_categorical_accuracy: 0.5611
# Epoch 13/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0092 - categorical_accuracy: 0.9985 - val_loss: 4.1293 - val_categorical_accuracy: 0.6170
# Epoch 14/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0097 - categorical_accuracy: 0.9987 - val_loss: 4.3818 - val_categorical_accuracy: 0.5975
# Epoch 15/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0049 - categorical_accuracy: 0.9990 - val_loss: 4.7511 - val_categorical_accuracy: 0.5770
# Epoch 16/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0138 - categorical_accuracy: 0.9973 - val_loss: 4.9344 - val_categorical_accuracy: 0.5590
# Epoch 17/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0023 - categorical_accuracy: 0.9988 - val_loss: 5.7467 - val_categorical_accuracy: 0.4974
# Epoch 18/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 0.0038 - categorical_accuracy: 0.9991 - val_loss: 4.6932 - val_categorical_accuracy: 0.5924
# Epoch 19/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 8.2121e-04 - categorical_accuracy: 0.9996 - val_loss: 4.8026 - val_categorical_accuracy: 0.5806
# Epoch 20/20
# 7791/7791 [==============================] - 14s 2ms/step - loss: 5.1138e-04 - categorical_accuracy: 0.9997 - val_loss: 5.5052 - val_categorical_accuracy: 0.5354

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=5e-3),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 5994, 32)          22432
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1198, 32)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1192, 32)          7200
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 596, 32)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 19072)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               4882688
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 14,457,290
# Trainable params: 14,457,290
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 9s 1ms/step - loss: 1.6891 - categorical_accuracy: 0.4780 - val_loss: 1.6347 - val_categorical_accuracy: 0.3845
# Epoch 2/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 1.1917 - categorical_accuracy: 0.6126 - val_loss: 1.2824 - val_categorical_accuracy: 0.5888
# Epoch 3/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 1.0121 - categorical_accuracy: 0.6673 - val_loss: 1.3426 - val_categorical_accuracy: 0.5329
# Epoch 4/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.8335 - categorical_accuracy: 0.7261 - val_loss: 1.9330 - val_categorical_accuracy: 0.4713
# Epoch 5/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.6649 - categorical_accuracy: 0.7840 - val_loss: 2.7195 - val_categorical_accuracy: 0.4743
# Epoch 6/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.5802 - categorical_accuracy: 0.8295 - val_loss: 2.4547 - val_categorical_accuracy: 0.4754
# Epoch 7/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4823 - categorical_accuracy: 0.8553 - val_loss: 3.6399 - val_categorical_accuracy: 0.4389
# Epoch 8/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4743 - categorical_accuracy: 0.8772 - val_loss: 2.9327 - val_categorical_accuracy: 0.4892
# Epoch 9/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.5381 - categorical_accuracy: 0.8892 - val_loss: 3.6467 - val_categorical_accuracy: 0.4600
# Epoch 10/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.3899 - categorical_accuracy: 0.9053 - val_loss: 3.7503 - val_categorical_accuracy: 0.4692
# Epoch 11/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.8942 - categorical_accuracy: 0.8829 - val_loss: 3.6246 - val_categorical_accuracy: 0.4482
# Epoch 12/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.3159 - categorical_accuracy: 0.9270 - val_loss: 4.0901 - val_categorical_accuracy: 0.4384
# Epoch 13/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4550 - categorical_accuracy: 0.9281 - val_loss: 5.1791 - val_categorical_accuracy: 0.5287
# Epoch 14/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.5126 - categorical_accuracy: 0.9309 - val_loss: 6.4917 - val_categorical_accuracy: 0.4569
# Epoch 15/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4061 - categorical_accuracy: 0.9347 - val_loss: 4.9255 - val_categorical_accuracy: 0.4728
# Epoch 16/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.3147 - categorical_accuracy: 0.9494 - val_loss: 5.4004 - val_categorical_accuracy: 0.4892
# Epoch 17/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4898 - categorical_accuracy: 0.9389 - val_loss: 5.4009 - val_categorical_accuracy: 0.4584
# Epoch 18/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4250 - categorical_accuracy: 0.9467 - val_loss: 6.2953 - val_categorical_accuracy: 0.4902
# Epoch 19/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.4786 - categorical_accuracy: 0.9421 - val_loss: 6.1240 - val_categorical_accuracy: 0.4892
# Epoch 20/20
# 7791/7791 [==============================] - 8s 1ms/step - loss: 0.5132 - categorical_accuracy: 0.9447 - val_loss: 6.3752 - val_categorical_accuracy: 0.4995

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, input_length=x.shape[1]))
model.add(Conv1D(64, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 6000, 100)         9542400
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 5994, 64)          44864
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 1198, 64)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 1192, 32)          14368
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 238, 32)           0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 7616)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              7799808
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 17,533,930
# Trainable params: 17,533,930
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7791 samples, validate on 1948 samples
# Epoch 1/20
# 7791/7791 [==============================] - 12s 2ms/step - loss: 1.2697 - categorical_accuracy: 0.5703 - val_loss: 1.2238 - val_categorical_accuracy: 0.5903
# Epoch 2/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.9307 - categorical_accuracy: 0.6709 - val_loss: 1.1612 - val_categorical_accuracy: 0.6247
# Epoch 3/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.7407 - categorical_accuracy: 0.7344 - val_loss: 1.2630 - val_categorical_accuracy: 0.5421
# Epoch 4/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.5194 - categorical_accuracy: 0.8197 - val_loss: 1.6091 - val_categorical_accuracy: 0.6027
# Epoch 5/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.2783 - categorical_accuracy: 0.9091 - val_loss: 2.2268 - val_categorical_accuracy: 0.5970
# Epoch 6/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.1409 - categorical_accuracy: 0.9576 - val_loss: 2.2919 - val_categorical_accuracy: 0.5755
# Epoch 7/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0843 - categorical_accuracy: 0.9798 - val_loss: 2.5136 - val_categorical_accuracy: 0.5590
# Epoch 8/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0494 - categorical_accuracy: 0.9892 - val_loss: 5.5935 - val_categorical_accuracy: 0.4579
# Epoch 9/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0565 - categorical_accuracy: 0.9882 - val_loss: 3.3952 - val_categorical_accuracy: 0.5544
# Epoch 10/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0345 - categorical_accuracy: 0.9902 - val_loss: 3.8604 - val_categorical_accuracy: 0.5647
# Epoch 11/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0314 - categorical_accuracy: 0.9928 - val_loss: 3.7586 - val_categorical_accuracy: 0.5606
# Epoch 12/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0231 - categorical_accuracy: 0.9937 - val_loss: 3.9290 - val_categorical_accuracy: 0.5729
# Epoch 13/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0304 - categorical_accuracy: 0.9938 - val_loss: 4.5552 - val_categorical_accuracy: 0.5277
# Epoch 14/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0296 - categorical_accuracy: 0.9937 - val_loss: 4.6489 - val_categorical_accuracy: 0.5395
# Epoch 15/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0203 - categorical_accuracy: 0.9968 - val_loss: 4.9341 - val_categorical_accuracy: 0.5616
# Epoch 16/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0298 - categorical_accuracy: 0.9935 - val_loss: 5.6552 - val_categorical_accuracy: 0.5108
# Epoch 17/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0361 - categorical_accuracy: 0.9933 - val_loss: 4.1861 - val_categorical_accuracy: 0.5611
# Epoch 18/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0255 - categorical_accuracy: 0.9944 - val_loss: 4.7027 - val_categorical_accuracy: 0.5518
# Epoch 19/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0307 - categorical_accuracy: 0.9938 - val_loss: 4.8331 - val_categorical_accuracy: 0.5416
# Epoch 20/20
# 7791/7791 [==============================] - 11s 1ms/step - loss: 0.0196 - categorical_accuracy: 0.9954 - val_loss: 5.0490 - val_categorical_accuracy: 0.5611
