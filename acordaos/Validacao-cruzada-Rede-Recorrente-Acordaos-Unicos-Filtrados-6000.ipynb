# %% [markdown]
# # Obtenção e organização dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/acordaos-unicos-filtrados-6000.csv', sep = '|')[['acordao', 'areas', 'filtrado_6000']]
df['filtrado_6000'] = df['filtrado_6000'].astype(str)
df.head()
# Out:
#       acordao               areas  \
# 0  297/2016-P    Responsabilidade
# 1  366/2016-P   Finanças Públicas
# 2  944/2016-P    Responsabilidade
# 3   30/2016-P  Direito Processual
# 4   55/2016-P             Pessoal
#
#                                        filtrado_6000
# 0  tribunal conta união tc grupo classe plenário ...
# 1  tribunal conta união tc grupo classe ii plenár...
# 2  tribunal conta união tc grupo classe plenário ...
# 3  tribunal conta união tc grupo classe plenário ...
# 4  wania lucia pasquarelli nascimentotcuwania luc...

# %%
df.shape
# Out:
# (9739, 3)

# %%
from sklearn.preprocessing import LabelBinarizer

areas = df.groupby(['areas']).groups.keys()
lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
y = lbArea.transform(df['areas'])
lbArea.classes_, y.shape
# Out:
# (array(['Competência do TCU', 'Contrato Administrativo', 'Convênio',
#         'Desestatização', 'Direito Processual', 'Finanças Públicas',
#         'Gestão Administrativa', 'Licitação', 'Pessoal',
#         'Responsabilidade'], dtype='<U23'), (9739, 10))

# %% [markdown]
# # Pré-processamento

# %%
colunas_scores = list(lbArea.classes_)
colunas_scores.extend(['accuracy', 'macro avg', 'weighted avg'])

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

print('\tCarregamento do modelo de acordaos...')
modelo = Word2Vec.load('../vocabularios/modelo-acordaos-50.w2v')
# Out:
# 	Carregamento do modelo de acordaos...
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

df_scores = pd.DataFrame()

limite_texto = 6000
dim_vetor = 50

print('\tTokenizacao e montagem de sequencias...')
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['filtrado_6000'])
vocabulario = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(df['filtrado_6000'])

print('\tMontagem da matriz de embeddings...')
embedding_matrix = np.zeros((vocabulario, dim_vetor))
for word, i in tokenizer.word_index.items():
    if word in modelo.wv:
        embedding_matrix[i] = modelo.wv[word]
# Out:
# Using TensorFlow backend.
# 	Tokenizacao e montagem de sequencias...
# 	Montagem da matriz de embeddings...

# %% [markdown]
# # Treinamentos com Cross-validation

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, GlobalMaxPooling1D, Flatten, GRU
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint

fold = 0
for train_index, val_index in KFold(n_splits=10, random_state=42, shuffle=True).split(df):
    str_fold = 'Fold ' + str(fold)
    print()
    print()
    print(str_fold + ':')
    print('\tDefinicao de valores de entrada e saida da rede...')

    df_train = df.loc[train_index]
    df_val = df.loc[val_index]

    sequences_train = tokenizer.texts_to_sequences(df_train['filtrado_6000'])
    sequences_val = tokenizer.texts_to_sequences(df_val['filtrado_6000'])

    x_train = pad_sequences(sequences_train, maxlen=limite_texto)
    x_val = pad_sequences(sequences_val, maxlen=limite_texto)

    y_train = lbArea.transform(df_train['areas'])
    y_val = lbArea.transform(df_val['areas'])

    print('\tTreinamento da rede...')
    model = Sequential()
    model.add(Embedding(vocabulario, dim_vetor, input_length=limite_texto, trainable=True,  weights=[embedding_matrix]))
    model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=['categorical_accuracy'])

    checkpoint_filename = 'weights' + str(fold) + '.hdf5'
    checkpointer = ModelCheckpoint(filepath=checkpoint_filename, monitor='val_categorical_accuracy', verbose=1, save_best_only=True)
    model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), verbose=1, shuffle=False, callbacks=[checkpointer])

    print('\n\tAvaliacao do melhor modelo and registro dos scores...')
    model.load_weights(checkpoint_filename)
    y_val_pred = model.predict_classes(x_val, verbose=1)
    y_val_i = [list(x).index(1) for x in y_val]
    report = classification_report(y_val_i, y_val_pred, target_names=lbArea.classes_, output_dict = True)
    for col in colunas_scores:
        if col == 'accuracy':
            f = report[col]
        else:
            f = report[col]['f1-score']
        df_scores.loc[str_fold,col] = f
    fold += 1
# Out:
# Fold 0:
# 	Definicao de valores de entrada e saida da rede...
# WARNING: Logging before flag parsing goes to stderr.
# W0319 17:46:58.701393 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0319 17:46:58.712806 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0319 17:46:58.714306 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0319 17:46:58.845228 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0319 17:46:58.846112 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 	Treinamento da rede...
# W0319 17:46:59.947525 139883022051136 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0319 17:47:00.149991 139883022051136 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0319 17:47:00.672403 139883022051136 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1638s 187ms/step - loss: 1.6369 - categorical_accuracy: 0.4546 - val_loss: 1.8872 - val_categorical_accuracy: 0.2895
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.28953, saving model to weights0.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1644s 188ms/step - loss: 1.5838 - categorical_accuracy: 0.4630 - val_loss: 1.8667 - val_categorical_accuracy: 0.2988
#
# Epoch 00002: val_categorical_accuracy improved from 0.28953 to 0.29877, saving model to weights0.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 1.5635 - categorical_accuracy: 0.4633 - val_loss: 1.8438 - val_categorical_accuracy: 0.3480
#
# Epoch 00003: val_categorical_accuracy improved from 0.29877 to 0.34805, saving model to weights0.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 1.5157 - categorical_accuracy: 0.4840 - val_loss: 1.6400 - val_categorical_accuracy: 0.4435
#
# Epoch 00004: val_categorical_accuracy improved from 0.34805 to 0.44353, saving model to weights0.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 1.2641 - categorical_accuracy: 0.5817 - val_loss: 1.2760 - val_categorical_accuracy: 0.5719
#
# Epoch 00005: val_categorical_accuracy improved from 0.44353 to 0.57187, saving model to weights0.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1638s 187ms/step - loss: 1.0504 - categorical_accuracy: 0.6536 - val_loss: 1.1717 - val_categorical_accuracy: 0.6160
#
# Epoch 00006: val_categorical_accuracy improved from 0.57187 to 0.61602, saving model to weights0.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 0.9664 - categorical_accuracy: 0.6763 - val_loss: 1.1051 - val_categorical_accuracy: 0.6314
#
# Epoch 00007: val_categorical_accuracy improved from 0.61602 to 0.63142, saving model to weights0.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 0.9153 - categorical_accuracy: 0.6959 - val_loss: 1.0913 - val_categorical_accuracy: 0.6314
#
# Epoch 00008: val_categorical_accuracy improved from 0.63142 to 0.63142, saving model to weights0.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 0.8702 - categorical_accuracy: 0.7074 - val_loss: 1.0289 - val_categorical_accuracy: 0.6468
#
# Epoch 00009: val_categorical_accuracy improved from 0.63142 to 0.64682, saving model to weights0.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1638s 187ms/step - loss: 0.8254 - categorical_accuracy: 0.7208 - val_loss: 1.0083 - val_categorical_accuracy: 0.6684
#
# Epoch 00010: val_categorical_accuracy improved from 0.64682 to 0.66838, saving model to weights0.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 55s 57ms/step
#
#
# Fold 1:
# 	Definicao de valores de entrada e saida da rede...
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1642s 187ms/step - loss: 1.6407 - categorical_accuracy: 0.4513 - val_loss: 1.8374 - val_categorical_accuracy: 0.2967
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.29671, saving model to weights1.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1643s 188ms/step - loss: 1.5893 - categorical_accuracy: 0.4568 - val_loss: 1.8174 - val_categorical_accuracy: 0.3193
#
# Epoch 00002: val_categorical_accuracy improved from 0.29671 to 0.31930, saving model to weights1.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1645s 188ms/step - loss: 1.5683 - categorical_accuracy: 0.4600 - val_loss: 1.7863 - val_categorical_accuracy: 0.3224
#
# Epoch 00003: val_categorical_accuracy improved from 0.31930 to 0.32238, saving model to weights1.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1644s 188ms/step - loss: 1.5423 - categorical_accuracy: 0.4710 - val_loss: 1.7541 - val_categorical_accuracy: 0.3645
#
# Epoch 00004: val_categorical_accuracy improved from 0.32238 to 0.36448, saving model to weights1.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1642s 187ms/step - loss: 1.4552 - categorical_accuracy: 0.5059 - val_loss: 1.4178 - val_categorical_accuracy: 0.5021
#
# Epoch 00005: val_categorical_accuracy improved from 0.36448 to 0.50205, saving model to weights1.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1641s 187ms/step - loss: 1.2095 - categorical_accuracy: 0.6073 - val_loss: 1.1883 - val_categorical_accuracy: 0.5780
#
# Epoch 00006: val_categorical_accuracy improved from 0.50205 to 0.57803, saving model to weights1.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1644s 188ms/step - loss: 1.0343 - categorical_accuracy: 0.6586 - val_loss: 1.0867 - val_categorical_accuracy: 0.6396
#
# Epoch 00007: val_categorical_accuracy improved from 0.57803 to 0.63963, saving model to weights1.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1641s 187ms/step - loss: 0.9830 - categorical_accuracy: 0.6730 - val_loss: 1.0294 - val_categorical_accuracy: 0.6509
#
# Epoch 00008: val_categorical_accuracy improved from 0.63963 to 0.65092, saving model to weights1.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1643s 187ms/step - loss: 0.9269 - categorical_accuracy: 0.6931 - val_loss: 0.9996 - val_categorical_accuracy: 0.6602
#
# Epoch 00009: val_categorical_accuracy improved from 0.65092 to 0.66016, saving model to weights1.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1642s 187ms/step - loss: 0.8786 - categorical_accuracy: 0.7064 - val_loss: 0.9629 - val_categorical_accuracy: 0.6715
#
# Epoch 00010: val_categorical_accuracy improved from 0.66016 to 0.67146, saving model to weights1.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 56s 57ms/step
#
#
# Fold 2:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1659s 189ms/step - loss: 1.6338 - categorical_accuracy: 0.4554 - val_loss: 1.9364 - val_categorical_accuracy: 0.2823
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.28234, saving model to weights2.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1657s 189ms/step - loss: 1.5872 - categorical_accuracy: 0.4658 - val_loss: 1.8806 - val_categorical_accuracy: 0.2906
#
# Epoch 00002: val_categorical_accuracy improved from 0.28234 to 0.29055, saving model to weights2.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1659s 189ms/step - loss: 1.5680 - categorical_accuracy: 0.4638 - val_loss: 1.8439 - val_categorical_accuracy: 0.3018
#
# Epoch 00003: val_categorical_accuracy improved from 0.29055 to 0.30185, saving model to weights2.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1659s 189ms/step - loss: 1.5381 - categorical_accuracy: 0.4727 - val_loss: 1.7979 - val_categorical_accuracy: 0.3285
#
# Epoch 00004: val_categorical_accuracy improved from 0.30185 to 0.32854, saving model to weights2.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1643s 187ms/step - loss: 1.4328 - categorical_accuracy: 0.5155 - val_loss: 1.5067 - val_categorical_accuracy: 0.5195
#
# Epoch 00005: val_categorical_accuracy improved from 0.32854 to 0.51951, saving model to weights2.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1628s 186ms/step - loss: 1.1582 - categorical_accuracy: 0.6192 - val_loss: 1.1549 - val_categorical_accuracy: 0.5955
#
# Epoch 00006: val_categorical_accuracy improved from 0.51951 to 0.59548, saving model to weights2.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1629s 186ms/step - loss: 0.9972 - categorical_accuracy: 0.6673 - val_loss: 1.1092 - val_categorical_accuracy: 0.6099
#
# Epoch 00007: val_categorical_accuracy improved from 0.59548 to 0.60986, saving model to weights2.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1628s 186ms/step - loss: 0.9254 - categorical_accuracy: 0.6890 - val_loss: 1.0262 - val_categorical_accuracy: 0.6520
#
# Epoch 00008: val_categorical_accuracy improved from 0.60986 to 0.65195, saving model to weights2.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1629s 186ms/step - loss: 0.8637 - categorical_accuracy: 0.7091 - val_loss: 0.9668 - val_categorical_accuracy: 0.6612
#
# Epoch 00009: val_categorical_accuracy improved from 0.65195 to 0.66119, saving model to weights2.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1630s 186ms/step - loss: 0.8164 - categorical_accuracy: 0.7216 - val_loss: 0.9638 - val_categorical_accuracy: 0.6745
#
# Epoch 00010: val_categorical_accuracy improved from 0.66119 to 0.67454, saving model to weights2.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 55s 56ms/step
#
#
# Fold 3:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1628s 186ms/step - loss: 1.6397 - categorical_accuracy: 0.4556 - val_loss: 1.9130 - val_categorical_accuracy: 0.2782
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27823, saving model to weights3.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 1.5939 - categorical_accuracy: 0.4583 - val_loss: 1.8707 - val_categorical_accuracy: 0.2844
#
# Epoch 00002: val_categorical_accuracy improved from 0.27823 to 0.28439, saving model to weights3.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1628s 186ms/step - loss: 1.5726 - categorical_accuracy: 0.4623 - val_loss: 1.8419 - val_categorical_accuracy: 0.3060
#
# Epoch 00003: val_categorical_accuracy improved from 0.28439 to 0.30595, saving model to weights3.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 1.5449 - categorical_accuracy: 0.4718 - val_loss: 1.8187 - val_categorical_accuracy: 0.3060
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.30595
# Epoch 5/10
# 8765/8765 [==============================] - 1623s 185ms/step - loss: 1.4874 - categorical_accuracy: 0.4948 - val_loss: 1.4696 - val_categorical_accuracy: 0.5164
#
# Epoch 00005: val_categorical_accuracy improved from 0.30595 to 0.51643, saving model to weights3.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 1.2158 - categorical_accuracy: 0.5979 - val_loss: 1.2283 - val_categorical_accuracy: 0.5821
#
# Epoch 00006: val_categorical_accuracy improved from 0.51643 to 0.58214, saving model to weights3.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1623s 185ms/step - loss: 1.0354 - categorical_accuracy: 0.6577 - val_loss: 1.1146 - val_categorical_accuracy: 0.6294
#
# Epoch 00007: val_categorical_accuracy improved from 0.58214 to 0.62936, saving model to weights3.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 0.9635 - categorical_accuracy: 0.6824 - val_loss: 1.1017 - val_categorical_accuracy: 0.6437
#
# Epoch 00008: val_categorical_accuracy improved from 0.62936 to 0.64374, saving model to weights3.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1624s 185ms/step - loss: 0.9617 - categorical_accuracy: 0.6799 - val_loss: 1.0248 - val_categorical_accuracy: 0.6571
#
# Epoch 00009: val_categorical_accuracy improved from 0.64374 to 0.65708, saving model to weights3.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1624s 185ms/step - loss: 0.9108 - categorical_accuracy: 0.6924 - val_loss: 0.9932 - val_categorical_accuracy: 0.6694
#
# Epoch 00010: val_categorical_accuracy improved from 0.65708 to 0.66940, saving model to weights3.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 54s 56ms/step
#
#
# Fold 4:
# 	Definicao de valores de entrada e saida da rede...
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1652s 188ms/step - loss: 1.6358 - categorical_accuracy: 0.4516 - val_loss: 1.9227 - val_categorical_accuracy: 0.2752
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27515, saving model to weights4.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1651s 188ms/step - loss: 1.5893 - categorical_accuracy: 0.4559 - val_loss: 1.8882 - val_categorical_accuracy: 0.3039
#
# Epoch 00002: val_categorical_accuracy improved from 0.27515 to 0.30390, saving model to weights4.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1652s 188ms/step - loss: 1.5644 - categorical_accuracy: 0.4629 - val_loss: 1.8539 - val_categorical_accuracy: 0.3172
#
# Epoch 00003: val_categorical_accuracy improved from 0.30390 to 0.31725, saving model to weights4.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1651s 188ms/step - loss: 1.5241 - categorical_accuracy: 0.4795 - val_loss: 1.6982 - val_categorical_accuracy: 0.3953
#
# Epoch 00004: val_categorical_accuracy improved from 0.31725 to 0.39528, saving model to weights4.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1652s 188ms/step - loss: 1.2936 - categorical_accuracy: 0.5663 - val_loss: 1.3273 - val_categorical_accuracy: 0.5524
#
# Epoch 00005: val_categorical_accuracy improved from 0.39528 to 0.55236, saving model to weights4.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1654s 189ms/step - loss: 1.0891 - categorical_accuracy: 0.6404 - val_loss: 1.2096 - val_categorical_accuracy: 0.5996
#
# Epoch 00006: val_categorical_accuracy improved from 0.55236 to 0.59959, saving model to weights4.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1653s 189ms/step - loss: 1.0030 - categorical_accuracy: 0.6653 - val_loss: 1.1347 - val_categorical_accuracy: 0.6263
#
# Epoch 00007: val_categorical_accuracy improved from 0.59959 to 0.62628, saving model to weights4.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1653s 189ms/step - loss: 0.9468 - categorical_accuracy: 0.6795 - val_loss: 1.0620 - val_categorical_accuracy: 0.6407
#
# Epoch 00008: val_categorical_accuracy improved from 0.62628 to 0.64066, saving model to weights4.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1653s 189ms/step - loss: 0.8967 - categorical_accuracy: 0.6978 - val_loss: 1.0297 - val_categorical_accuracy: 0.6437
#
# Epoch 00009: val_categorical_accuracy improved from 0.64066 to 0.64374, saving model to weights4.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 0.8545 - categorical_accuracy: 0.7141 - val_loss: 0.9935 - val_categorical_accuracy: 0.6632
#
# Epoch 00010: val_categorical_accuracy improved from 0.64374 to 0.66324, saving model to weights4.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 54s 56ms/step
#
#
# Fold 5:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1695s 193ms/step - loss: 1.6373 - categorical_accuracy: 0.4542 - val_loss: 1.8426 - val_categorical_accuracy: 0.3131
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.31314, saving model to weights5.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1695s 193ms/step - loss: 1.5929 - categorical_accuracy: 0.4581 - val_loss: 1.8031 - val_categorical_accuracy: 0.3162
#
# Epoch 00002: val_categorical_accuracy improved from 0.31314 to 0.31622, saving model to weights5.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1694s 193ms/step - loss: 1.5721 - categorical_accuracy: 0.4592 - val_loss: 1.7824 - val_categorical_accuracy: 0.3368
#
# Epoch 00003: val_categorical_accuracy improved from 0.31622 to 0.33676, saving model to weights5.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1693s 193ms/step - loss: 1.5482 - categorical_accuracy: 0.4706 - val_loss: 1.7045 - val_categorical_accuracy: 0.3819
#
# Epoch 00004: val_categorical_accuracy improved from 0.33676 to 0.38193, saving model to weights5.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1694s 193ms/step - loss: 1.3641 - categorical_accuracy: 0.5525 - val_loss: 1.3013 - val_categorical_accuracy: 0.5626
#
# Epoch 00005: val_categorical_accuracy improved from 0.38193 to 0.56263, saving model to weights5.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1694s 193ms/step - loss: 1.2080 - categorical_accuracy: 0.6013 - val_loss: 1.0906 - val_categorical_accuracy: 0.6335
#
# Epoch 00006: val_categorical_accuracy improved from 0.56263 to 0.63347, saving model to weights5.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1696s 194ms/step - loss: 1.0825 - categorical_accuracy: 0.6443 - val_loss: 1.0328 - val_categorical_accuracy: 0.6632
#
# Epoch 00007: val_categorical_accuracy improved from 0.63347 to 0.66324, saving model to weights5.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1696s 193ms/step - loss: 0.9894 - categorical_accuracy: 0.6753 - val_loss: 0.9830 - val_categorical_accuracy: 0.6694
#
# Epoch 00008: val_categorical_accuracy improved from 0.66324 to 0.66940, saving model to weights5.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1694s 193ms/step - loss: 0.9170 - categorical_accuracy: 0.6915 - val_loss: 0.9657 - val_categorical_accuracy: 0.6879
#
# Epoch 00009: val_categorical_accuracy improved from 0.66940 to 0.68789, saving model to weights5.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1694s 193ms/step - loss: 0.8803 - categorical_accuracy: 0.7031 - val_loss: 0.9155 - val_categorical_accuracy: 0.6858
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.68789
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 54s 56ms/step
#
#
# Fold 6:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1642s 187ms/step - loss: 1.6527 - categorical_accuracy: 0.4517 - val_loss: 1.8454 - val_categorical_accuracy: 0.3070
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.30698, saving model to weights6.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 1.6088 - categorical_accuracy: 0.4578 - val_loss: 1.8073 - val_categorical_accuracy: 0.3234
#
# Epoch 00002: val_categorical_accuracy improved from 0.30698 to 0.32341, saving model to weights6.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 1.5898 - categorical_accuracy: 0.4600 - val_loss: 1.7953 - val_categorical_accuracy: 0.3645
#
# Epoch 00003: val_categorical_accuracy improved from 0.32341 to 0.36448, saving model to weights6.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 1.5648 - categorical_accuracy: 0.4649 - val_loss: 1.7657 - val_categorical_accuracy: 0.3696
#
# Epoch 00004: val_categorical_accuracy improved from 0.36448 to 0.36961, saving model to weights6.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 1.4674 - categorical_accuracy: 0.5038 - val_loss: 1.4177 - val_categorical_accuracy: 0.5462
#
# Epoch 00005: val_categorical_accuracy improved from 0.36961 to 0.54620, saving model to weights6.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1641s 187ms/step - loss: 1.2215 - categorical_accuracy: 0.5983 - val_loss: 1.2933 - val_categorical_accuracy: 0.5801
#
# Epoch 00006: val_categorical_accuracy improved from 0.54620 to 0.58008, saving model to weights6.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1641s 187ms/step - loss: 1.0604 - categorical_accuracy: 0.6554 - val_loss: 1.0888 - val_categorical_accuracy: 0.6458
#
# Epoch 00007: val_categorical_accuracy improved from 0.58008 to 0.64579, saving model to weights6.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 0.9780 - categorical_accuracy: 0.6716 - val_loss: 1.0363 - val_categorical_accuracy: 0.6530
#
# Epoch 00008: val_categorical_accuracy improved from 0.64579 to 0.65298, saving model to weights6.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1639s 187ms/step - loss: 0.9092 - categorical_accuracy: 0.6946 - val_loss: 0.9959 - val_categorical_accuracy: 0.6602
#
# Epoch 00009: val_categorical_accuracy improved from 0.65298 to 0.66016, saving model to weights6.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1640s 187ms/step - loss: 0.8571 - categorical_accuracy: 0.7104 - val_loss: 0.9610 - val_categorical_accuracy: 0.6694
#
# Epoch 00010: val_categorical_accuracy improved from 0.66016 to 0.66940, saving model to weights6.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 55s 56ms/step
#
#
# Fold 7:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1629s 186ms/step - loss: 1.6358 - categorical_accuracy: 0.4546 - val_loss: 1.9057 - val_categorical_accuracy: 0.2864
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.28645, saving model to weights7.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1626s 185ms/step - loss: 1.5920 - categorical_accuracy: 0.4633 - val_loss: 1.8580 - val_categorical_accuracy: 0.3090
#
# Epoch 00002: val_categorical_accuracy improved from 0.28645 to 0.30903, saving model to weights7.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1627s 186ms/step - loss: 1.5656 - categorical_accuracy: 0.4626 - val_loss: 1.8222 - val_categorical_accuracy: 0.3378
#
# Epoch 00003: val_categorical_accuracy improved from 0.30903 to 0.33778, saving model to weights7.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1626s 185ms/step - loss: 1.5303 - categorical_accuracy: 0.4737 - val_loss: 1.7050 - val_categorical_accuracy: 0.4004
#
# Epoch 00004: val_categorical_accuracy improved from 0.33778 to 0.40041, saving model to weights7.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1626s 185ms/step - loss: 1.3700 - categorical_accuracy: 0.5339 - val_loss: 1.3250 - val_categorical_accuracy: 0.5318
#
# Epoch 00005: val_categorical_accuracy improved from 0.40041 to 0.53183, saving model to weights7.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 1.1347 - categorical_accuracy: 0.6217 - val_loss: 1.1604 - val_categorical_accuracy: 0.5934
#
# Epoch 00006: val_categorical_accuracy improved from 0.53183 to 0.59343, saving model to weights7.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1626s 186ms/step - loss: 1.0645 - categorical_accuracy: 0.6491 - val_loss: 1.1830 - val_categorical_accuracy: 0.5924
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.59343
# Epoch 8/10
# 8765/8765 [==============================] - 1625s 185ms/step - loss: 1.0551 - categorical_accuracy: 0.6494 - val_loss: 1.1422 - val_categorical_accuracy: 0.6037
#
# Epoch 00008: val_categorical_accuracy improved from 0.59343 to 0.60370, saving model to weights7.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1626s 186ms/step - loss: 0.9768 - categorical_accuracy: 0.6731 - val_loss: 1.0810 - val_categorical_accuracy: 0.6160
#
# Epoch 00009: val_categorical_accuracy improved from 0.60370 to 0.61602, saving model to weights7.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1626s 186ms/step - loss: 0.9253 - categorical_accuracy: 0.6948 - val_loss: 1.0333 - val_categorical_accuracy: 0.6355
#
# Epoch 00010: val_categorical_accuracy improved from 0.61602 to 0.63552, saving model to weights7.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 55s 57ms/step
#
#
# Fold 8:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8765 samples, validate on 974 samples
# Epoch 1/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 1.6311 - categorical_accuracy: 0.4601 - val_loss: 1.8877 - val_categorical_accuracy: 0.2752
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27515, saving model to weights8.hdf5
# Epoch 2/10
# 8765/8765 [==============================] - 1654s 189ms/step - loss: 1.5869 - categorical_accuracy: 0.4637 - val_loss: 1.8491 - val_categorical_accuracy: 0.2926
#
# Epoch 00002: val_categorical_accuracy improved from 0.27515 to 0.29261, saving model to weights8.hdf5
# Epoch 3/10
# 8765/8765 [==============================] - 1654s 189ms/step - loss: 1.5632 - categorical_accuracy: 0.4666 - val_loss: 1.8353 - val_categorical_accuracy: 0.2967
#
# Epoch 00003: val_categorical_accuracy improved from 0.29261 to 0.29671, saving model to weights8.hdf5
# Epoch 4/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 1.4729 - categorical_accuracy: 0.5061 - val_loss: 1.5131 - val_categorical_accuracy: 0.4569
#
# Epoch 00004: val_categorical_accuracy improved from 0.29671 to 0.45688, saving model to weights8.hdf5
# Epoch 5/10
# 8765/8765 [==============================] - 1653s 189ms/step - loss: 1.2051 - categorical_accuracy: 0.6018 - val_loss: 1.2898 - val_categorical_accuracy: 0.5616
#
# Epoch 00005: val_categorical_accuracy improved from 0.45688 to 0.56160, saving model to weights8.hdf5
# Epoch 6/10
# 8765/8765 [==============================] - 1654s 189ms/step - loss: 1.0623 - categorical_accuracy: 0.6521 - val_loss: 1.1707 - val_categorical_accuracy: 0.5996
#
# Epoch 00006: val_categorical_accuracy improved from 0.56160 to 0.59959, saving model to weights8.hdf5
# Epoch 7/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 0.9721 - categorical_accuracy: 0.6740 - val_loss: 1.1038 - val_categorical_accuracy: 0.6314
#
# Epoch 00007: val_categorical_accuracy improved from 0.59959 to 0.63142, saving model to weights8.hdf5
# Epoch 8/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 0.9029 - categorical_accuracy: 0.6973 - val_loss: 1.0741 - val_categorical_accuracy: 0.6366
#
# Epoch 00008: val_categorical_accuracy improved from 0.63142 to 0.63655, saving model to weights8.hdf5
# Epoch 9/10
# 8765/8765 [==============================] - 1656s 189ms/step - loss: 0.8520 - categorical_accuracy: 0.7158 - val_loss: 1.0114 - val_categorical_accuracy: 0.6530
#
# Epoch 00009: val_categorical_accuracy improved from 0.63655 to 0.65298, saving model to weights8.hdf5
# Epoch 10/10
# 8765/8765 [==============================] - 1655s 189ms/step - loss: 0.8180 - categorical_accuracy: 0.7223 - val_loss: 0.9922 - val_categorical_accuracy: 0.6622
#
# Epoch 00010: val_categorical_accuracy improved from 0.65298 to 0.66222, saving model to weights8.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 974/974 [==============================] - 59s 60ms/step
#
#
# Fold 9:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 8766 samples, validate on 973 samples
# Epoch 1/10
# 8766/8766 [==============================] - 1649s 188ms/step - loss: 1.6385 - categorical_accuracy: 0.4555 - val_loss: 1.8885 - val_categorical_accuracy: 0.2785
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27852, saving model to weights9.hdf5
# Epoch 2/10
# 8766/8766 [==============================] - 1615s 184ms/step - loss: 1.5934 - categorical_accuracy: 0.4597 - val_loss: 1.8329 - val_categorical_accuracy: 0.3104
#
# Epoch 00002: val_categorical_accuracy improved from 0.27852 to 0.31038, saving model to weights9.hdf5
# Epoch 3/10
# 8766/8766 [==============================] - 1617s 184ms/step - loss: 1.5631 - categorical_accuracy: 0.4661 - val_loss: 1.8017 - val_categorical_accuracy: 0.3248
#
# Epoch 00003: val_categorical_accuracy improved from 0.31038 to 0.32477, saving model to weights9.hdf5
# Epoch 4/10
# 8766/8766 [==============================] - 1615s 184ms/step - loss: 1.4961 - categorical_accuracy: 0.4978 - val_loss: 1.4281 - val_categorical_accuracy: 0.5406
#
# Epoch 00004: val_categorical_accuracy improved from 0.32477 to 0.54060, saving model to weights9.hdf5
# Epoch 5/10
# 8766/8766 [==============================] - 1618s 185ms/step - loss: 1.2210 - categorical_accuracy: 0.6083 - val_loss: 1.2165 - val_categorical_accuracy: 0.6095
#
# Epoch 00005: val_categorical_accuracy improved from 0.54060 to 0.60946, saving model to weights9.hdf5
# Epoch 6/10
# 8766/8766 [==============================] - 1616s 184ms/step - loss: 1.0664 - categorical_accuracy: 0.6475 - val_loss: 1.1502 - val_categorical_accuracy: 0.6310
#
# Epoch 00006: val_categorical_accuracy improved from 0.60946 to 0.63104, saving model to weights9.hdf5
# Epoch 7/10
# 8766/8766 [==============================] - 1616s 184ms/step - loss: 0.9939 - categorical_accuracy: 0.6708 - val_loss: 1.0719 - val_categorical_accuracy: 0.6393
#
# Epoch 00007: val_categorical_accuracy improved from 0.63104 to 0.63926, saving model to weights9.hdf5
# Epoch 8/10
# 8766/8766 [==============================] - 1616s 184ms/step - loss: 0.9372 - categorical_accuracy: 0.6856 - val_loss: 1.0085 - val_categorical_accuracy: 0.6526
#
# Epoch 00008: val_categorical_accuracy improved from 0.63926 to 0.65262, saving model to weights9.hdf5
# Epoch 9/10
# 8766/8766 [==============================] - 1616s 184ms/step - loss: 0.8920 - categorical_accuracy: 0.6946 - val_loss: 0.9640 - val_categorical_accuracy: 0.6711
#
# Epoch 00009: val_categorical_accuracy improved from 0.65262 to 0.67112, saving model to weights9.hdf5
# Epoch 10/10
# 8766/8766 [==============================] - 1616s 184ms/step - loss: 0.8482 - categorical_accuracy: 0.7174 - val_loss: 0.9352 - val_categorical_accuracy: 0.6732
#
# Epoch 00010: val_categorical_accuracy improved from 0.67112 to 0.67318, saving model to weights9.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 973/973 [==============================] - 54s 56ms/step

# %% [markdown]
# # Exportação dos resultados

# %%
df_medias = pd.DataFrame()
df_medias['mean'] = df_scores.mean()
df_medias['std'] = df_scores.std()
df_medias.T
# Out:
#       Competência do TCU  Contrato Administrativo  Convênio  Desestatização  \
# mean            0.036714                 0.232627  0.099641        0.290263
# std             0.050664                 0.095432  0.055103        0.161434
#
#       Direito Processual  Finanças Públicas  Gestão Administrativa  Licitação  \
# mean            0.549983            0.38059               0.120238   0.758794
# std             0.034867            0.05274               0.093244   0.016677
#
#        Pessoal  Responsabilidade  accuracy  macro avg  weighted avg
# mean  0.938752          0.576538  0.667523   0.398414      0.634152
# std   0.006688          0.045975  0.013289   0.029673      0.013404

# %%
df_medias.T.to_csv('scores_recorrente.csv', encoding = 'Latin1')
