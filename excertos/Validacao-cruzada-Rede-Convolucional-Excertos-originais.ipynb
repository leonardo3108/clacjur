# %% [markdown]
# # Obtenção e organização dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/jurisprudencia_selecionada_excertos.CSV', sep = ';')[['DESCR_AREA', 'TEXTO_EXCERTO']]
df.head()
# Out:
#            DESCR_AREA                                      TEXTO_EXCERTO
# 0    Responsabilidade  Voto:Cuidam os autos de tomada de contas espec...
# 1   Finanças Públicas  Voto:Cuidam os autos de Solicitação do Congres...
# 2    Responsabilidade  Relatório:Trata-se de embargos de declaração o...
# 3  Direito Processual  Voto:8. Em relação a outros processos judiciai...
# 4             Pessoal  Voto:11. Relativamente ao ato envolvendo a Sra...

# %%
df.shape
# Out:
# (13285, 2)

# %%
from sklearn.preprocessing import LabelBinarizer

areas = df.groupby(['DESCR_AREA']).groups.keys()
lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
y = lbArea.transform(df['DESCR_AREA'])
lbArea.classes_, y.shape
# Out:
# (array(['Competência do TCU', 'Contrato Administrativo', 'Convênio',
#         'Desestatização', 'Direito Processual', 'Finanças Públicas',
#         'Gestão Administrativa', 'Licitação', 'Pessoal',
#         'Responsabilidade'], dtype='<U23'), (13285, 10))

# %% [markdown]
# # Pré-processamento

# %%
colunas_scores = list(lbArea.classes_)
colunas_scores.extend(['accuracy', 'macro avg', 'weighted avg'])

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

print('\tCarregamento do modelo de acordaos...')
modelo = Word2Vec.load('../vocabularios/modelo-acordaos.w2v')
# Out:
# 	Carregamento do modelo de acordaos...
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

df_scores = pd.DataFrame()

limite_texto = 2000
dim_vetor = 100

print('\tTokenizacao e montagem de sequencias...')
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['TEXTO_EXCERTO'])
vocabulario = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(df['TEXTO_EXCERTO'])

print('\tMontagem da matriz de embeddings...')
embedding_matrix = np.zeros((vocabulario, dim_vetor))
for word, i in tokenizer.word_index.items():
    if word in modelo.wv:
        embedding_matrix[i] = modelo.wv[word]
# Out:
# 	Tokenizacao e montagem de sequencias...
# 	Montagem da matriz de embeddings...

# %% [markdown]
# # Treinamentos com Cross-validation

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, GlobalMaxPooling1D, Flatten, GRU
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint

fold = 0
for train_index, val_index in KFold(n_splits=10, random_state=42, shuffle=True).split(df):
    str_fold = 'Fold ' + str(fold)
    print()
    print()
    print(str_fold + ':')
    print('\tDefinicao de valores de entrada e saida da rede...')

    df_train = df.loc[train_index]
    df_val = df.loc[val_index]

    sequences_train = tokenizer.texts_to_sequences(df_train['TEXTO_EXCERTO'])
    sequences_val = tokenizer.texts_to_sequences(df_val['TEXTO_EXCERTO'])

    x_train = pad_sequences(sequences_train, maxlen=limite_texto)
    x_val = pad_sequences(sequences_val, maxlen=limite_texto)

    y_train = lbArea.transform(df_train['DESCR_AREA'])
    y_val = lbArea.transform(df_val['DESCR_AREA'])

    print('\tTreinamento da rede...')
    model = Sequential()
    model.add(Embedding(vocabulario, dim_vetor, input_length=limite_texto, trainable=True,  weights=[embedding_matrix]))
    model.add(Conv1D(32, 7, activation='relu'))
    model.add(MaxPooling1D(5))
    model.add(Conv1D(32, 7, activation='relu'))
    model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=['categorical_accuracy'])

    checkpoint_filename = 'weights' + str(fold) + '.hdf5'
    checkpointer = ModelCheckpoint(filepath=checkpoint_filename, monitor='val_categorical_accuracy', verbose=1, save_best_only=True)
    model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), verbose=1, shuffle=False, callbacks=[checkpointer])

    print('\n\tAvaliacao do melhor modelo and registro dos scores...')
    model.load_weights(checkpoint_filename)
    y_val_pred = model.predict_classes(x_val, verbose=1)
    y_val_i = [list(x).index(1) for x in y_val]
    report = classification_report(y_val_i, y_val_pred, target_names=lbArea.classes_, output_dict = True)
    for col in colunas_scores:
        if col == 'accuracy':
            f = report[col]
        else:
            f = report[col]['f1-score']
        df_scores.loc[str_fold,col] = f
    fold += 1
# Out:
# Fold 0:
# 	Definicao de valores de entrada e saida da rede...
# WARNING: Logging before flag parsing goes to stderr.
# W0322 13:36:41.725331 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0322 13:36:41.736631 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0322 13:36:41.741533 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0322 13:36:41.781068 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0322 13:36:41.781592 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# 	Treinamento da rede...
# W0322 13:36:42.761628 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0322 13:36:42.886315 140548442859328 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0322 13:36:43.323782 140548442859328 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0322 13:36:43.424240 140548442859328 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 11956 samples, validate on 1329 samples
# Epoch 1/10
# 11956/11956 [==============================] - 142s 12ms/step - loss: 1.2842 - categorical_accuracy: 0.5752 - val_loss: 1.4043 - val_categorical_accuracy: 0.5290
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.52897, saving model to weights0.hdf5
# Epoch 2/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.9422 - categorical_accuracy: 0.6838 - val_loss: 1.1313 - val_categorical_accuracy: 0.6290
#
# Epoch 00002: val_categorical_accuracy improved from 0.52897 to 0.62904, saving model to weights0.hdf5
# Epoch 3/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.7983 - categorical_accuracy: 0.7246 - val_loss: 0.9573 - val_categorical_accuracy: 0.6764
#
# Epoch 00003: val_categorical_accuracy improved from 0.62904 to 0.67645, saving model to weights0.hdf5
# Epoch 4/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.7130 - categorical_accuracy: 0.7557 - val_loss: 0.8982 - val_categorical_accuracy: 0.7013
#
# Epoch 00004: val_categorical_accuracy improved from 0.67645 to 0.70128, saving model to weights0.hdf5
# Epoch 5/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.6386 - categorical_accuracy: 0.7850 - val_loss: 0.8655 - val_categorical_accuracy: 0.7141
#
# Epoch 00005: val_categorical_accuracy improved from 0.70128 to 0.71407, saving model to weights0.hdf5
# Epoch 6/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.5725 - categorical_accuracy: 0.8045 - val_loss: 0.8300 - val_categorical_accuracy: 0.7314
#
# Epoch 00006: val_categorical_accuracy improved from 0.71407 to 0.73138, saving model to weights0.hdf5
# Epoch 7/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.5178 - categorical_accuracy: 0.8267 - val_loss: 0.8227 - val_categorical_accuracy: 0.7457
#
# Epoch 00007: val_categorical_accuracy improved from 0.73138 to 0.74567, saving model to weights0.hdf5
# Epoch 8/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.4653 - categorical_accuracy: 0.8423 - val_loss: 0.8420 - val_categorical_accuracy: 0.7479
#
# Epoch 00008: val_categorical_accuracy improved from 0.74567 to 0.74793, saving model to weights0.hdf5
# Epoch 9/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.4192 - categorical_accuracy: 0.8597 - val_loss: 0.7842 - val_categorical_accuracy: 0.7615
#
# Epoch 00009: val_categorical_accuracy improved from 0.74793 to 0.76147, saving model to weights0.hdf5
# Epoch 10/10
# 11956/11956 [==============================] - 138s 12ms/step - loss: 0.3759 - categorical_accuracy: 0.8747 - val_loss: 0.8257 - val_categorical_accuracy: 0.7479
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.76147
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1329/1329 [==============================] - 5s 4ms/step
#
#
# Fold 1:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11956 samples, validate on 1329 samples
# Epoch 1/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 1.2538 - categorical_accuracy: 0.5867 - val_loss: 1.2298 - val_categorical_accuracy: 0.5952
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.59518, saving model to weights1.hdf5
# Epoch 2/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.9167 - categorical_accuracy: 0.6919 - val_loss: 1.2111 - val_categorical_accuracy: 0.6065
#
# Epoch 00002: val_categorical_accuracy improved from 0.59518 to 0.60647, saving model to weights1.hdf5
# Epoch 3/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.7825 - categorical_accuracy: 0.7359 - val_loss: 0.9561 - val_categorical_accuracy: 0.6847
#
# Epoch 00003: val_categorical_accuracy improved from 0.60647 to 0.68473, saving model to weights1.hdf5
# Epoch 4/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.6931 - categorical_accuracy: 0.7646 - val_loss: 0.8279 - val_categorical_accuracy: 0.7223
#
# Epoch 00004: val_categorical_accuracy improved from 0.68473 to 0.72235, saving model to weights1.hdf5
# Epoch 5/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.6110 - categorical_accuracy: 0.7984 - val_loss: 0.8280 - val_categorical_accuracy: 0.7239
#
# Epoch 00005: val_categorical_accuracy improved from 0.72235 to 0.72385, saving model to weights1.hdf5
# Epoch 6/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.5548 - categorical_accuracy: 0.8152 - val_loss: 0.7796 - val_categorical_accuracy: 0.7321
#
# Epoch 00006: val_categorical_accuracy improved from 0.72385 to 0.73213, saving model to weights1.hdf5
# Epoch 7/10
# 11956/11956 [==============================] - 142s 12ms/step - loss: 0.4925 - categorical_accuracy: 0.8376 - val_loss: 0.7652 - val_categorical_accuracy: 0.7585
#
# Epoch 00007: val_categorical_accuracy improved from 0.73213 to 0.75847, saving model to weights1.hdf5
# Epoch 8/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.4396 - categorical_accuracy: 0.8550 - val_loss: 0.7282 - val_categorical_accuracy: 0.7690
#
# Epoch 00008: val_categorical_accuracy improved from 0.75847 to 0.76900, saving model to weights1.hdf5
# Epoch 9/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.3949 - categorical_accuracy: 0.8700 - val_loss: 0.7391 - val_categorical_accuracy: 0.7788
#
# Epoch 00009: val_categorical_accuracy improved from 0.76900 to 0.77878, saving model to weights1.hdf5
# Epoch 10/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.3655 - categorical_accuracy: 0.8795 - val_loss: 0.7465 - val_categorical_accuracy: 0.7698
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.77878
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1329/1329 [==============================] - 5s 4ms/step
#
#
# Fold 2:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11956 samples, validate on 1329 samples
# Epoch 1/10
# 11956/11956 [==============================] - 142s 12ms/step - loss: 1.2643 - categorical_accuracy: 0.5841 - val_loss: 1.1261 - val_categorical_accuracy: 0.5989
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.59895, saving model to weights2.hdf5
# Epoch 2/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.9070 - categorical_accuracy: 0.6971 - val_loss: 1.0513 - val_categorical_accuracy: 0.6193
#
# Epoch 00002: val_categorical_accuracy improved from 0.59895 to 0.61926, saving model to weights2.hdf5
# Epoch 3/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.7622 - categorical_accuracy: 0.7428 - val_loss: 0.8728 - val_categorical_accuracy: 0.7013
#
# Epoch 00003: val_categorical_accuracy improved from 0.61926 to 0.70128, saving model to weights2.hdf5
# Epoch 4/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.6693 - categorical_accuracy: 0.7728 - val_loss: 0.7799 - val_categorical_accuracy: 0.7366
#
# Epoch 00004: val_categorical_accuracy improved from 0.70128 to 0.73664, saving model to weights2.hdf5
# Epoch 5/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.5945 - categorical_accuracy: 0.8009 - val_loss: 0.7559 - val_categorical_accuracy: 0.7472
#
# Epoch 00005: val_categorical_accuracy improved from 0.73664 to 0.74718, saving model to weights2.hdf5
# Epoch 6/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.5397 - categorical_accuracy: 0.8209 - val_loss: 0.6945 - val_categorical_accuracy: 0.7713
#
# Epoch 00006: val_categorical_accuracy improved from 0.74718 to 0.77126, saving model to weights2.hdf5
# Epoch 7/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.4786 - categorical_accuracy: 0.8399 - val_loss: 0.7066 - val_categorical_accuracy: 0.7645
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.77126
# Epoch 8/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.4262 - categorical_accuracy: 0.8588 - val_loss: 0.6776 - val_categorical_accuracy: 0.7856
#
# Epoch 00008: val_categorical_accuracy improved from 0.77126 to 0.78555, saving model to weights2.hdf5
# Epoch 9/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.3856 - categorical_accuracy: 0.8745 - val_loss: 0.6697 - val_categorical_accuracy: 0.7856
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.78555
# Epoch 10/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 0.3402 - categorical_accuracy: 0.8881 - val_loss: 0.6971 - val_categorical_accuracy: 0.7803
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.78555
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1329/1329 [==============================] - 5s 4ms/step
#
#
# Fold 3:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11956 samples, validate on 1329 samples
# Epoch 1/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 1.2562 - categorical_accuracy: 0.5881 - val_loss: 1.2951 - val_categorical_accuracy: 0.5726
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.57261, saving model to weights3.hdf5
# Epoch 2/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.9259 - categorical_accuracy: 0.6903 - val_loss: 1.1385 - val_categorical_accuracy: 0.6140
#
# Epoch 00002: val_categorical_accuracy improved from 0.57261 to 0.61400, saving model to weights3.hdf5
# Epoch 3/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.7950 - categorical_accuracy: 0.7298 - val_loss: 1.0276 - val_categorical_accuracy: 0.6411
#
# Epoch 00003: val_categorical_accuracy improved from 0.61400 to 0.64108, saving model to weights3.hdf5
# Epoch 4/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.7029 - categorical_accuracy: 0.7661 - val_loss: 0.8792 - val_categorical_accuracy: 0.6975
#
# Epoch 00004: val_categorical_accuracy improved from 0.64108 to 0.69752, saving model to weights3.hdf5
# Epoch 5/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.6312 - categorical_accuracy: 0.7895 - val_loss: 0.8450 - val_categorical_accuracy: 0.7246
#
# Epoch 00005: val_categorical_accuracy improved from 0.69752 to 0.72460, saving model to weights3.hdf5
# Epoch 6/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.5684 - categorical_accuracy: 0.8075 - val_loss: 0.8073 - val_categorical_accuracy: 0.7464
#
# Epoch 00006: val_categorical_accuracy improved from 0.72460 to 0.74643, saving model to weights3.hdf5
# Epoch 7/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.5112 - categorical_accuracy: 0.8297 - val_loss: 0.7628 - val_categorical_accuracy: 0.7607
#
# Epoch 00007: val_categorical_accuracy improved from 0.74643 to 0.76072, saving model to weights3.hdf5
# Epoch 8/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.4652 - categorical_accuracy: 0.8454 - val_loss: 0.7545 - val_categorical_accuracy: 0.7637
#
# Epoch 00008: val_categorical_accuracy improved from 0.76072 to 0.76373, saving model to weights3.hdf5
# Epoch 9/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.4165 - categorical_accuracy: 0.8634 - val_loss: 0.7181 - val_categorical_accuracy: 0.7818
#
# Epoch 00009: val_categorical_accuracy improved from 0.76373 to 0.78179, saving model to weights3.hdf5
# Epoch 10/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.3705 - categorical_accuracy: 0.8795 - val_loss: 0.7540 - val_categorical_accuracy: 0.7652
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.78179
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1329/1329 [==============================] - 5s 4ms/step
#
#
# Fold 4:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11956 samples, validate on 1329 samples
# Epoch 1/10
# 11956/11956 [==============================] - 141s 12ms/step - loss: 1.2264 - categorical_accuracy: 0.5987 - val_loss: 1.1843 - val_categorical_accuracy: 0.5967
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.59669, saving model to weights4.hdf5
# Epoch 2/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.9063 - categorical_accuracy: 0.6917 - val_loss: 1.0000 - val_categorical_accuracy: 0.6486
#
# Epoch 00002: val_categorical_accuracy improved from 0.59669 to 0.64861, saving model to weights4.hdf5
# Epoch 3/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.7778 - categorical_accuracy: 0.7329 - val_loss: 0.8868 - val_categorical_accuracy: 0.7043
#
# Epoch 00003: val_categorical_accuracy improved from 0.64861 to 0.70429, saving model to weights4.hdf5
# Epoch 4/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.6929 - categorical_accuracy: 0.7667 - val_loss: 0.8148 - val_categorical_accuracy: 0.7381
#
# Epoch 00004: val_categorical_accuracy improved from 0.70429 to 0.73815, saving model to weights4.hdf5
# Epoch 5/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.6276 - categorical_accuracy: 0.7913 - val_loss: 0.7852 - val_categorical_accuracy: 0.7351
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.73815
# Epoch 6/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.5601 - categorical_accuracy: 0.8152 - val_loss: 0.7615 - val_categorical_accuracy: 0.7570
#
# Epoch 00006: val_categorical_accuracy improved from 0.73815 to 0.75696, saving model to weights4.hdf5
# Epoch 7/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.5028 - categorical_accuracy: 0.8320 - val_loss: 0.7704 - val_categorical_accuracy: 0.7555
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.75696
# Epoch 8/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.4589 - categorical_accuracy: 0.8495 - val_loss: 0.7285 - val_categorical_accuracy: 0.7652
#
# Epoch 00008: val_categorical_accuracy improved from 0.75696 to 0.76524, saving model to weights4.hdf5
# Epoch 9/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.4110 - categorical_accuracy: 0.8679 - val_loss: 0.7635 - val_categorical_accuracy: 0.7652
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.76524
# Epoch 10/10
# 11956/11956 [==============================] - 140s 12ms/step - loss: 0.3628 - categorical_accuracy: 0.8831 - val_loss: 0.7585 - val_categorical_accuracy: 0.7743
#
# Epoch 00010: val_categorical_accuracy improved from 0.76524 to 0.77427, saving model to weights4.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1329/1329 [==============================] - 5s 4ms/step
#
#
# Fold 5:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11957 samples, validate on 1328 samples
# Epoch 1/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 1.2556 - categorical_accuracy: 0.5923 - val_loss: 1.1877 - val_categorical_accuracy: 0.5768
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.57681, saving model to weights5.hdf5
# Epoch 2/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.9209 - categorical_accuracy: 0.6890 - val_loss: 0.9754 - val_categorical_accuracy: 0.6679
#
# Epoch 00002: val_categorical_accuracy improved from 0.57681 to 0.66792, saving model to weights5.hdf5
# Epoch 3/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.7936 - categorical_accuracy: 0.7308 - val_loss: 0.8368 - val_categorical_accuracy: 0.7011
#
# Epoch 00003: val_categorical_accuracy improved from 0.66792 to 0.70105, saving model to weights5.hdf5
# Epoch 4/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.6993 - categorical_accuracy: 0.7633 - val_loss: 0.7980 - val_categorical_accuracy: 0.7139
#
# Epoch 00004: val_categorical_accuracy improved from 0.70105 to 0.71386, saving model to weights5.hdf5
# Epoch 5/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.6263 - categorical_accuracy: 0.7922 - val_loss: 0.7660 - val_categorical_accuracy: 0.7342
#
# Epoch 00005: val_categorical_accuracy improved from 0.71386 to 0.73419, saving model to weights5.hdf5
# Epoch 6/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.5674 - categorical_accuracy: 0.8133 - val_loss: 0.6349 - val_categorical_accuracy: 0.7794
#
# Epoch 00006: val_categorical_accuracy improved from 0.73419 to 0.77937, saving model to weights5.hdf5
# Epoch 7/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.5065 - categorical_accuracy: 0.8327 - val_loss: 0.7373 - val_categorical_accuracy: 0.7598
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.77937
# Epoch 8/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.4494 - categorical_accuracy: 0.8500 - val_loss: 0.6669 - val_categorical_accuracy: 0.7831
#
# Epoch 00008: val_categorical_accuracy improved from 0.77937 to 0.78313, saving model to weights5.hdf5
# Epoch 9/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.4145 - categorical_accuracy: 0.8644 - val_loss: 0.6398 - val_categorical_accuracy: 0.7929
#
# Epoch 00009: val_categorical_accuracy improved from 0.78313 to 0.79292, saving model to weights5.hdf5
# Epoch 10/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.3703 - categorical_accuracy: 0.8788 - val_loss: 0.6761 - val_categorical_accuracy: 0.7831
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.79292
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1328/1328 [==============================] - 5s 4ms/step
#
#
# Fold 6:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11957 samples, validate on 1328 samples
# Epoch 1/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 1.2415 - categorical_accuracy: 0.5935 - val_loss: 1.3412 - val_categorical_accuracy: 0.5640
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.56401, saving model to weights6.hdf5
# Epoch 2/10
# 11957/11957 [==============================] - 137s 11ms/step - loss: 0.9190 - categorical_accuracy: 0.6933 - val_loss: 1.1028 - val_categorical_accuracy: 0.6152
#
# Epoch 00002: val_categorical_accuracy improved from 0.56401 to 0.61521, saving model to weights6.hdf5
# Epoch 3/10
# 11957/11957 [==============================] - 138s 12ms/step - loss: 0.7926 - categorical_accuracy: 0.7330 - val_loss: 0.9020 - val_categorical_accuracy: 0.6845
#
# Epoch 00003: val_categorical_accuracy improved from 0.61521 to 0.68449, saving model to weights6.hdf5
# Epoch 4/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.6903 - categorical_accuracy: 0.7715 - val_loss: 0.8407 - val_categorical_accuracy: 0.6965
#
# Epoch 00004: val_categorical_accuracy improved from 0.68449 to 0.69654, saving model to weights6.hdf5
# Epoch 5/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.6148 - categorical_accuracy: 0.7941 - val_loss: 0.8208 - val_categorical_accuracy: 0.7176
#
# Epoch 00005: val_categorical_accuracy improved from 0.69654 to 0.71762, saving model to weights6.hdf5
# Epoch 6/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.5569 - categorical_accuracy: 0.8158 - val_loss: 0.8243 - val_categorical_accuracy: 0.7229
#
# Epoch 00006: val_categorical_accuracy improved from 0.71762 to 0.72289, saving model to weights6.hdf5
# Epoch 7/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.5030 - categorical_accuracy: 0.8336 - val_loss: 0.7332 - val_categorical_accuracy: 0.7485
#
# Epoch 00007: val_categorical_accuracy improved from 0.72289 to 0.74849, saving model to weights6.hdf5
# Epoch 8/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.4513 - categorical_accuracy: 0.8517 - val_loss: 0.7777 - val_categorical_accuracy: 0.7530
#
# Epoch 00008: val_categorical_accuracy improved from 0.74849 to 0.75301, saving model to weights6.hdf5
# Epoch 9/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.4081 - categorical_accuracy: 0.8655 - val_loss: 0.7399 - val_categorical_accuracy: 0.7583
#
# Epoch 00009: val_categorical_accuracy improved from 0.75301 to 0.75828, saving model to weights6.hdf5
# Epoch 10/10
# 11957/11957 [==============================] - 139s 12ms/step - loss: 0.3655 - categorical_accuracy: 0.8823 - val_loss: 0.7621 - val_categorical_accuracy: 0.7530
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.75828
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1328/1328 [==============================] - 6s 4ms/step
#
#
# Fold 7:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11957 samples, validate on 1328 samples
# Epoch 1/10
# 11957/11957 [==============================] - 143s 12ms/step - loss: 1.2235 - categorical_accuracy: 0.5954 - val_loss: 1.4517 - val_categorical_accuracy: 0.5339
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.53389, saving model to weights7.hdf5
# Epoch 2/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.8987 - categorical_accuracy: 0.6920 - val_loss: 0.9667 - val_categorical_accuracy: 0.6672
#
# Epoch 00002: val_categorical_accuracy improved from 0.53389 to 0.66717, saving model to weights7.hdf5
# Epoch 3/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.7630 - categorical_accuracy: 0.7402 - val_loss: 0.8504 - val_categorical_accuracy: 0.7131
#
# Epoch 00003: val_categorical_accuracy improved from 0.66717 to 0.71310, saving model to weights7.hdf5
# Epoch 4/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.6786 - categorical_accuracy: 0.7695 - val_loss: 0.7829 - val_categorical_accuracy: 0.7372
#
# Epoch 00004: val_categorical_accuracy improved from 0.71310 to 0.73720, saving model to weights7.hdf5
# Epoch 5/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.6035 - categorical_accuracy: 0.7980 - val_loss: 0.8391 - val_categorical_accuracy: 0.7206
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.73720
# Epoch 6/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.5466 - categorical_accuracy: 0.8166 - val_loss: 0.7805 - val_categorical_accuracy: 0.7455
#
# Epoch 00006: val_categorical_accuracy improved from 0.73720 to 0.74548, saving model to weights7.hdf5
# Epoch 7/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.4886 - categorical_accuracy: 0.8378 - val_loss: 0.8082 - val_categorical_accuracy: 0.7387
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.74548
# Epoch 8/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.4353 - categorical_accuracy: 0.8549 - val_loss: 0.7851 - val_categorical_accuracy: 0.7568
#
# Epoch 00008: val_categorical_accuracy improved from 0.74548 to 0.75678, saving model to weights7.hdf5
# Epoch 9/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.3897 - categorical_accuracy: 0.8705 - val_loss: 0.6958 - val_categorical_accuracy: 0.7733
#
# Epoch 00009: val_categorical_accuracy improved from 0.75678 to 0.77334, saving model to weights7.hdf5
# Epoch 10/10
# 11957/11957 [==============================] - 141s 12ms/step - loss: 0.3450 - categorical_accuracy: 0.8875 - val_loss: 0.7112 - val_categorical_accuracy: 0.7764
#
# Epoch 00010: val_categorical_accuracy improved from 0.77334 to 0.77636, saving model to weights7.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1328/1328 [==============================] - 6s 4ms/step
#
#
# Fold 8:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11957 samples, validate on 1328 samples
# Epoch 1/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 1.2267 - categorical_accuracy: 0.5963 - val_loss: 1.1015 - val_categorical_accuracy: 0.6363
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.63630, saving model to weights8.hdf5
# Epoch 2/10
# 11957/11957 [==============================] - 142s 12ms/step - loss: 0.8824 - categorical_accuracy: 0.7003 - val_loss: 0.9144 - val_categorical_accuracy: 0.6867
#
# Epoch 00002: val_categorical_accuracy improved from 0.63630 to 0.68675, saving model to weights8.hdf5
# Epoch 3/10
# 11957/11957 [==============================] - 142s 12ms/step - loss: 0.7540 - categorical_accuracy: 0.7448 - val_loss: 0.8419 - val_categorical_accuracy: 0.7199
#
# Epoch 00003: val_categorical_accuracy improved from 0.68675 to 0.71988, saving model to weights8.hdf5
# Epoch 4/10
# 11957/11957 [==============================] - 142s 12ms/step - loss: 0.6598 - categorical_accuracy: 0.7781 - val_loss: 0.8082 - val_categorical_accuracy: 0.7372
#
# Epoch 00004: val_categorical_accuracy improved from 0.71988 to 0.73720, saving model to weights8.hdf5
# Epoch 5/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.5899 - categorical_accuracy: 0.8054 - val_loss: 0.8315 - val_categorical_accuracy: 0.7214
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.73720
# Epoch 6/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.5293 - categorical_accuracy: 0.8236 - val_loss: 0.7988 - val_categorical_accuracy: 0.7477
#
# Epoch 00006: val_categorical_accuracy improved from 0.73720 to 0.74774, saving model to weights8.hdf5
# Epoch 7/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.4811 - categorical_accuracy: 0.8424 - val_loss: 0.8034 - val_categorical_accuracy: 0.7462
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.74774
# Epoch 8/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.4323 - categorical_accuracy: 0.8561 - val_loss: 0.8361 - val_categorical_accuracy: 0.7500
#
# Epoch 00008: val_categorical_accuracy improved from 0.74774 to 0.75000, saving model to weights8.hdf5
# Epoch 9/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.3884 - categorical_accuracy: 0.8720 - val_loss: 0.8156 - val_categorical_accuracy: 0.7673
#
# Epoch 00009: val_categorical_accuracy improved from 0.75000 to 0.76732, saving model to weights8.hdf5
# Epoch 10/10
# 11957/11957 [==============================] - 140s 12ms/step - loss: 0.3489 - categorical_accuracy: 0.8853 - val_loss: 0.8294 - val_categorical_accuracy: 0.7500
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.76732
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1328/1328 [==============================] - 6s 4ms/step
#
#
# Fold 9:
# 	Definicao de valores de entrada e saida da rede...
# 	Treinamento da rede...
# Train on 11957 samples, validate on 1328 samples
# Epoch 1/10
# 11957/11957 [==============================] - 145s 12ms/step - loss: 1.2561 - categorical_accuracy: 0.5910 - val_loss: 1.2013 - val_categorical_accuracy: 0.6039
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.60392, saving model to weights9.hdf5
# Epoch 2/10
# 11957/11957 [==============================] - 143s 12ms/step - loss: 0.9191 - categorical_accuracy: 0.6908 - val_loss: 0.9528 - val_categorical_accuracy: 0.6762
#
# Epoch 00002: val_categorical_accuracy improved from 0.60392 to 0.67620, saving model to weights9.hdf5
# Epoch 3/10
# 11957/11957 [==============================] - 143s 12ms/step - loss: 0.7912 - categorical_accuracy: 0.7301 - val_loss: 0.8391 - val_categorical_accuracy: 0.7176
#
# Epoch 00003: val_categorical_accuracy improved from 0.67620 to 0.71762, saving model to weights9.hdf5
# Epoch 4/10
# 11957/11957 [==============================] - 143s 12ms/step - loss: 0.7010 - categorical_accuracy: 0.7629 - val_loss: 0.7611 - val_categorical_accuracy: 0.7530
#
# Epoch 00004: val_categorical_accuracy improved from 0.71762 to 0.75301, saving model to weights9.hdf5
# Epoch 5/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.6287 - categorical_accuracy: 0.7872 - val_loss: 0.7632 - val_categorical_accuracy: 0.7628
#
# Epoch 00005: val_categorical_accuracy improved from 0.75301 to 0.76280, saving model to weights9.hdf5
# Epoch 6/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.5712 - categorical_accuracy: 0.8067 - val_loss: 0.6800 - val_categorical_accuracy: 0.7854
#
# Epoch 00006: val_categorical_accuracy improved from 0.76280 to 0.78539, saving model to weights9.hdf5
# Epoch 7/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.5157 - categorical_accuracy: 0.8285 - val_loss: 0.6612 - val_categorical_accuracy: 0.7922
#
# Epoch 00007: val_categorical_accuracy improved from 0.78539 to 0.79217, saving model to weights9.hdf5
# Epoch 8/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.4590 - categorical_accuracy: 0.8482 - val_loss: 0.6977 - val_categorical_accuracy: 0.7801
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.79217
# Epoch 9/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.4134 - categorical_accuracy: 0.8669 - val_loss: 0.6582 - val_categorical_accuracy: 0.8042
#
# Epoch 00009: val_categorical_accuracy improved from 0.79217 to 0.80422, saving model to weights9.hdf5
# Epoch 10/10
# 11957/11957 [==============================] - 144s 12ms/step - loss: 0.3691 - categorical_accuracy: 0.8788 - val_loss: 0.6363 - val_categorical_accuracy: 0.8110
#
# Epoch 00010: val_categorical_accuracy improved from 0.80422 to 0.81099, saving model to weights9.hdf5
#
# 	Avaliacao do melhor modelo and registro dos scores...
# 1328/1328 [==============================] - 6s 4ms/step
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Exportação dos resultados

# %%
df_medias = pd.DataFrame()
df_medias['mean'] = df_scores.mean()
df_medias['std'] = df_scores.std()
df_medias.T
# Out:
#       Competência do TCU  Contrato Administrativo  Convênio  Desestatização  \
# mean            0.500756                 0.629869  0.518170        0.252624
# std             0.106851                 0.041450  0.054284        0.160289
#
#       Direito Processual  Finanças Públicas  Gestão Administrativa  Licitação  \
# mean            0.751895           0.560830               0.584903   0.836726
# std             0.019285           0.053011               0.100507   0.019427
#
#        Pessoal  Responsabilidade  accuracy  macro avg  weighted avg
# mean  0.951267          0.739474  0.778774   0.632651      0.773068
# std   0.009269          0.027705  0.015527   0.024342      0.015854

# %%
df_medias.T.to_csv('scores_excerto_original.csv', encoding = 'Latin1')
