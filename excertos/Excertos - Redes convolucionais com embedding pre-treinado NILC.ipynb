# %% [markdown]
# # Importação e preparação dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/jurisprudencia_selecionada_excertos.CSV', sep = ';')
df.head()
# Out:
#     COD  NUM_ENUNCIADO  COD_AREA          DESCR_AREA  COD_TEMA  \
# 0  1400           1236        50    Responsabilidade       488
# 1  1700           1534        46   Finanças Públicas       981
# 2  5700           5314        50    Responsabilidade       203
# 3   284             40        45  Direito Processual       162
# 4   298             54        49             Pessoal       141
#
#                                   DESCR_TEMA  COD_SUBTEMA  \
# 0                              Solidariedade          261
# 1                                 Exportação          983
# 2                                      Multa         1021
# 3  Princípio da independência das instâncias          481
# 4                                  Sistema S          142
#
#               DESCR_SUBTEMA  COD_DOC_TRAMITAVEL_EXCERTO  \
# 0  Benefício previdenciário                    54995438
# 1                  Petróleo                    55025603
# 2                Dosimetria                    55455375
# 3          Decisão judicial                    54773747
# 4                 Nepotismo                    54773403
#
#                                        TEXTO_EXCERTO                ACORDAO  \
# 0  Voto:Cuidam os autos de tomada de contas espec...  Acórdão 297/2016 - PL
# 1  Voto:Cuidam os autos de Solicitação do Congres...  Acórdão 366/2016 - PL
# 2  Relatório:Trata-se de embargos de declaração o...  Acórdão 944/2016 - PL
# 3  Voto:8. Em relação a outros processos judiciai...   Acórdão 30/2016 - PL
# 4  Voto:11. Relativamente ao ato envolvendo a Sra...   Acórdão 55/2016 - PL
#
#                         TIPO_PROCESSO
# 0           Tomada de Contas Especial
# 1   Solicitação do Congresso Nacional
# 2                      Acompanhamento
# 3           Tomada de Contas Especial
# 4                       Representação

# %%
df.shape
# Out:
# (13285, 12)

# %%
from sklearn.preprocessing import LabelBinarizer

areas = df.groupby(['DESCR_AREA']).groups.keys()
lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
y = lbArea.transform(df['DESCR_AREA'])
y.shape
# Out:
# (13285, 10)

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

vocabulario = 70000
limite_texto = 2000
dim_vetor = 100

tokenizer = Tokenizer(num_words=vocabulario)
tokenizer.fit_on_texts(df['TEXTO_EXCERTO'])

sequences = tokenizer.texts_to_sequences(df['TEXTO_EXCERTO'])

word_index = tokenizer.word_index
vocabulario = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))
# Out:
# Using TensorFlow backend.
# Found 63925 unique tokens.

# %%
from keras.preprocessing.sequence import pad_sequences

x = pad_sequences(sequences, maxlen=limite_texto)

print('Shape of data tensor:', x.shape)
# Out:
# Shape of data tensor: (13285, 2000)

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format('../externos/model.txt')
# Out:
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# create a weight matrix for words in training docs

embedding_matrix = np.zeros((vocabulario, dim_vetor))

ok = 0
for word, i in tokenizer.word_index.items():
    if word in model:
        embedding_matrix[i] = model[word]
        ok += 1
print('Vocabulario:', i)
print('Encontrados no modelo:', ok, '=', ok * 100. / i)
# Out:
# Vocabulario: 63925
# Encontrados no modelo: 42309 = 66.18537348455222

# %%
x.shape, y.shape
# Out:
# ((13285, 2000), (13285, 10))

# %% [markdown]
# # Treinamento

# %%
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, GlobalMaxPooling1D
from keras.optimizers import RMSprop

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=False))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1201 00:55:20.977986 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1201 00:55:21.128664 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1201 00:55:21.130525 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1201 00:55:21.140298 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1201 00:55:21.141090 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1201 00:55:22.237171 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W1201 00:55:22.280371 140632674797376 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1201 00:55:22.374485 140632674797376 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 392, 32)           7200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 6,422,562
# Trainable params: 29,962
# Non-trainable params: 6,392,600
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 4s 401us/step - loss: 1.5350 - categorical_accuracy: 0.4904 - val_loss: 1.5870 - val_categorical_accuracy: 0.4885
# Epoch 2/20
# 10628/10628 [==============================] - 3s 246us/step - loss: 1.0499 - categorical_accuracy: 0.6563 - val_loss: 1.3792 - val_categorical_accuracy: 0.5280
# Epoch 3/20
# 10628/10628 [==============================] - 3s 251us/step - loss: 0.8606 - categorical_accuracy: 0.7095 - val_loss: 1.5233 - val_categorical_accuracy: 0.4784
# Epoch 4/20
# 10628/10628 [==============================] - 3s 266us/step - loss: 0.7467 - categorical_accuracy: 0.7488 - val_loss: 1.7878 - val_categorical_accuracy: 0.4513
# Epoch 5/20
# 10628/10628 [==============================] - 3s 242us/step - loss: 0.6489 - categorical_accuracy: 0.7826 - val_loss: 1.1560 - val_categorical_accuracy: 0.5950
# Epoch 6/20
# 10628/10628 [==============================] - 3s 243us/step - loss: 0.5761 - categorical_accuracy: 0.8084 - val_loss: 1.6983 - val_categorical_accuracy: 0.5231
# Epoch 7/20
# 10628/10628 [==============================] - 3s 273us/step - loss: 0.5033 - categorical_accuracy: 0.8312 - val_loss: 1.3831 - val_categorical_accuracy: 0.5890
# Epoch 8/20
# 10628/10628 [==============================] - 3s 250us/step - loss: 0.4437 - categorical_accuracy: 0.8518 - val_loss: 1.5720 - val_categorical_accuracy: 0.5687
# Epoch 9/20
# 10628/10628 [==============================] - 3s 253us/step - loss: 0.3889 - categorical_accuracy: 0.8700 - val_loss: 1.4748 - val_categorical_accuracy: 0.5849
# Epoch 10/20
# 10628/10628 [==============================] - 3s 260us/step - loss: 0.3438 - categorical_accuracy: 0.8847 - val_loss: 1.3965 - val_categorical_accuracy: 0.6251
# Epoch 11/20
# 10628/10628 [==============================] - 3s 262us/step - loss: 0.2930 - categorical_accuracy: 0.9025 - val_loss: 1.4586 - val_categorical_accuracy: 0.6293
# Epoch 12/20
# 10628/10628 [==============================] - 3s 255us/step - loss: 0.2579 - categorical_accuracy: 0.9161 - val_loss: 1.1837 - val_categorical_accuracy: 0.6688
# Epoch 13/20
# 10628/10628 [==============================] - 3s 277us/step - loss: 0.2252 - categorical_accuracy: 0.9254 - val_loss: 1.6861 - val_categorical_accuracy: 0.5837
# Epoch 14/20
# 10628/10628 [==============================] - 3s 249us/step - loss: 0.1971 - categorical_accuracy: 0.9385 - val_loss: 1.5423 - val_categorical_accuracy: 0.6146
# Epoch 15/20
# 10628/10628 [==============================] - 3s 254us/step - loss: 0.1693 - categorical_accuracy: 0.9479 - val_loss: 1.3796 - val_categorical_accuracy: 0.6451
# Epoch 16/20
# 10628/10628 [==============================] - 3s 268us/step - loss: 0.1490 - categorical_accuracy: 0.9540 - val_loss: 1.4293 - val_categorical_accuracy: 0.6394
# Epoch 17/20
# 10628/10628 [==============================] - 3s 247us/step - loss: 0.1332 - categorical_accuracy: 0.9598 - val_loss: 1.3919 - val_categorical_accuracy: 0.6688
# Epoch 18/20
# 10628/10628 [==============================] - 3s 253us/step - loss: 0.1170 - categorical_accuracy: 0.9674 - val_loss: 1.4751 - val_categorical_accuracy: 0.6654
# Epoch 19/20
# 10628/10628 [==============================] - 3s 273us/step - loss: 0.1072 - categorical_accuracy: 0.9674 - val_loss: 1.8506 - val_categorical_accuracy: 0.6150
# Epoch 20/20
# 10628/10628 [==============================] - 3s 250us/step - loss: 0.0917 - categorical_accuracy: 0.9756 - val_loss: 1.5945 - val_categorical_accuracy: 0.6575

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 392, 32)           7200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 6,422,562
# Trainable params: 6,422,562
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 6s 543us/step - loss: 1.5301 - categorical_accuracy: 0.5060 - val_loss: 1.3623 - val_categorical_accuracy: 0.5615
# Epoch 2/20
# 10628/10628 [==============================] - 5s 507us/step - loss: 0.9547 - categorical_accuracy: 0.6827 - val_loss: 1.2507 - val_categorical_accuracy: 0.5830
# Epoch 3/20
# 10628/10628 [==============================] - 6s 518us/step - loss: 0.7211 - categorical_accuracy: 0.7545 - val_loss: 2.2134 - val_categorical_accuracy: 0.4196
# Epoch 4/20
# 10628/10628 [==============================] - 5s 512us/step - loss: 0.5560 - categorical_accuracy: 0.8196 - val_loss: 1.0402 - val_categorical_accuracy: 0.6711
# Epoch 5/20
# 10628/10628 [==============================] - 5s 512us/step - loss: 0.4137 - categorical_accuracy: 0.8639 - val_loss: 1.1902 - val_categorical_accuracy: 0.6123
# Epoch 6/20
# 10628/10628 [==============================] - 5s 514us/step - loss: 0.2989 - categorical_accuracy: 0.9087 - val_loss: 2.3405 - val_categorical_accuracy: 0.3805
# Epoch 7/20
# 10628/10628 [==============================] - 5s 509us/step - loss: 0.2060 - categorical_accuracy: 0.9419 - val_loss: 1.1671 - val_categorical_accuracy: 0.6741
# Epoch 8/20
# 10628/10628 [==============================] - 5s 505us/step - loss: 0.1364 - categorical_accuracy: 0.9643 - val_loss: 1.1871 - val_categorical_accuracy: 0.6748
# Epoch 9/20
# 10628/10628 [==============================] - 6s 520us/step - loss: 0.0901 - categorical_accuracy: 0.9786 - val_loss: 1.6381 - val_categorical_accuracy: 0.5920
# Epoch 10/20
# 10628/10628 [==============================] - 6s 534us/step - loss: 0.0628 - categorical_accuracy: 0.9864 - val_loss: 1.4715 - val_categorical_accuracy: 0.6323
# Epoch 11/20
# 10628/10628 [==============================] - 6s 522us/step - loss: 0.0558 - categorical_accuracy: 0.9877 - val_loss: 1.4264 - val_categorical_accuracy: 0.6526
# Epoch 12/20
# 10628/10628 [==============================] - 6s 520us/step - loss: 0.0457 - categorical_accuracy: 0.9902 - val_loss: 1.6653 - val_categorical_accuracy: 0.6496
# Epoch 13/20
# 10628/10628 [==============================] - 6s 523us/step - loss: 0.0461 - categorical_accuracy: 0.9905 - val_loss: 1.7831 - val_categorical_accuracy: 0.6428
# Epoch 14/20
# 10628/10628 [==============================] - 5s 517us/step - loss: 0.0452 - categorical_accuracy: 0.9902 - val_loss: 1.3816 - val_categorical_accuracy: 0.7064
# Epoch 15/20
# 10628/10628 [==============================] - 5s 504us/step - loss: 0.0442 - categorical_accuracy: 0.9912 - val_loss: 1.8056 - val_categorical_accuracy: 0.6635
# Epoch 16/20
# 10628/10628 [==============================] - 6s 520us/step - loss: 0.0430 - categorical_accuracy: 0.9912 - val_loss: 1.4638 - val_categorical_accuracy: 0.6963
# Epoch 17/20
# 10628/10628 [==============================] - 6s 521us/step - loss: 0.0402 - categorical_accuracy: 0.9932 - val_loss: 1.5396 - val_categorical_accuracy: 0.6744
# Epoch 18/20
# 10628/10628 [==============================] - 5s 517us/step - loss: 0.0418 - categorical_accuracy: 0.9921 - val_loss: 1.4892 - val_categorical_accuracy: 0.6936
# Epoch 19/20
# 10628/10628 [==============================] - 5s 516us/step - loss: 0.0351 - categorical_accuracy: 0.9934 - val_loss: 1.7166 - val_categorical_accuracy: 0.6891
# Epoch 20/20
# 10628/10628 [==============================] - 5s 516us/step - loss: 0.0440 - categorical_accuracy: 0.9928 - val_loss: 1.4952 - val_categorical_accuracy: 0.7061

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=5e-3),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 392, 32)           7200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# =================================================================
# Total params: 6,422,562
# Trainable params: 6,422,562
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 6s 564us/step - loss: 1.3441 - categorical_accuracy: 0.5543 - val_loss: 1.2893 - val_categorical_accuracy: 0.5905
# Epoch 2/20
# 10628/10628 [==============================] - 5s 509us/step - loss: 0.8061 - categorical_accuracy: 0.7368 - val_loss: 1.4710 - val_categorical_accuracy: 0.5141
# Epoch 3/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.5702 - categorical_accuracy: 0.8147 - val_loss: 1.1371 - val_categorical_accuracy: 0.6872
# Epoch 4/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.3936 - categorical_accuracy: 0.8721 - val_loss: 2.1497 - val_categorical_accuracy: 0.5209
# Epoch 5/20
# 10628/10628 [==============================] - 6s 523us/step - loss: 0.2510 - categorical_accuracy: 0.9222 - val_loss: 1.6498 - val_categorical_accuracy: 0.6519
# Epoch 6/20
# 10628/10628 [==============================] - 5s 511us/step - loss: 0.1734 - categorical_accuracy: 0.9515 - val_loss: 1.7925 - val_categorical_accuracy: 0.6586
# Epoch 7/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.1328 - categorical_accuracy: 0.9670 - val_loss: 2.1194 - val_categorical_accuracy: 0.6507
# Epoch 8/20
# 10628/10628 [==============================] - 5s 512us/step - loss: 0.1248 - categorical_accuracy: 0.9718 - val_loss: 2.0720 - val_categorical_accuracy: 0.6782
# Epoch 9/20
# 10628/10628 [==============================] - 5s 516us/step - loss: 0.1116 - categorical_accuracy: 0.9788 - val_loss: 2.3094 - val_categorical_accuracy: 0.6729
# Epoch 10/20
# 10628/10628 [==============================] - 6s 527us/step - loss: 0.1102 - categorical_accuracy: 0.9803 - val_loss: 2.5721 - val_categorical_accuracy: 0.6786
# Epoch 11/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.1071 - categorical_accuracy: 0.9811 - val_loss: 2.4323 - val_categorical_accuracy: 0.7087
# Epoch 12/20
# 10628/10628 [==============================] - 6s 530us/step - loss: 0.0954 - categorical_accuracy: 0.9852 - val_loss: 4.4968 - val_categorical_accuracy: 0.5224
# Epoch 13/20
# 10628/10628 [==============================] - 6s 527us/step - loss: 0.1022 - categorical_accuracy: 0.9848 - val_loss: 2.6693 - val_categorical_accuracy: 0.6899
# Epoch 14/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.1079 - categorical_accuracy: 0.9862 - val_loss: 3.6146 - val_categorical_accuracy: 0.6297
# Epoch 15/20
# 10628/10628 [==============================] - 6s 519us/step - loss: 0.1015 - categorical_accuracy: 0.9873 - val_loss: 3.0993 - val_categorical_accuracy: 0.6793
# Epoch 16/20
# 10628/10628 [==============================] - 6s 521us/step - loss: 0.0971 - categorical_accuracy: 0.9870 - val_loss: 3.2035 - val_categorical_accuracy: 0.6823
# Epoch 17/20
# 10628/10628 [==============================] - 6s 535us/step - loss: 0.0960 - categorical_accuracy: 0.9869 - val_loss: 3.3211 - val_categorical_accuracy: 0.6665
# Epoch 18/20
# 10628/10628 [==============================] - 6s 521us/step - loss: 0.0941 - categorical_accuracy: 0.9875 - val_loss: 3.5404 - val_categorical_accuracy: 0.6741
# Epoch 19/20
# 10628/10628 [==============================] - 6s 534us/step - loss: 0.0925 - categorical_accuracy: 0.9898 - val_loss: 4.1804 - val_categorical_accuracy: 0.6304
# Epoch 20/20
# 10628/10628 [==============================] - 6s 529us/step - loss: 0.0917 - categorical_accuracy: 0.9895 - val_loss: 3.7607 - val_categorical_accuracy: 0.6605

# %%
from keras.layers import GRU

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# W1201 01:00:16.681195 140632674797376 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 392, 32)           7200
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               221952
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,646,754
# Trainable params: 6,646,754
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 188s 18ms/step - loss: 1.5697 - categorical_accuracy: 0.4578 - val_loss: 1.3172 - val_categorical_accuracy: 0.5371
# Epoch 2/20
# 10628/10628 [==============================] - 188s 18ms/step - loss: 1.0281 - categorical_accuracy: 0.6620 - val_loss: 1.3281 - val_categorical_accuracy: 0.5630
# Epoch 3/20
# 10628/10628 [==============================] - 185s 17ms/step - loss: 0.8191 - categorical_accuracy: 0.7274 - val_loss: 1.1219 - val_categorical_accuracy: 0.6470
# Epoch 4/20
# 10628/10628 [==============================] - 189s 18ms/step - loss: 0.6727 - categorical_accuracy: 0.7778 - val_loss: 1.1337 - val_categorical_accuracy: 0.6251
# Epoch 5/20
# 10628/10628 [==============================] - 194s 18ms/step - loss: 0.5644 - categorical_accuracy: 0.8129 - val_loss: 1.0093 - val_categorical_accuracy: 0.6839
# Epoch 6/20
# 10628/10628 [==============================] - 185s 17ms/step - loss: 0.4690 - categorical_accuracy: 0.8463 - val_loss: 1.0732 - val_categorical_accuracy: 0.6692
# Epoch 7/20
# 10628/10628 [==============================] - 184s 17ms/step - loss: 0.3755 - categorical_accuracy: 0.8733 - val_loss: 1.1479 - val_categorical_accuracy: 0.6496
# Epoch 8/20
# 10628/10628 [==============================] - 188s 18ms/step - loss: 0.3011 - categorical_accuracy: 0.8978 - val_loss: 1.1268 - val_categorical_accuracy: 0.6854
# Epoch 9/20
# 10628/10628 [==============================] - 186s 17ms/step - loss: 0.2408 - categorical_accuracy: 0.9199 - val_loss: 1.5449 - val_categorical_accuracy: 0.5995
# Epoch 10/20
# 10628/10628 [==============================] - 180s 17ms/step - loss: 0.1866 - categorical_accuracy: 0.9377 - val_loss: 1.1081 - val_categorical_accuracy: 0.6970
# Epoch 11/20
# 10628/10628 [==============================] - 189s 18ms/step - loss: 0.1508 - categorical_accuracy: 0.9500 - val_loss: 1.2981 - val_categorical_accuracy: 0.6929
# Epoch 12/20
# 10628/10628 [==============================] - 180s 17ms/step - loss: 0.1270 - categorical_accuracy: 0.9597 - val_loss: 1.5986 - val_categorical_accuracy: 0.6052
# Epoch 13/20
# 10628/10628 [==============================] - 191s 18ms/step - loss: 0.0997 - categorical_accuracy: 0.9696 - val_loss: 1.5570 - val_categorical_accuracy: 0.6722
# Epoch 14/20
# 10628/10628 [==============================] - 212s 20ms/step - loss: 0.0907 - categorical_accuracy: 0.9717 - val_loss: 1.2614 - val_categorical_accuracy: 0.7204
# Epoch 15/20
# 10628/10628 [==============================] - 189s 18ms/step - loss: 0.0716 - categorical_accuracy: 0.9783 - val_loss: 1.3837 - val_categorical_accuracy: 0.7181
# Epoch 16/20
# 10628/10628 [==============================] - 157s 15ms/step - loss: 0.0651 - categorical_accuracy: 0.9792 - val_loss: 1.4098 - val_categorical_accuracy: 0.7117
# Epoch 17/20
# 10628/10628 [==============================] - 156s 15ms/step - loss: 0.0647 - categorical_accuracy: 0.9804 - val_loss: 1.7400 - val_categorical_accuracy: 0.6571
# Epoch 18/20
# 10628/10628 [==============================] - 157s 15ms/step - loss: 0.0517 - categorical_accuracy: 0.9849 - val_loss: 1.5199 - val_categorical_accuracy: 0.7170
# Epoch 19/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0546 - categorical_accuracy: 0.9848 - val_loss: 1.5379 - val_categorical_accuracy: 0.7125
# Epoch 20/20
# 10628/10628 [==============================] - 157s 15ms/step - loss: 0.0481 - categorical_accuracy: 0.9857 - val_loss: 1.6131 - val_categorical_accuracy: 0.7102

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(64, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1994, 64)          44864
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 398, 64)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 392, 32)           14368
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 6,452,162
# Trainable params: 6,452,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 7s 650us/step - loss: 1.4380 - categorical_accuracy: 0.5263 - val_loss: 1.8957 - val_categorical_accuracy: 0.3974
# Epoch 2/20
# 10628/10628 [==============================] - 6s 592us/step - loss: 0.9091 - categorical_accuracy: 0.6953 - val_loss: 1.1940 - val_categorical_accuracy: 0.5935
# Epoch 3/20
# 10628/10628 [==============================] - 6s 602us/step - loss: 0.6706 - categorical_accuracy: 0.7782 - val_loss: 1.6799 - val_categorical_accuracy: 0.4471
# Epoch 4/20
# 10628/10628 [==============================] - 6s 591us/step - loss: 0.4969 - categorical_accuracy: 0.8373 - val_loss: 1.7709 - val_categorical_accuracy: 0.5834
# Epoch 5/20
# 10628/10628 [==============================] - 6s 589us/step - loss: 0.3491 - categorical_accuracy: 0.8884 - val_loss: 1.6407 - val_categorical_accuracy: 0.5085
# Epoch 6/20
# 10628/10628 [==============================] - 6s 594us/step - loss: 0.2315 - categorical_accuracy: 0.9313 - val_loss: 2.1856 - val_categorical_accuracy: 0.3673
# Epoch 7/20
# 10628/10628 [==============================] - 6s 597us/step - loss: 0.1544 - categorical_accuracy: 0.9562 - val_loss: 1.6669 - val_categorical_accuracy: 0.5871
# Epoch 8/20
# 10628/10628 [==============================] - 6s 598us/step - loss: 0.1006 - categorical_accuracy: 0.9757 - val_loss: 1.5642 - val_categorical_accuracy: 0.6413
# Epoch 9/20
# 10628/10628 [==============================] - 6s 590us/step - loss: 0.0750 - categorical_accuracy: 0.9830 - val_loss: 1.4543 - val_categorical_accuracy: 0.6458
# Epoch 10/20
# 10628/10628 [==============================] - 6s 588us/step - loss: 0.0613 - categorical_accuracy: 0.9871 - val_loss: 1.6216 - val_categorical_accuracy: 0.6406
# Epoch 11/20
# 10628/10628 [==============================] - 6s 590us/step - loss: 0.0637 - categorical_accuracy: 0.9875 - val_loss: 1.4350 - val_categorical_accuracy: 0.6914
# Epoch 12/20
# 10628/10628 [==============================] - 6s 601us/step - loss: 0.0549 - categorical_accuracy: 0.9885 - val_loss: 1.4712 - val_categorical_accuracy: 0.6797
# Epoch 13/20
# 10628/10628 [==============================] - 6s 592us/step - loss: 0.0529 - categorical_accuracy: 0.9902 - val_loss: 1.3906 - val_categorical_accuracy: 0.6865
# Epoch 14/20
# 10628/10628 [==============================] - 6s 585us/step - loss: 0.0542 - categorical_accuracy: 0.9890 - val_loss: 1.4357 - val_categorical_accuracy: 0.6891
# Epoch 15/20
# 10628/10628 [==============================] - 6s 590us/step - loss: 0.0534 - categorical_accuracy: 0.9908 - val_loss: 2.0875 - val_categorical_accuracy: 0.6808
# Epoch 16/20
# 10628/10628 [==============================] - 6s 593us/step - loss: 0.0564 - categorical_accuracy: 0.9906 - val_loss: 1.3720 - val_categorical_accuracy: 0.7053
# Epoch 17/20
# 10628/10628 [==============================] - 6s 597us/step - loss: 0.0530 - categorical_accuracy: 0.9918 - val_loss: 1.5188 - val_categorical_accuracy: 0.6865
# Epoch 18/20
# 10628/10628 [==============================] - 6s 588us/step - loss: 0.0541 - categorical_accuracy: 0.9919 - val_loss: 1.4691 - val_categorical_accuracy: 0.7061
# Epoch 19/20
# 10628/10628 [==============================] - 6s 590us/step - loss: 0.0536 - categorical_accuracy: 0.9925 - val_loss: 1.4550 - val_categorical_accuracy: 0.6872
# Epoch 20/20
# 10628/10628 [==============================] - 6s 596us/step - loss: 0.0524 - categorical_accuracy: 0.9921 - val_loss: 1.7985 - val_categorical_accuracy: 0.6297

# %%
from keras.layers import Flatten
from keras.layers.core import Dropout

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12736)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               3260672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 9,678,274
# Trainable params: 9,678,274
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 7s 628us/step - loss: 1.4336 - categorical_accuracy: 0.5358 - val_loss: 1.4502 - val_categorical_accuracy: 0.5438
# Epoch 2/20
# 10628/10628 [==============================] - 6s 556us/step - loss: 0.7374 - categorical_accuracy: 0.7566 - val_loss: 1.2995 - val_categorical_accuracy: 0.5962
# Epoch 3/20
# 10628/10628 [==============================] - 6s 554us/step - loss: 0.4160 - categorical_accuracy: 0.8650 - val_loss: 1.5207 - val_categorical_accuracy: 0.6022
# Epoch 4/20
# 10628/10628 [==============================] - 6s 552us/step - loss: 0.2130 - categorical_accuracy: 0.9346 - val_loss: 1.9007 - val_categorical_accuracy: 0.5849
# Epoch 5/20
# 10628/10628 [==============================] - 6s 561us/step - loss: 0.1230 - categorical_accuracy: 0.9684 - val_loss: 2.2696 - val_categorical_accuracy: 0.6097
# Epoch 6/20
# 10628/10628 [==============================] - 6s 556us/step - loss: 0.0815 - categorical_accuracy: 0.9822 - val_loss: 3.0336 - val_categorical_accuracy: 0.5875
# Epoch 7/20
# 10628/10628 [==============================] - 6s 550us/step - loss: 0.0761 - categorical_accuracy: 0.9862 - val_loss: 3.0541 - val_categorical_accuracy: 0.6052
# Epoch 8/20
# 10628/10628 [==============================] - 6s 555us/step - loss: 0.0649 - categorical_accuracy: 0.9883 - val_loss: 3.2110 - val_categorical_accuracy: 0.6251
# Epoch 9/20
# 10628/10628 [==============================] - 6s 555us/step - loss: 0.0568 - categorical_accuracy: 0.9907 - val_loss: 3.5155 - val_categorical_accuracy: 0.5841
# Epoch 10/20
# 10628/10628 [==============================] - 6s 553us/step - loss: 0.0570 - categorical_accuracy: 0.9906 - val_loss: 3.3364 - val_categorical_accuracy: 0.6191
# Epoch 11/20
# 10628/10628 [==============================] - 6s 551us/step - loss: 0.0543 - categorical_accuracy: 0.9915 - val_loss: 3.2046 - val_categorical_accuracy: 0.5958
# Epoch 12/20
# 10628/10628 [==============================] - 6s 558us/step - loss: 0.0469 - categorical_accuracy: 0.9923 - val_loss: 3.5124 - val_categorical_accuracy: 0.6176
# Epoch 13/20
# 10628/10628 [==============================] - 6s 558us/step - loss: 0.0455 - categorical_accuracy: 0.9925 - val_loss: 3.5095 - val_categorical_accuracy: 0.6172
# Epoch 14/20
# 10628/10628 [==============================] - 6s 553us/step - loss: 0.0477 - categorical_accuracy: 0.9920 - val_loss: 3.6552 - val_categorical_accuracy: 0.5980
# Epoch 15/20
# 10628/10628 [==============================] - 6s 560us/step - loss: 0.0376 - categorical_accuracy: 0.9932 - val_loss: 4.6857 - val_categorical_accuracy: 0.5510
# Epoch 16/20
# 10628/10628 [==============================] - 6s 553us/step - loss: 0.0404 - categorical_accuracy: 0.9932 - val_loss: 4.0022 - val_categorical_accuracy: 0.5826
# Epoch 17/20
# 10628/10628 [==============================] - 6s 552us/step - loss: 0.0372 - categorical_accuracy: 0.9930 - val_loss: 4.0991 - val_categorical_accuracy: 0.5804
# Epoch 18/20
# 10628/10628 [==============================] - 6s 554us/step - loss: 0.0359 - categorical_accuracy: 0.9928 - val_loss: 4.0258 - val_categorical_accuracy: 0.6101
# Epoch 19/20
# 10628/10628 [==============================] - 6s 560us/step - loss: 0.0374 - categorical_accuracy: 0.9936 - val_loss: 3.7370 - val_categorical_accuracy: 0.6093
# Epoch 20/20
# 10628/10628 [==============================] - 6s 555us/step - loss: 0.0327 - categorical_accuracy: 0.9928 - val_loss: 4.2364 - val_categorical_accuracy: 0.5995

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(32, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 1994, 32)          22432
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 398, 32)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 392, 32)           7200
# _________________________________________________________________
# gru_2 (GRU)                  (None, 128)               61824
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 6,485,346
# Trainable params: 6,485,346
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 156s 15ms/step - loss: 1.5114 - categorical_accuracy: 0.4905 - val_loss: 1.4043 - val_categorical_accuracy: 0.5036
# Epoch 2/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 1.0224 - categorical_accuracy: 0.6578 - val_loss: 1.4176 - val_categorical_accuracy: 0.5446
# Epoch 3/20
# 10628/10628 [==============================] - 154s 14ms/step - loss: 0.8271 - categorical_accuracy: 0.7208 - val_loss: 1.4044 - val_categorical_accuracy: 0.5694
# Epoch 4/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.7030 - categorical_accuracy: 0.7642 - val_loss: 1.1916 - val_categorical_accuracy: 0.5920
# Epoch 5/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.5899 - categorical_accuracy: 0.8021 - val_loss: 0.9636 - val_categorical_accuracy: 0.6906
# Epoch 6/20
# 10628/10628 [==============================] - 154s 14ms/step - loss: 0.4958 - categorical_accuracy: 0.8336 - val_loss: 1.1391 - val_categorical_accuracy: 0.6846
# Epoch 7/20
# 10628/10628 [==============================] - 154s 14ms/step - loss: 0.4107 - categorical_accuracy: 0.8641 - val_loss: 1.0560 - val_categorical_accuracy: 0.6869
# Epoch 8/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.3311 - categorical_accuracy: 0.8875 - val_loss: 1.5623 - val_categorical_accuracy: 0.6108
# Epoch 9/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.2672 - categorical_accuracy: 0.9120 - val_loss: 1.1558 - val_categorical_accuracy: 0.6910
# Epoch 10/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.2089 - categorical_accuracy: 0.9317 - val_loss: 1.3484 - val_categorical_accuracy: 0.6522
# Epoch 11/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.1727 - categorical_accuracy: 0.9450 - val_loss: 1.5944 - val_categorical_accuracy: 0.6270
# Epoch 12/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.1371 - categorical_accuracy: 0.9550 - val_loss: 1.2759 - val_categorical_accuracy: 0.6899
# Epoch 13/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.1079 - categorical_accuracy: 0.9671 - val_loss: 1.2454 - val_categorical_accuracy: 0.7132
# Epoch 14/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.0899 - categorical_accuracy: 0.9724 - val_loss: 1.3908 - val_categorical_accuracy: 0.7027
# Epoch 15/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.0819 - categorical_accuracy: 0.9736 - val_loss: 1.4425 - val_categorical_accuracy: 0.6970
# Epoch 16/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.0646 - categorical_accuracy: 0.9796 - val_loss: 1.5597 - val_categorical_accuracy: 0.6782
# Epoch 17/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0635 - categorical_accuracy: 0.9802 - val_loss: 1.3878 - val_categorical_accuracy: 0.7087
# Epoch 18/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.0537 - categorical_accuracy: 0.9842 - val_loss: 1.5679 - val_categorical_accuracy: 0.6970
# Epoch 19/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0504 - categorical_accuracy: 0.9852 - val_loss: 1.5438 - val_categorical_accuracy: 0.7110
# Epoch 20/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.0521 - categorical_accuracy: 0.9852 - val_loss: 1.5476 - val_categorical_accuracy: 0.6940

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Conv1D(64, 7, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Conv1D(32, 7, activation='relu'))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()
history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 2000, 100)         6392600
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 1994, 64)          44864
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 398, 64)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 392, 32)           14368
# _________________________________________________________________
# gru_3 (GRU)                  (None, 256)               221952
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,676,354
# Trainable params: 6,676,354
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 156s 15ms/step - loss: 1.4704 - categorical_accuracy: 0.5085 - val_loss: 1.1737 - val_categorical_accuracy: 0.6169
# Epoch 2/20
# 10628/10628 [==============================] - 156s 15ms/step - loss: 0.9861 - categorical_accuracy: 0.6643 - val_loss: 1.4141 - val_categorical_accuracy: 0.5427
# Epoch 3/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.7887 - categorical_accuracy: 0.7346 - val_loss: 1.2908 - val_categorical_accuracy: 0.6048
# Epoch 4/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.6511 - categorical_accuracy: 0.7803 - val_loss: 0.8812 - val_categorical_accuracy: 0.7151
# Epoch 5/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.5329 - categorical_accuracy: 0.8234 - val_loss: 1.1967 - val_categorical_accuracy: 0.6244
# Epoch 6/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.4266 - categorical_accuracy: 0.8615 - val_loss: 1.3622 - val_categorical_accuracy: 0.6361
# Epoch 7/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.3427 - categorical_accuracy: 0.8875 - val_loss: 1.0119 - val_categorical_accuracy: 0.7094
# Epoch 8/20
# 10628/10628 [==============================] - 154s 15ms/step - loss: 0.2529 - categorical_accuracy: 0.9161 - val_loss: 1.2107 - val_categorical_accuracy: 0.6673
# Epoch 9/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.1935 - categorical_accuracy: 0.9396 - val_loss: 1.3552 - val_categorical_accuracy: 0.6744
# Epoch 10/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.1511 - categorical_accuracy: 0.9536 - val_loss: 1.2768 - val_categorical_accuracy: 0.6865
# Epoch 11/20
# 10628/10628 [==============================] - 153s 14ms/step - loss: 0.1200 - categorical_accuracy: 0.9630 - val_loss: 1.7422 - val_categorical_accuracy: 0.6266
# Epoch 12/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0981 - categorical_accuracy: 0.9695 - val_loss: 1.4605 - val_categorical_accuracy: 0.6839
# Epoch 13/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0857 - categorical_accuracy: 0.9734 - val_loss: 1.5513 - val_categorical_accuracy: 0.6910
# Epoch 14/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0719 - categorical_accuracy: 0.9799 - val_loss: 1.4411 - val_categorical_accuracy: 0.7155
# Epoch 15/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0624 - categorical_accuracy: 0.9805 - val_loss: 1.4027 - val_categorical_accuracy: 0.7166
# Epoch 16/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0654 - categorical_accuracy: 0.9811 - val_loss: 1.6503 - val_categorical_accuracy: 0.6876
# Epoch 17/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0528 - categorical_accuracy: 0.9849 - val_loss: 1.9674 - val_categorical_accuracy: 0.6458
# Epoch 18/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0444 - categorical_accuracy: 0.9871 - val_loss: 1.7677 - val_categorical_accuracy: 0.6726
# Epoch 19/20
# 10628/10628 [==============================] - 154s 14ms/step - loss: 0.0715 - categorical_accuracy: 0.9794 - val_loss: 2.2689 - val_categorical_accuracy: 0.6327
# Epoch 20/20
# 10628/10628 [==============================] - 155s 15ms/step - loss: 0.0490 - categorical_accuracy: 0.9854 - val_loss: 1.9353 - val_categorical_accuracy: 0.6500
