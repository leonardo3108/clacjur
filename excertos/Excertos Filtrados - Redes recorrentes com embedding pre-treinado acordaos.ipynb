# %% [markdown]
# # Importação e preparação dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/excertos_filtrados500.csv', sep = '|')
df.head()
# Out:
#     COD          DESCR_AREA                                           filtrado
# 0  1400    Responsabilidade  voto cuidar auto tomada conta especial instaur...
# 1  1700   Finanças Públicas  voto cuidar auto solicitação congresso naciona...
# 2  5700    Responsabilidade  relatório tratar embargo declaração opor exemp...
# 3   284  Direito Processual  voto relação outro processo judiciais tratar r...
# 4   298             Pessoal  voto relativo ato envolver senhor caber rememo...

# %%
df.shape
# Out:
# (13285, 3)

# %%
from sklearn.preprocessing import LabelBinarizer

areas = df.groupby(['DESCR_AREA']).groups.keys()
lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
y = lbArea.transform(df['DESCR_AREA'])
y.shape
# Out:
# (13285, 10)

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

vocabulario = 30000
limite_texto = 500
dim_vetor = 100

tokenizer = Tokenizer(num_words=vocabulario)
tokenizer.fit_on_texts(df['filtrado'].astype(str))

sequences = tokenizer.texts_to_sequences(df['filtrado'].astype(str))

word_index = tokenizer.word_index
vocabulario = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))
# Out:
# Using TensorFlow backend.
# Found 22972 unique tokens.

# %%
from keras.preprocessing.sequence import pad_sequences

x = pad_sequences(sequences, maxlen=limite_texto)

print('Shape of data tensor:', x.shape)
# Out:
# Shape of data tensor: (13285, 500)

# %%
from gensim.models import Word2Vec

model = Word2Vec.load('../vocabularios/modelo-acordaos.w2v')
# Out:
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# create a weight matrix for words in training docs

embedding_matrix = np.zeros((vocabulario, dim_vetor))

ok = 0
for word, i in tokenizer.word_index.items():
    if word in model:
        embedding_matrix[i] = model[word]
        ok += 1
print('Vocabulario:', i)
print('Encontrados no modelo:', ok, '=', ok * 100. / i)
# Out:
# Vocabulario: 22972
# Encontrados no modelo: 18860 = 82.09994776249347
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   import sys
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# # Treinamento

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, GRU, LSTM, Bidirectional
from keras.optimizers import RMSprop
from keras.layers.core import Dropout

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=False))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1127 13:58:04.142743 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1127 13:58:04.210463 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1127 13:58:04.212082 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1127 13:58:04.219673 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1127 13:58:04.220424 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1127 13:58:04.975976 140001869367104 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W1127 13:58:05.177587 140001869367104 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1127 13:58:05.275929 140001869367104 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 2,574,046
# Trainable params: 276,746
# Non-trainable params: 2,297,300
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 149s 14ms/step - loss: 1.1763 - categorical_accuracy: 0.6073 - val_loss: 0.9573 - val_categorical_accuracy: 0.6854
# Epoch 2/20
# 10628/10628 [==============================] - 146s 14ms/step - loss: 0.6897 - categorical_accuracy: 0.7637 - val_loss: 0.8724 - val_categorical_accuracy: 0.6933
# Epoch 3/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.5464 - categorical_accuracy: 0.8159 - val_loss: 0.7486 - val_categorical_accuracy: 0.7524
# Epoch 4/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.4659 - categorical_accuracy: 0.8387 - val_loss: 0.7280 - val_categorical_accuracy: 0.7614
# Epoch 5/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.4105 - categorical_accuracy: 0.8602 - val_loss: 0.7920 - val_categorical_accuracy: 0.7448
# Epoch 6/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.3657 - categorical_accuracy: 0.8763 - val_loss: 0.7361 - val_categorical_accuracy: 0.7621
# Epoch 7/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.3255 - categorical_accuracy: 0.8864 - val_loss: 0.7876 - val_categorical_accuracy: 0.7591
# Epoch 8/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.2975 - categorical_accuracy: 0.8994 - val_loss: 0.8004 - val_categorical_accuracy: 0.7426
# Epoch 9/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.2703 - categorical_accuracy: 0.9060 - val_loss: 0.8250 - val_categorical_accuracy: 0.7373
# Epoch 10/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.2590 - categorical_accuracy: 0.9075 - val_loss: 0.8025 - val_categorical_accuracy: 0.7546
# Epoch 11/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.2272 - categorical_accuracy: 0.9182 - val_loss: 0.7791 - val_categorical_accuracy: 0.7753
# Epoch 12/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.2090 - categorical_accuracy: 0.9260 - val_loss: 0.8707 - val_categorical_accuracy: 0.7411
# Epoch 13/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1931 - categorical_accuracy: 0.9321 - val_loss: 0.9287 - val_categorical_accuracy: 0.7294
# Epoch 14/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1777 - categorical_accuracy: 0.9393 - val_loss: 0.8280 - val_categorical_accuracy: 0.7768
# Epoch 15/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1649 - categorical_accuracy: 0.9425 - val_loss: 0.9131 - val_categorical_accuracy: 0.7441
# Epoch 16/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1505 - categorical_accuracy: 0.9499 - val_loss: 1.0096 - val_categorical_accuracy: 0.7362
# Epoch 17/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1403 - categorical_accuracy: 0.9505 - val_loss: 0.9173 - val_categorical_accuracy: 0.7659
# Epoch 18/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1450 - categorical_accuracy: 0.9503 - val_loss: 0.9589 - val_categorical_accuracy: 0.7486
# Epoch 19/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1414 - categorical_accuracy: 0.9492 - val_loss: 0.9077 - val_categorical_accuracy: 0.7708
# Epoch 20/20
# 10628/10628 [==============================] - 144s 14ms/step - loss: 0.1265 - categorical_accuracy: 0.9536 - val_loss: 1.0135 - val_categorical_accuracy: 0.7524

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_2 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 2,588,574
# Trainable params: 2,588,574
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 1.2735 - categorical_accuracy: 0.5841 - val_loss: 1.3142 - val_categorical_accuracy: 0.5431
# Epoch 2/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.8076 - categorical_accuracy: 0.7357 - val_loss: 1.1173 - val_categorical_accuracy: 0.5860
# Epoch 3/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.6424 - categorical_accuracy: 0.7857 - val_loss: 0.8717 - val_categorical_accuracy: 0.7222
# Epoch 4/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.5473 - categorical_accuracy: 0.8180 - val_loss: 0.8511 - val_categorical_accuracy: 0.7264
# Epoch 5/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.4749 - categorical_accuracy: 0.8414 - val_loss: 0.8537 - val_categorical_accuracy: 0.7309
# Epoch 6/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.4191 - categorical_accuracy: 0.8593 - val_loss: 0.7713 - val_categorical_accuracy: 0.7490
# Epoch 7/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3734 - categorical_accuracy: 0.8737 - val_loss: 0.7685 - val_categorical_accuracy: 0.7742
# Epoch 8/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3503 - categorical_accuracy: 0.8822 - val_loss: 0.7749 - val_categorical_accuracy: 0.7727
# Epoch 9/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3077 - categorical_accuracy: 0.8957 - val_loss: 0.8493 - val_categorical_accuracy: 0.7734
# Epoch 10/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2794 - categorical_accuracy: 0.9022 - val_loss: 0.8891 - val_categorical_accuracy: 0.7486
# Epoch 11/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2551 - categorical_accuracy: 0.9113 - val_loss: 0.8751 - val_categorical_accuracy: 0.7621
# Epoch 12/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2375 - categorical_accuracy: 0.9180 - val_loss: 0.9056 - val_categorical_accuracy: 0.7527
# Epoch 13/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2126 - categorical_accuracy: 0.9264 - val_loss: 0.9603 - val_categorical_accuracy: 0.7731
# Epoch 14/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2073 - categorical_accuracy: 0.9288 - val_loss: 0.9675 - val_categorical_accuracy: 0.7644
# Epoch 15/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1916 - categorical_accuracy: 0.9343 - val_loss: 0.9904 - val_categorical_accuracy: 0.7693
# Epoch 16/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1831 - categorical_accuracy: 0.9336 - val_loss: 1.0261 - val_categorical_accuracy: 0.7810
# Epoch 17/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1806 - categorical_accuracy: 0.9367 - val_loss: 0.9771 - val_categorical_accuracy: 0.7749
# Epoch 18/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1662 - categorical_accuracy: 0.9435 - val_loss: 1.0906 - val_categorical_accuracy: 0.7644
# Epoch 19/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1601 - categorical_accuracy: 0.9458 - val_loss: 1.1323 - val_categorical_accuracy: 0.7603
# Epoch 20/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1537 - categorical_accuracy: 0.9457 - val_loss: 1.1897 - val_categorical_accuracy: 0.7610

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_3 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 2,580,030
# Trainable params: 2,580,030
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 159s 15ms/step - loss: 1.2964 - categorical_accuracy: 0.5794 - val_loss: 1.3988 - val_categorical_accuracy: 0.5645
# Epoch 2/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.8319 - categorical_accuracy: 0.7330 - val_loss: 1.0336 - val_categorical_accuracy: 0.6805
# Epoch 3/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.6814 - categorical_accuracy: 0.7795 - val_loss: 0.8382 - val_categorical_accuracy: 0.7204
# Epoch 4/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.5731 - categorical_accuracy: 0.8138 - val_loss: 0.7255 - val_categorical_accuracy: 0.7700
# Epoch 5/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.5049 - categorical_accuracy: 0.8371 - val_loss: 0.8345 - val_categorical_accuracy: 0.7418
# Epoch 6/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.4554 - categorical_accuracy: 0.8509 - val_loss: 0.7234 - val_categorical_accuracy: 0.7802
# Epoch 7/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.4004 - categorical_accuracy: 0.8718 - val_loss: 0.7539 - val_categorical_accuracy: 0.7663
# Epoch 8/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3743 - categorical_accuracy: 0.8781 - val_loss: 0.7267 - val_categorical_accuracy: 0.7840
# Epoch 9/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3421 - categorical_accuracy: 0.8899 - val_loss: 0.7857 - val_categorical_accuracy: 0.7674
# Epoch 10/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.3131 - categorical_accuracy: 0.8981 - val_loss: 0.8269 - val_categorical_accuracy: 0.7670
# Epoch 11/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2874 - categorical_accuracy: 0.9037 - val_loss: 0.8246 - val_categorical_accuracy: 0.7761
# Epoch 12/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2687 - categorical_accuracy: 0.9100 - val_loss: 0.8960 - val_categorical_accuracy: 0.7682
# Epoch 13/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2476 - categorical_accuracy: 0.9169 - val_loss: 1.0097 - val_categorical_accuracy: 0.7358
# Epoch 14/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2400 - categorical_accuracy: 0.9174 - val_loss: 0.9205 - val_categorical_accuracy: 0.7768
# Epoch 15/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2308 - categorical_accuracy: 0.9257 - val_loss: 1.0615 - val_categorical_accuracy: 0.7539
# Epoch 16/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2146 - categorical_accuracy: 0.9262 - val_loss: 0.9944 - val_categorical_accuracy: 0.7659
# Epoch 17/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.2065 - categorical_accuracy: 0.9281 - val_loss: 1.0604 - val_categorical_accuracy: 0.7456
# Epoch 18/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1938 - categorical_accuracy: 0.9359 - val_loss: 1.1166 - val_categorical_accuracy: 0.7475
# Epoch 19/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1846 - categorical_accuracy: 0.9387 - val_loss: 1.1178 - val_categorical_accuracy: 0.7524
# Epoch 20/20
# 10628/10628 [==============================] - 158s 15ms/step - loss: 0.1728 - categorical_accuracy: 0.9436 - val_loss: 1.0735 - val_categorical_accuracy: 0.7742

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_4 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 2,574,046
# Trainable params: 2,574,046
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 1.1749 - categorical_accuracy: 0.6138 - val_loss: 1.2543 - val_categorical_accuracy: 0.5950
# Epoch 2/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.6929 - categorical_accuracy: 0.7676 - val_loss: 1.1166 - val_categorical_accuracy: 0.6082
# Epoch 3/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.5357 - categorical_accuracy: 0.8180 - val_loss: 0.7267 - val_categorical_accuracy: 0.7539
# Epoch 4/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.4516 - categorical_accuracy: 0.8479 - val_loss: 0.7942 - val_categorical_accuracy: 0.7444
# Epoch 5/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3848 - categorical_accuracy: 0.8681 - val_loss: 0.7962 - val_categorical_accuracy: 0.7448
# Epoch 6/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3468 - categorical_accuracy: 0.8817 - val_loss: 0.7201 - val_categorical_accuracy: 0.7746
# Epoch 7/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2993 - categorical_accuracy: 0.8981 - val_loss: 0.7154 - val_categorical_accuracy: 0.7821
# Epoch 8/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2683 - categorical_accuracy: 0.9097 - val_loss: 0.7920 - val_categorical_accuracy: 0.7651
# Epoch 9/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 0.2329 - categorical_accuracy: 0.9228 - val_loss: 0.7706 - val_categorical_accuracy: 0.7764
# Epoch 10/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2066 - categorical_accuracy: 0.9289 - val_loss: 0.7982 - val_categorical_accuracy: 0.7697
# Epoch 11/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1887 - categorical_accuracy: 0.9355 - val_loss: 0.8208 - val_categorical_accuracy: 0.7670
# Epoch 12/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1650 - categorical_accuracy: 0.9428 - val_loss: 0.8593 - val_categorical_accuracy: 0.7693
# Epoch 13/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1536 - categorical_accuracy: 0.9467 - val_loss: 0.8740 - val_categorical_accuracy: 0.7697
# Epoch 14/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1747 - categorical_accuracy: 0.9433 - val_loss: 0.9328 - val_categorical_accuracy: 0.7508
# Epoch 15/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1492 - categorical_accuracy: 0.9506 - val_loss: 0.8659 - val_categorical_accuracy: 0.7798
# Epoch 16/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1452 - categorical_accuracy: 0.9494 - val_loss: 0.8969 - val_categorical_accuracy: 0.7625
# Epoch 17/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 0.1272 - categorical_accuracy: 0.9548 - val_loss: 0.9534 - val_categorical_accuracy: 0.7655
# Epoch 18/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1241 - categorical_accuracy: 0.9570 - val_loss: 0.9837 - val_categorical_accuracy: 0.7550
# Epoch 19/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1147 - categorical_accuracy: 0.9632 - val_loss: 0.9793 - val_categorical_accuracy: 0.7697
# Epoch 20/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1144 - categorical_accuracy: 0.9598 - val_loss: 1.0129 - val_categorical_accuracy: 0.7569

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, return_sequences=True, dropout=0.2, recurrent_dropout=0.2))
model.add(GRU(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_5 (GRU)                  (None, 500, 256)          274176
# _________________________________________________________________
# gru_6 (GRU)                  (None, 64)                61632
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 2,633,758
# Trainable params: 2,633,758
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 316s 30ms/step - loss: 1.0884 - categorical_accuracy: 0.6411 - val_loss: 0.9974 - val_categorical_accuracy: 0.6786
# Epoch 2/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.7017 - categorical_accuracy: 0.7688 - val_loss: 0.8583 - val_categorical_accuracy: 0.7189
# Epoch 3/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.5662 - categorical_accuracy: 0.8106 - val_loss: 0.9102 - val_categorical_accuracy: 0.6918
# Epoch 4/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.4836 - categorical_accuracy: 0.8386 - val_loss: 0.6852 - val_categorical_accuracy: 0.7734
# Epoch 5/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.4229 - categorical_accuracy: 0.8599 - val_loss: 0.7117 - val_categorical_accuracy: 0.7576
# Epoch 6/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.3769 - categorical_accuracy: 0.8733 - val_loss: 0.7153 - val_categorical_accuracy: 0.7761
# Epoch 7/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.3471 - categorical_accuracy: 0.8814 - val_loss: 0.6605 - val_categorical_accuracy: 0.7945
# Epoch 8/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.3155 - categorical_accuracy: 0.8962 - val_loss: 0.7568 - val_categorical_accuracy: 0.7588
# Epoch 9/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.2819 - categorical_accuracy: 0.9062 - val_loss: 0.7596 - val_categorical_accuracy: 0.7753
# Epoch 10/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.2533 - categorical_accuracy: 0.9132 - val_loss: 0.7160 - val_categorical_accuracy: 0.7907
# Epoch 11/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.2252 - categorical_accuracy: 0.9231 - val_loss: 0.7404 - val_categorical_accuracy: 0.7832
# Epoch 12/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.2210 - categorical_accuracy: 0.9260 - val_loss: 0.7582 - val_categorical_accuracy: 0.7870
# Epoch 13/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.1930 - categorical_accuracy: 0.9363 - val_loss: 0.9019 - val_categorical_accuracy: 0.7663
# Epoch 14/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.1872 - categorical_accuracy: 0.9352 - val_loss: 0.8433 - val_categorical_accuracy: 0.7719
# Epoch 15/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.1755 - categorical_accuracy: 0.9392 - val_loss: 0.8589 - val_categorical_accuracy: 0.7764
# Epoch 16/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.1610 - categorical_accuracy: 0.9451 - val_loss: 0.8697 - val_categorical_accuracy: 0.7761
# Epoch 17/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.1508 - categorical_accuracy: 0.9468 - val_loss: 1.0528 - val_categorical_accuracy: 0.7475
# Epoch 18/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.1513 - categorical_accuracy: 0.9489 - val_loss: 0.8269 - val_categorical_accuracy: 0.7877
# Epoch 19/20
# 10628/10628 [==============================] - 314s 30ms/step - loss: 0.1403 - categorical_accuracy: 0.9521 - val_loss: 0.8651 - val_categorical_accuracy: 0.7881
# Epoch 20/20
# 10628/10628 [==============================] - 315s 30ms/step - loss: 0.1386 - categorical_accuracy: 0.9517 - val_loss: 0.9039 - val_categorical_accuracy: 0.7689

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_7 (GRU)                  (None, 512)               941568
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 3,372,766
# Trainable params: 3,372,766
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 1.1139 - categorical_accuracy: 0.6364 - val_loss: 0.9736 - val_categorical_accuracy: 0.6880
# Epoch 2/20
# 10628/10628 [==============================] - 159s 15ms/step - loss: 0.6680 - categorical_accuracy: 0.7747 - val_loss: 0.8471 - val_categorical_accuracy: 0.7245
# Epoch 3/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.5272 - categorical_accuracy: 0.8257 - val_loss: 0.9097 - val_categorical_accuracy: 0.6775
# Epoch 4/20
# 10628/10628 [==============================] - 159s 15ms/step - loss: 0.4294 - categorical_accuracy: 0.8540 - val_loss: 0.7390 - val_categorical_accuracy: 0.7715
# Epoch 5/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3677 - categorical_accuracy: 0.8759 - val_loss: 0.8854 - val_categorical_accuracy: 0.7396
# Epoch 6/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3101 - categorical_accuracy: 0.8936 - val_loss: 0.8487 - val_categorical_accuracy: 0.7772
# Epoch 7/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2666 - categorical_accuracy: 0.9075 - val_loss: 1.0418 - val_categorical_accuracy: 0.7460
# Epoch 8/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2259 - categorical_accuracy: 0.9212 - val_loss: 0.9849 - val_categorical_accuracy: 0.7659
# Epoch 9/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1992 - categorical_accuracy: 0.9334 - val_loss: 1.0826 - val_categorical_accuracy: 0.7539
# Epoch 10/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1769 - categorical_accuracy: 0.9419 - val_loss: 1.1547 - val_categorical_accuracy: 0.7708
# Epoch 11/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1646 - categorical_accuracy: 0.9426 - val_loss: 1.4114 - val_categorical_accuracy: 0.7132
# Epoch 12/20
# 10628/10628 [==============================] - 159s 15ms/step - loss: 0.1591 - categorical_accuracy: 0.9489 - val_loss: 1.1790 - val_categorical_accuracy: 0.7636
# Epoch 13/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1420 - categorical_accuracy: 0.9544 - val_loss: 1.3962 - val_categorical_accuracy: 0.7362
# Epoch 14/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1335 - categorical_accuracy: 0.9566 - val_loss: 1.4226 - val_categorical_accuracy: 0.7482
# Epoch 15/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1354 - categorical_accuracy: 0.9555 - val_loss: 1.3667 - val_categorical_accuracy: 0.7727
# Epoch 16/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1408 - categorical_accuracy: 0.9545 - val_loss: 1.4055 - val_categorical_accuracy: 0.7467
# Epoch 17/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1277 - categorical_accuracy: 0.9585 - val_loss: 1.4301 - val_categorical_accuracy: 0.7640
# Epoch 18/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1249 - categorical_accuracy: 0.9594 - val_loss: 1.4168 - val_categorical_accuracy: 0.7591
# Epoch 19/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1171 - categorical_accuracy: 0.9638 - val_loss: 1.4608 - val_categorical_accuracy: 0.7554
# Epoch 20/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1215 - categorical_accuracy: 0.9615 - val_loss: 1.7710 - val_categorical_accuracy: 0.6933

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_8 (GRU)                  (None, 512)               941568
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 3,305,822
# Trainable params: 3,305,822
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 165s 16ms/step - loss: 1.1620 - categorical_accuracy: 0.6226 - val_loss: 1.1639 - val_categorical_accuracy: 0.5698
# Epoch 2/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.7011 - categorical_accuracy: 0.7667 - val_loss: 0.7776 - val_categorical_accuracy: 0.7411
# Epoch 3/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.5465 - categorical_accuracy: 0.8182 - val_loss: 0.9747 - val_categorical_accuracy: 0.7177
# Epoch 4/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.4502 - categorical_accuracy: 0.8477 - val_loss: 0.8024 - val_categorical_accuracy: 0.7618
# Epoch 5/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.3851 - categorical_accuracy: 0.8672 - val_loss: 0.7643 - val_categorical_accuracy: 0.7734
# Epoch 6/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.3306 - categorical_accuracy: 0.8891 - val_loss: 0.9014 - val_categorical_accuracy: 0.7339
# Epoch 7/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2795 - categorical_accuracy: 0.9048 - val_loss: 0.8152 - val_categorical_accuracy: 0.7840
# Epoch 8/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.2372 - categorical_accuracy: 0.9174 - val_loss: 0.9613 - val_categorical_accuracy: 0.7787
# Epoch 9/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.2167 - categorical_accuracy: 0.9256 - val_loss: 1.0206 - val_categorical_accuracy: 0.7599
# Epoch 10/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1957 - categorical_accuracy: 0.9328 - val_loss: 1.0829 - val_categorical_accuracy: 0.7610
# Epoch 11/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.1723 - categorical_accuracy: 0.9413 - val_loss: 1.2341 - val_categorical_accuracy: 0.7189
# Epoch 12/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1596 - categorical_accuracy: 0.9476 - val_loss: 1.1965 - val_categorical_accuracy: 0.7505
# Epoch 13/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1522 - categorical_accuracy: 0.9483 - val_loss: 1.1784 - val_categorical_accuracy: 0.7761
# Epoch 14/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1404 - categorical_accuracy: 0.9550 - val_loss: 1.3055 - val_categorical_accuracy: 0.7606
# Epoch 15/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1313 - categorical_accuracy: 0.9574 - val_loss: 1.3980 - val_categorical_accuracy: 0.7527
# Epoch 16/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1277 - categorical_accuracy: 0.9578 - val_loss: 1.2493 - val_categorical_accuracy: 0.7768
# Epoch 17/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.1245 - categorical_accuracy: 0.9555 - val_loss: 1.3446 - val_categorical_accuracy: 0.7603
# Epoch 18/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.1153 - categorical_accuracy: 0.9599 - val_loss: 1.5763 - val_categorical_accuracy: 0.7542
# Epoch 19/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.1259 - categorical_accuracy: 0.9581 - val_loss: 1.4452 - val_categorical_accuracy: 0.7712
# Epoch 20/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1221 - categorical_accuracy: 0.9590 - val_loss: 1.5027 - val_categorical_accuracy: 0.7554

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_9 (GRU)                  (None, 512)               941568
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                650
# =================================================================
# Total params: 3,272,350
# Trainable params: 3,272,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 1.1868 - categorical_accuracy: 0.6115 - val_loss: 1.3034 - val_categorical_accuracy: 0.6248
# Epoch 2/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.7338 - categorical_accuracy: 0.7579 - val_loss: 1.0052 - val_categorical_accuracy: 0.6680
# Epoch 3/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.5805 - categorical_accuracy: 0.8090 - val_loss: 0.8492 - val_categorical_accuracy: 0.7237
# Epoch 4/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.4808 - categorical_accuracy: 0.8400 - val_loss: 0.7622 - val_categorical_accuracy: 0.7588
# Epoch 5/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 0.4064 - categorical_accuracy: 0.8617 - val_loss: 0.7829 - val_categorical_accuracy: 0.7478
# Epoch 6/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 0.3393 - categorical_accuracy: 0.8826 - val_loss: 0.8091 - val_categorical_accuracy: 0.7603
# Epoch 7/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 0.2801 - categorical_accuracy: 0.9047 - val_loss: 0.9455 - val_categorical_accuracy: 0.7377
# Epoch 8/20
# 10628/10628 [==============================] - 169s 16ms/step - loss: 0.3245 - categorical_accuracy: 0.8913 - val_loss: 0.8243 - val_categorical_accuracy: 0.7825
# Epoch 9/20
# 10628/10628 [==============================] - 168s 16ms/step - loss: 0.3003 - categorical_accuracy: 0.8935 - val_loss: 0.8529 - val_categorical_accuracy: 0.7719
# Epoch 10/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2222 - categorical_accuracy: 0.9220 - val_loss: 0.9641 - val_categorical_accuracy: 0.7648
# Epoch 11/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2558 - categorical_accuracy: 0.9117 - val_loss: 0.9419 - val_categorical_accuracy: 0.7377
# Epoch 12/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2310 - categorical_accuracy: 0.9210 - val_loss: 1.0761 - val_categorical_accuracy: 0.7467
# Epoch 13/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2258 - categorical_accuracy: 0.9209 - val_loss: 1.0228 - val_categorical_accuracy: 0.7365
# Epoch 14/20
# 10628/10628 [==============================] - 164s 15ms/step - loss: 0.2077 - categorical_accuracy: 0.9291 - val_loss: 1.1095 - val_categorical_accuracy: 0.7554
# Epoch 15/20
# 10628/10628 [==============================] - 163s 15ms/step - loss: 0.1956 - categorical_accuracy: 0.9346 - val_loss: 1.1429 - val_categorical_accuracy: 0.7565
# Epoch 16/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 0.1788 - categorical_accuracy: 0.9402 - val_loss: 1.1242 - val_categorical_accuracy: 0.7625
# Epoch 17/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 0.1570 - categorical_accuracy: 0.9472 - val_loss: 1.3451 - val_categorical_accuracy: 0.7381
# Epoch 18/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 0.1607 - categorical_accuracy: 0.9454 - val_loss: 1.3593 - val_categorical_accuracy: 0.7294
# Epoch 19/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 1.8678 - categorical_accuracy: 0.3097 - val_loss: 2.2012 - val_categorical_accuracy: 0.1283
# Epoch 20/20
# 10628/10628 [==============================] - 162s 15ms/step - loss: 2.1337 - categorical_accuracy: 0.2272 - val_loss: 2.1123 - val_categorical_accuracy: 0.1283

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 500, 100)          2297300
# _________________________________________________________________
# gru_10 (GRU)                 (None, 512)               941568
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 3,243,998
# Trainable params: 3,243,998
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 161s 15ms/step - loss: 1.0801 - categorical_accuracy: 0.6447 - val_loss: 1.4803 - val_categorical_accuracy: 0.4938
# Epoch 2/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.5941 - categorical_accuracy: 0.8006 - val_loss: 1.0275 - val_categorical_accuracy: 0.6022
# Epoch 3/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.4787 - categorical_accuracy: 0.8397 - val_loss: 0.9259 - val_categorical_accuracy: 0.6850
# Epoch 4/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3908 - categorical_accuracy: 0.8683 - val_loss: 0.7793 - val_categorical_accuracy: 0.7531
# Epoch 5/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3197 - categorical_accuracy: 0.8901 - val_loss: 0.7840 - val_categorical_accuracy: 0.7539
# Epoch 6/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2616 - categorical_accuracy: 0.9095 - val_loss: 0.7586 - val_categorical_accuracy: 0.7764
# Epoch 7/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.2159 - categorical_accuracy: 0.9277 - val_loss: 0.8587 - val_categorical_accuracy: 0.7655
# Epoch 8/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1635 - categorical_accuracy: 0.9445 - val_loss: 0.8598 - val_categorical_accuracy: 0.7700
# Epoch 9/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.3257 - categorical_accuracy: 0.8957 - val_loss: 0.8949 - val_categorical_accuracy: 0.7738
# Epoch 10/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1325 - categorical_accuracy: 0.9563 - val_loss: 0.8892 - val_categorical_accuracy: 0.7689
# Epoch 11/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1160 - categorical_accuracy: 0.9626 - val_loss: 0.9549 - val_categorical_accuracy: 0.7648
# Epoch 12/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1036 - categorical_accuracy: 0.9665 - val_loss: 1.0984 - val_categorical_accuracy: 0.7633
# Epoch 13/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1069 - categorical_accuracy: 0.9657 - val_loss: 1.0348 - val_categorical_accuracy: 0.7640
# Epoch 14/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0946 - categorical_accuracy: 0.9689 - val_loss: 0.9945 - val_categorical_accuracy: 0.7810
# Epoch 15/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0815 - categorical_accuracy: 0.9753 - val_loss: 1.0808 - val_categorical_accuracy: 0.7651
# Epoch 16/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0813 - categorical_accuracy: 0.9733 - val_loss: 1.1223 - val_categorical_accuracy: 0.7700
# Epoch 17/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0754 - categorical_accuracy: 0.9744 - val_loss: 1.0951 - val_categorical_accuracy: 0.7817
# Epoch 18/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.1177 - categorical_accuracy: 0.9634 - val_loss: 1.2482 - val_categorical_accuracy: 0.7580
# Epoch 19/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0950 - categorical_accuracy: 0.9679 - val_loss: 1.0914 - val_categorical_accuracy: 0.7708
# Epoch 20/20
# 10628/10628 [==============================] - 160s 15ms/step - loss: 0.0732 - categorical_accuracy: 0.9765 - val_loss: 1.1378 - val_categorical_accuracy: 0.7651

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512, return_sequences=True, dropout=0.2, recurrent_dropout=0.2))
model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 500, 100)          2297300
# _________________________________________________________________
# gru_11 (GRU)                 (None, 500, 512)          941568
# _________________________________________________________________
# gru_12 (GRU)                 (None, 128)               246144
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 3,486,302
# Trainable params: 3,486,302
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 316s 30ms/step - loss: 1.0300 - categorical_accuracy: 0.6560 - val_loss: 1.1670 - val_categorical_accuracy: 0.5992
# Epoch 2/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.6265 - categorical_accuracy: 0.7854 - val_loss: 0.8160 - val_categorical_accuracy: 0.7531
# Epoch 3/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.4958 - categorical_accuracy: 0.8292 - val_loss: 0.8540 - val_categorical_accuracy: 0.7271
# Epoch 4/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.4207 - categorical_accuracy: 0.8603 - val_loss: 0.7367 - val_categorical_accuracy: 0.7640
# Epoch 5/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.3493 - categorical_accuracy: 0.8793 - val_loss: 0.7128 - val_categorical_accuracy: 0.7776
# Epoch 6/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.2928 - categorical_accuracy: 0.8972 - val_loss: 0.7883 - val_categorical_accuracy: 0.7531
# Epoch 7/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.2465 - categorical_accuracy: 0.9169 - val_loss: 0.7608 - val_categorical_accuracy: 0.7712
# Epoch 8/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.2139 - categorical_accuracy: 0.9265 - val_loss: 0.8090 - val_categorical_accuracy: 0.7591
# Epoch 9/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.1755 - categorical_accuracy: 0.9413 - val_loss: 0.7806 - val_categorical_accuracy: 0.7813
# Epoch 10/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.1611 - categorical_accuracy: 0.9430 - val_loss: 0.8374 - val_categorical_accuracy: 0.7817
# Epoch 11/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.1453 - categorical_accuracy: 0.9511 - val_loss: 0.9143 - val_categorical_accuracy: 0.7663
# Epoch 12/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.1348 - categorical_accuracy: 0.9536 - val_loss: 0.9516 - val_categorical_accuracy: 0.7678
# Epoch 13/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.1162 - categorical_accuracy: 0.9594 - val_loss: 0.9457 - val_categorical_accuracy: 0.7693
# Epoch 14/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.1169 - categorical_accuracy: 0.9591 - val_loss: 0.9736 - val_categorical_accuracy: 0.7776
# Epoch 15/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.1148 - categorical_accuracy: 0.9599 - val_loss: 0.9407 - val_categorical_accuracy: 0.7749
# Epoch 16/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.0955 - categorical_accuracy: 0.9673 - val_loss: 0.9500 - val_categorical_accuracy: 0.7832
# Epoch 17/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.0927 - categorical_accuracy: 0.9689 - val_loss: 1.0017 - val_categorical_accuracy: 0.7764
# Epoch 18/20
# 10628/10628 [==============================] - 313s 29ms/step - loss: 0.0891 - categorical_accuracy: 0.9697 - val_loss: 1.1058 - val_categorical_accuracy: 0.7633
# Epoch 19/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.0880 - categorical_accuracy: 0.9702 - val_loss: 1.0445 - val_categorical_accuracy: 0.7682
# Epoch 20/20
# 10628/10628 [==============================] - 312s 29ms/step - loss: 0.0884 - categorical_accuracy: 0.9708 - val_loss: 1.0336 - val_categorical_accuracy: 0.7791

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(LSTM(512, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, 500, 100)          2297300
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1255424
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 3,557,854
# Trainable params: 3,557,854
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 201s 19ms/step - loss: 1.1090 - categorical_accuracy: 0.6363 - val_loss: 1.1484 - val_categorical_accuracy: 0.6191
# Epoch 2/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.7766 - categorical_accuracy: 0.7408 - val_loss: 0.9082 - val_categorical_accuracy: 0.6842
# Epoch 3/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.6221 - categorical_accuracy: 0.7930 - val_loss: 0.9530 - val_categorical_accuracy: 0.6835
# Epoch 4/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.5220 - categorical_accuracy: 0.8248 - val_loss: 0.8802 - val_categorical_accuracy: 0.7064
# Epoch 5/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.4494 - categorical_accuracy: 0.8463 - val_loss: 0.7590 - val_categorical_accuracy: 0.7561
# Epoch 6/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.3757 - categorical_accuracy: 0.8724 - val_loss: 0.8040 - val_categorical_accuracy: 0.7429
# Epoch 7/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.3156 - categorical_accuracy: 0.8918 - val_loss: 0.8461 - val_categorical_accuracy: 0.7527
# Epoch 8/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.2711 - categorical_accuracy: 0.9048 - val_loss: 0.7584 - val_categorical_accuracy: 0.7685
# Epoch 9/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.2244 - categorical_accuracy: 0.9226 - val_loss: 0.8334 - val_categorical_accuracy: 0.7663
# Epoch 10/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.1877 - categorical_accuracy: 0.9352 - val_loss: 0.8639 - val_categorical_accuracy: 0.7501
# Epoch 11/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.1793 - categorical_accuracy: 0.9373 - val_loss: 0.9467 - val_categorical_accuracy: 0.7482
# Epoch 12/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.1341 - categorical_accuracy: 0.9539 - val_loss: 0.9848 - val_categorical_accuracy: 0.7591
# Epoch 13/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.1231 - categorical_accuracy: 0.9587 - val_loss: 1.0516 - val_categorical_accuracy: 0.7460
# Epoch 14/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.1088 - categorical_accuracy: 0.9641 - val_loss: 0.9960 - val_categorical_accuracy: 0.7648
# Epoch 15/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0939 - categorical_accuracy: 0.9683 - val_loss: 1.0365 - val_categorical_accuracy: 0.7610
# Epoch 16/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0917 - categorical_accuracy: 0.9720 - val_loss: 1.1077 - val_categorical_accuracy: 0.7640
# Epoch 17/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0779 - categorical_accuracy: 0.9749 - val_loss: 1.1696 - val_categorical_accuracy: 0.7629
# Epoch 18/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0719 - categorical_accuracy: 0.9769 - val_loss: 1.1404 - val_categorical_accuracy: 0.7644
# Epoch 19/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0607 - categorical_accuracy: 0.9794 - val_loss: 1.1905 - val_categorical_accuracy: 0.7693
# Epoch 20/20
# 10628/10628 [==============================] - 199s 19ms/step - loss: 0.0705 - categorical_accuracy: 0.9772 - val_loss: 1.2124 - val_categorical_accuracy: 0.7463

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Bidirectional(LSTM(512, dropout=0.2, recurrent_dropout=0.2)))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 500, 100)          2297300
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 1024)              2510848
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 4,818,398
# Trainable params: 4,818,398
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10628 samples, validate on 2657 samples
# Epoch 1/20
# 10628/10628 [==============================] - 389s 37ms/step - loss: 1.1193 - categorical_accuracy: 0.6346 - val_loss: 1.0913 - val_categorical_accuracy: 0.6665
# Epoch 2/20
# 10628/10628 [==============================] - 386s 36ms/step - loss: 0.7914 - categorical_accuracy: 0.7411 - val_loss: 0.9993 - val_categorical_accuracy: 0.6857
# Epoch 3/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.6193 - categorical_accuracy: 0.7942 - val_loss: 0.8659 - val_categorical_accuracy: 0.7505
# Epoch 4/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.5307 - categorical_accuracy: 0.8244 - val_loss: 0.8433 - val_categorical_accuracy: 0.7497
# Epoch 5/20
# 10628/10628 [==============================] - 386s 36ms/step - loss: 0.4389 - categorical_accuracy: 0.8528 - val_loss: 0.9602 - val_categorical_accuracy: 0.7155
# Epoch 6/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.3742 - categorical_accuracy: 0.8733 - val_loss: 0.8235 - val_categorical_accuracy: 0.7644
# Epoch 7/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.3070 - categorical_accuracy: 0.8941 - val_loss: 0.9082 - val_categorical_accuracy: 0.7441
# Epoch 8/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.2558 - categorical_accuracy: 0.9146 - val_loss: 0.9484 - val_categorical_accuracy: 0.7448
# Epoch 9/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.2127 - categorical_accuracy: 0.9246 - val_loss: 0.9734 - val_categorical_accuracy: 0.7456
# Epoch 10/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.1821 - categorical_accuracy: 0.9353 - val_loss: 1.0547 - val_categorical_accuracy: 0.7294
# Epoch 11/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.1653 - categorical_accuracy: 0.9457 - val_loss: 0.9793 - val_categorical_accuracy: 0.7444
# Epoch 12/20
# 10628/10628 [==============================] - 386s 36ms/step - loss: 0.1280 - categorical_accuracy: 0.9554 - val_loss: 1.1006 - val_categorical_accuracy: 0.7332
# Epoch 13/20
# 10628/10628 [==============================] - 384s 36ms/step - loss: 0.1184 - categorical_accuracy: 0.9619 - val_loss: 1.0871 - val_categorical_accuracy: 0.7429
# Epoch 14/20
# 10628/10628 [==============================] - 384s 36ms/step - loss: 0.0997 - categorical_accuracy: 0.9682 - val_loss: 1.1373 - val_categorical_accuracy: 0.7354
# Epoch 15/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.0907 - categorical_accuracy: 0.9718 - val_loss: 1.2193 - val_categorical_accuracy: 0.7381
# Epoch 16/20
# 10628/10628 [==============================] - 385s 36ms/step - loss: 0.0805 - categorical_accuracy: 0.9736 - val_loss: 1.2091 - val_categorical_accuracy: 0.7603
# Epoch 17/20
# 10628/10628 [==============================] - 384s 36ms/step - loss: 0.0736 - categorical_accuracy: 0.9776 - val_loss: 1.2883 - val_categorical_accuracy: 0.7313
# Epoch 18/20
# 10628/10628 [==============================] - 384s 36ms/step - loss: 0.0674 - categorical_accuracy: 0.9771 - val_loss: 1.2572 - val_categorical_accuracy: 0.7572
# Epoch 19/20
# 10628/10628 [==============================] - 384s 36ms/step - loss: 0.0667 - categorical_accuracy: 0.9788 - val_loss: 1.2946 - val_categorical_accuracy: 0.7648
# Epoch 20/20
# 10628/10628 [==============================] - 382s 36ms/step - loss: 0.0625 - categorical_accuracy: 0.9814 - val_loss: 1.3458 - val_categorical_accuracy: 0.7524
