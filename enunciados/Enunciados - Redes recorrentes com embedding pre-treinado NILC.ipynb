# %% [markdown]
# # Importação e preparação dos dados

# %%
import pandas as pd

df = pd.read_csv('../dados/jurisprudencia_selecionada_enunciados.csv', sep = '|')
df.head()
# Out:
#     COD  NUM_ENUNCIADO  COD_AREA          DESCR_AREA  COD_TEMA  \
# 0  1400           1236        50    Responsabilidade       488
# 1  1700           1534        46   Finanças Públicas       981
# 2  5700           5314        50    Responsabilidade       203
# 3   284             40        45  Direito Processual       162
# 4   298             54        49             Pessoal       141
#
#                                   DESCR_TEMA  COD_SUBTEMA  \
# 0                              Solidariedade          261
# 1                                 Exportação          983
# 2                                      Multa         1021
# 3  Princípio da independência das instâncias          481
# 4                                  Sistema S          142
#
#               DESCR_SUBTEMA  COD_DOC_TRAMITAVEL_ENUNCIADO  \
# 0  Benefício previdenciário                      54995437
# 1                  Petróleo                      55025587
# 2                Dosimetria                      55455370
# 3          Decisão judicial                      54773746
# 4                 Nepotismo                      54773402
#
#                                      TEXTO_ENUNCIADO                ACORDAO  \
# 0  Não comprovada a participação do beneficiário ...  Acórdão 297/2016 - PL
# 1  A operação ficta de exportação de plataformas ...  Acórdão 366/2016 - PL
# 2  No âmbito do TCU, a dosimetria da pena tem com...  Acórdão 944/2016 - PL
# 3  O princípio da independência das instâncias pe...   Acórdão 30/2016 - PL
# 4  É vedado aos dirigentes das entidades do Siste...   Acórdão 55/2016 - PL
#
#                         TIPO_PROCESSO
# 0           Tomada de Contas Especial
# 1   Solicitação do Congresso Nacional
# 2                      Acompanhamento
# 3           Tomada de Contas Especial
# 4                       Representação

# %%
df.shape
# Out:
# (13312, 12)

# %%
df.groupby(['DESCR_AREA']).size()
# Out:
# DESCR_AREA
# Competência do TCU          557
# Contrato Administrativo     942
# Convênio                    685
# Desestatização              140
# Direito Processual         1813
# Finanças Públicas           328
# Gestão Administrativa       339
# Licitação                  2765
# Pessoal                    3396
# Responsabilidade           2347
# dtype: int64

# %%
areas = df.groupby(['DESCR_AREA']).groups.keys()
areas
# Out:
# dict_keys(['Competência do TCU', 'Contrato Administrativo', 'Convênio', 'Desestatização', 'Direito Processual', 'Finanças Públicas', 'Gestão Administrativa', 'Licitação', 'Pessoal', 'Responsabilidade'])

# %%
from sklearn.preprocessing import LabelBinarizer

lbArea = LabelBinarizer()
lbArea.fit([x for x in areas])
lbArea.classes_
# Out:
# array(['Competência do TCU', 'Contrato Administrativo', 'Convênio',
#        'Desestatização', 'Direito Processual', 'Finanças Públicas',
#        'Gestão Administrativa', 'Licitação', 'Pessoal',
#        'Responsabilidade'], dtype='<U23')

# %%
y = lbArea.transform(df['DESCR_AREA'])
y.shape
# Out:
# (13312, 10)

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

limite_texto = 200
dim_vetor = 100

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['TEXTO_ENUNCIADO'])

word_index = tokenizer.word_index
vocabulario = len(word_index) + 1
print('Found %s unique tokens.' % len(word_index))

sequences = tokenizer.texts_to_sequences(df['TEXTO_ENUNCIADO'])
# Out:
# Using TensorFlow backend.
# Found 15387 unique tokens.

# %%
from keras.preprocessing.sequence import pad_sequences

x = pad_sequences(sequences, maxlen=limite_texto)

print('Shape of data tensor:', x.shape)
# Out:
# Shape of data tensor: (13312, 200)

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format('model.txt')
# Out:
# /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# create a weight matrix for words in training docs

embedding_matrix = np.zeros((vocabulario, 100))

ok = 0
for word, i in tokenizer.word_index.items():
    if word in model:
        embedding_matrix[i] = model[word]
        ok += 1
print('Vocabulario:', i)
print('Encontrados no modelo:', ok, '=', ok * 100. / i)
# Out:
# Vocabulario: 15387
# Encontrados no modelo: 13758 = 89.41314096315071

# %% [markdown]
# # Treinamento

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, GRU
from keras.optimizers import RMSprop

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=False))
model.add(GRU(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# W0814 21:24:06.801036 140582074754880 deprecation_wrapper.py:119] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0814 21:24:06.901064 140582074754880 deprecation.py:323] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 276,746
# Non-trainable params: 1,538,800
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 1.2118 - categorical_accuracy: 0.5959 - val_loss: 0.9387 - val_categorical_accuracy: 0.6898
# Epoch 2/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.6484 - categorical_accuracy: 0.7894 - val_loss: 0.6783 - val_categorical_accuracy: 0.7754
# Epoch 3/20
# 10649/10649 [==============================] - 51s 5ms/step - loss: 0.5099 - categorical_accuracy: 0.8305 - val_loss: 0.7342 - val_categorical_accuracy: 0.7724
# Epoch 4/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.3753 - categorical_accuracy: 0.8741 - val_loss: 0.6601 - val_categorical_accuracy: 0.7863
# Epoch 5/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.2825 - categorical_accuracy: 0.9060 - val_loss: 0.6727 - val_categorical_accuracy: 0.8025
# Epoch 6/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.1970 - categorical_accuracy: 0.9345 - val_loss: 0.6405 - val_categorical_accuracy: 0.8183
# Epoch 7/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 0.1361 - categorical_accuracy: 0.9546 - val_loss: 0.6990 - val_categorical_accuracy: 0.8224
# Epoch 8/20
# 10649/10649 [==============================] - 51s 5ms/step - loss: 0.0895 - categorical_accuracy: 0.9723 - val_loss: 0.7596 - val_categorical_accuracy: 0.8152
# Epoch 9/20
# 10649/10649 [==============================] - 51s 5ms/step - loss: 0.0595 - categorical_accuracy: 0.9819 - val_loss: 1.1121 - val_categorical_accuracy: 0.7792
# Epoch 10/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.0603 - categorical_accuracy: 0.9866 - val_loss: 1.0966 - val_categorical_accuracy: 0.7923
# Epoch 11/20
# 10649/10649 [==============================] - 51s 5ms/step - loss: 0.0520 - categorical_accuracy: 0.9890 - val_loss: 1.2432 - val_categorical_accuracy: 0.7803
# Epoch 12/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 0.0427 - categorical_accuracy: 0.9882 - val_loss: 1.0762 - val_categorical_accuracy: 0.8194
# Epoch 13/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 0.1099 - categorical_accuracy: 0.9844 - val_loss: 1.0634 - val_categorical_accuracy: 0.8269
# Epoch 14/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.0173 - categorical_accuracy: 0.9950 - val_loss: 1.0911 - val_categorical_accuracy: 0.8280
# Epoch 15/20
# 10649/10649 [==============================] - 52s 5ms/step - loss: 0.0169 - categorical_accuracy: 0.9952 - val_loss: 1.1133 - val_categorical_accuracy: 0.8209
# Epoch 16/20
# 10649/10649 [==============================] - 54s 5ms/step - loss: 0.1260 - categorical_accuracy: 0.9745 - val_loss: 1.3455 - val_categorical_accuracy: 0.8066
# Epoch 17/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 0.0111 - categorical_accuracy: 0.9968 - val_loss: 1.2890 - val_categorical_accuracy: 0.8145
# Epoch 18/20
# 10649/10649 [==============================] - 53s 5ms/step - loss: 0.0616 - categorical_accuracy: 0.9878 - val_loss: 1.2759 - val_categorical_accuracy: 0.8122
# Epoch 19/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0320 - categorical_accuracy: 0.9912 - val_loss: 1.1253 - val_categorical_accuracy: 0.8258
# Epoch 20/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0165 - categorical_accuracy: 0.9952 - val_loss: 1.4158 - val_categorical_accuracy: 0.7983

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# gru_2 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 61s 6ms/step - loss: 1.1480 - categorical_accuracy: 0.6179 - val_loss: 0.8972 - val_categorical_accuracy: 0.7142
# Epoch 2/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.5203 - categorical_accuracy: 0.8294 - val_loss: 0.6987 - val_categorical_accuracy: 0.7679
# Epoch 3/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.3432 - categorical_accuracy: 0.8851 - val_loss: 0.6156 - val_categorical_accuracy: 0.8111
# Epoch 4/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.2551 - categorical_accuracy: 0.9196 - val_loss: 0.5816 - val_categorical_accuracy: 0.8194
# Epoch 5/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.1588 - categorical_accuracy: 0.9458 - val_loss: 0.5362 - val_categorical_accuracy: 0.8483
# Epoch 6/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0970 - categorical_accuracy: 0.9679 - val_loss: 0.7055 - val_categorical_accuracy: 0.8310
# Epoch 7/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.1017 - categorical_accuracy: 0.9717 - val_loss: 0.7102 - val_categorical_accuracy: 0.8404
# Epoch 8/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0462 - categorical_accuracy: 0.9865 - val_loss: 0.9402 - val_categorical_accuracy: 0.8261
# Epoch 9/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0211 - categorical_accuracy: 0.9937 - val_loss: 0.9093 - val_categorical_accuracy: 0.8400
# Epoch 10/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0122 - categorical_accuracy: 0.9971 - val_loss: 0.9745 - val_categorical_accuracy: 0.8408
# Epoch 11/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0100 - categorical_accuracy: 0.9977 - val_loss: 0.9997 - val_categorical_accuracy: 0.8434
# Epoch 12/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0084 - categorical_accuracy: 0.9982 - val_loss: 1.1381 - val_categorical_accuracy: 0.8261
# Epoch 13/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0042 - categorical_accuracy: 0.9990 - val_loss: 1.1401 - val_categorical_accuracy: 0.8479
# Epoch 14/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0053 - categorical_accuracy: 0.9987 - val_loss: 1.1638 - val_categorical_accuracy: 0.8397
# Epoch 15/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0080 - categorical_accuracy: 0.9986 - val_loss: 1.1426 - val_categorical_accuracy: 0.8460
# Epoch 16/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0044 - categorical_accuracy: 0.9992 - val_loss: 1.2536 - val_categorical_accuracy: 0.8438
# Epoch 17/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0062 - categorical_accuracy: 0.9991 - val_loss: 1.2504 - val_categorical_accuracy: 0.8487
# Epoch 18/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0108 - categorical_accuracy: 0.9978 - val_loss: 1.3528 - val_categorical_accuracy: 0.8389
# Epoch 19/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0050 - categorical_accuracy: 0.9992 - val_loss: 1.3781 - val_categorical_accuracy: 0.8393
# Epoch 20/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0030 - categorical_accuracy: 0.9993 - val_loss: 1.4519 - val_categorical_accuracy: 0.8269

# %%
from keras.layers import SimpleRNN

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(SimpleRNN(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 256)               91392
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,632,762
# Trainable params: 1,632,762
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 24s 2ms/step - loss: 1.6143 - categorical_accuracy: 0.4610 - val_loss: 1.5065 - val_categorical_accuracy: 0.5024
# Epoch 2/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 1.2121 - categorical_accuracy: 0.5979 - val_loss: 1.5370 - val_categorical_accuracy: 0.5100
# Epoch 3/20
# 10649/10649 [==============================] - 23s 2ms/step - loss: 1.0077 - categorical_accuracy: 0.6710 - val_loss: 1.3405 - val_categorical_accuracy: 0.5851
# Epoch 4/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.8613 - categorical_accuracy: 0.7205 - val_loss: 1.4236 - val_categorical_accuracy: 0.5441
# Epoch 5/20
# 10649/10649 [==============================] - 23s 2ms/step - loss: 0.7523 - categorical_accuracy: 0.7535 - val_loss: 1.3410 - val_categorical_accuracy: 0.5922
# Epoch 6/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.6564 - categorical_accuracy: 0.7914 - val_loss: 1.3243 - val_categorical_accuracy: 0.6200
# Epoch 7/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.5812 - categorical_accuracy: 0.8125 - val_loss: 1.4496 - val_categorical_accuracy: 0.5888
# Epoch 8/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.4707 - categorical_accuracy: 0.8509 - val_loss: 1.4340 - val_categorical_accuracy: 0.6211
# Epoch 9/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.3781 - categorical_accuracy: 0.8777 - val_loss: 1.5120 - val_categorical_accuracy: 0.6121
# Epoch 10/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.3209 - categorical_accuracy: 0.9011 - val_loss: 1.7339 - val_categorical_accuracy: 0.6016
# Epoch 11/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.2577 - categorical_accuracy: 0.9190 - val_loss: 1.6317 - val_categorical_accuracy: 0.6219
# Epoch 12/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.2251 - categorical_accuracy: 0.9299 - val_loss: 1.5466 - val_categorical_accuracy: 0.6429
# Epoch 13/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.1879 - categorical_accuracy: 0.9434 - val_loss: 2.1683 - val_categorical_accuracy: 0.5805
# Epoch 14/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.1533 - categorical_accuracy: 0.9523 - val_loss: 1.6957 - val_categorical_accuracy: 0.6241
# Epoch 15/20
# 10649/10649 [==============================] - 22s 2ms/step - loss: 0.1300 - categorical_accuracy: 0.9620 - val_loss: 1.8308 - val_categorical_accuracy: 0.6241
# Epoch 16/20
# 10649/10649 [==============================] - 23s 2ms/step - loss: 0.1197 - categorical_accuracy: 0.9636 - val_loss: 1.7830 - val_categorical_accuracy: 0.6463
# Epoch 17/20
# 10649/10649 [==============================] - 24s 2ms/step - loss: 0.1093 - categorical_accuracy: 0.9681 - val_loss: 1.8826 - val_categorical_accuracy: 0.6388
# Epoch 18/20
# 10649/10649 [==============================] - 23s 2ms/step - loss: 0.0913 - categorical_accuracy: 0.9737 - val_loss: 1.9624 - val_categorical_accuracy: 0.6380
# Epoch 19/20
# 10649/10649 [==============================] - 24s 2ms/step - loss: 0.0875 - categorical_accuracy: 0.9736 - val_loss: 1.9950 - val_categorical_accuracy: 0.6568
# Epoch 20/20
# 10649/10649 [==============================] - 24s 2ms/step - loss: 0.0842 - categorical_accuracy: 0.9745 - val_loss: 2.1563 - val_categorical_accuracy: 0.6102

# %%
from keras.layers import LSTM

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(LSTM(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               365568
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,906,938
# Trainable params: 1,906,938
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 69s 7ms/step - loss: 1.1645 - categorical_accuracy: 0.6217 - val_loss: 1.2635 - val_categorical_accuracy: 0.6125
# Epoch 2/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.6397 - categorical_accuracy: 0.7992 - val_loss: 0.7412 - val_categorical_accuracy: 0.7724
# Epoch 3/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.4495 - categorical_accuracy: 0.8555 - val_loss: 0.6167 - val_categorical_accuracy: 0.8092
# Epoch 4/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.3291 - categorical_accuracy: 0.8960 - val_loss: 0.5402 - val_categorical_accuracy: 0.8419
# Epoch 5/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.2406 - categorical_accuracy: 0.9240 - val_loss: 0.6550 - val_categorical_accuracy: 0.8130
# Epoch 6/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.1742 - categorical_accuracy: 0.9443 - val_loss: 0.6612 - val_categorical_accuracy: 0.8235
# Epoch 7/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.1205 - categorical_accuracy: 0.9610 - val_loss: 0.6015 - val_categorical_accuracy: 0.8393
# Epoch 8/20
# 10649/10649 [==============================] - 68s 6ms/step - loss: 0.0812 - categorical_accuracy: 0.9743 - val_loss: 0.6532 - val_categorical_accuracy: 0.8558
# Epoch 9/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0501 - categorical_accuracy: 0.9838 - val_loss: 0.7494 - val_categorical_accuracy: 0.8464
# Epoch 10/20
# 10649/10649 [==============================] - 70s 7ms/step - loss: 0.0321 - categorical_accuracy: 0.9903 - val_loss: 0.8076 - val_categorical_accuracy: 0.8468
# Epoch 11/20
# 10649/10649 [==============================] - 68s 6ms/step - loss: 0.0225 - categorical_accuracy: 0.9938 - val_loss: 0.8400 - val_categorical_accuracy: 0.8520
# Epoch 12/20
# 10649/10649 [==============================] - 68s 6ms/step - loss: 0.0154 - categorical_accuracy: 0.9958 - val_loss: 0.9496 - val_categorical_accuracy: 0.8415
# Epoch 13/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0082 - categorical_accuracy: 0.9975 - val_loss: 1.0552 - val_categorical_accuracy: 0.8520
# Epoch 14/20
# 10649/10649 [==============================] - 70s 7ms/step - loss: 0.0105 - categorical_accuracy: 0.9968 - val_loss: 1.0594 - val_categorical_accuracy: 0.8363
# Epoch 15/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0066 - categorical_accuracy: 0.9982 - val_loss: 1.1461 - val_categorical_accuracy: 0.8532
# Epoch 16/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0092 - categorical_accuracy: 0.9976 - val_loss: 1.1729 - val_categorical_accuracy: 0.8434
# Epoch 17/20
# 10649/10649 [==============================] - 70s 7ms/step - loss: 0.0070 - categorical_accuracy: 0.9984 - val_loss: 1.1529 - val_categorical_accuracy: 0.8551
# Epoch 18/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0073 - categorical_accuracy: 0.9983 - val_loss: 1.1947 - val_categorical_accuracy: 0.8558
# Epoch 19/20
# 10649/10649 [==============================] - 68s 6ms/step - loss: 0.0058 - categorical_accuracy: 0.9986 - val_loss: 1.1455 - val_categorical_accuracy: 0.8573
# Epoch 20/20
# 10649/10649 [==============================] - 69s 6ms/step - loss: 0.0035 - categorical_accuracy: 0.9991 - val_loss: 1.2716 - val_categorical_accuracy: 0.8490

# %%
from keras.layers import Bidirectional

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Bidirectional(SimpleRNN(256)))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 512)               182784
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,726,714
# Trainable params: 1,726,714
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 1.6490 - categorical_accuracy: 0.4494 - val_loss: 1.8254 - val_categorical_accuracy: 0.3954
# Epoch 2/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 1.2326 - categorical_accuracy: 0.6004 - val_loss: 2.3334 - val_categorical_accuracy: 0.3526
# Epoch 3/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 1.0143 - categorical_accuracy: 0.6717 - val_loss: 1.4043 - val_categorical_accuracy: 0.5697
# Epoch 4/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.8880 - categorical_accuracy: 0.7128 - val_loss: 1.2665 - val_categorical_accuracy: 0.6173
# Epoch 5/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.7771 - categorical_accuracy: 0.7466 - val_loss: 1.6320 - val_categorical_accuracy: 0.5009
# Epoch 6/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.6673 - categorical_accuracy: 0.7836 - val_loss: 1.7615 - val_categorical_accuracy: 0.5051
# Epoch 7/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.5851 - categorical_accuracy: 0.8110 - val_loss: 1.3863 - val_categorical_accuracy: 0.6170
# Epoch 8/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.4939 - categorical_accuracy: 0.8420 - val_loss: 1.3333 - val_categorical_accuracy: 0.6421
# Epoch 9/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.4218 - categorical_accuracy: 0.8660 - val_loss: 1.4581 - val_categorical_accuracy: 0.6279
# Epoch 10/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.3648 - categorical_accuracy: 0.8853 - val_loss: 1.4540 - val_categorical_accuracy: 0.6286
# Epoch 11/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.2995 - categorical_accuracy: 0.9037 - val_loss: 1.4051 - val_categorical_accuracy: 0.6632
# Epoch 12/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.2726 - categorical_accuracy: 0.9163 - val_loss: 1.7079 - val_categorical_accuracy: 0.6181
# Epoch 13/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.2105 - categorical_accuracy: 0.9344 - val_loss: 1.6198 - val_categorical_accuracy: 0.6373
# Epoch 14/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1979 - categorical_accuracy: 0.9384 - val_loss: 1.6620 - val_categorical_accuracy: 0.6500
# Epoch 15/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1664 - categorical_accuracy: 0.9477 - val_loss: 2.1769 - val_categorical_accuracy: 0.5948
# Epoch 16/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1636 - categorical_accuracy: 0.9489 - val_loss: 1.8151 - val_categorical_accuracy: 0.6384
# Epoch 17/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1266 - categorical_accuracy: 0.9618 - val_loss: 2.2812 - val_categorical_accuracy: 0.6068
# Epoch 18/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1235 - categorical_accuracy: 0.9621 - val_loss: 2.0305 - val_categorical_accuracy: 0.6312
# Epoch 19/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.1066 - categorical_accuracy: 0.9669 - val_loss: 2.1870 - val_categorical_accuracy: 0.6189
# Epoch 20/20
# 10649/10649 [==============================] - 35s 3ms/step - loss: 0.0909 - categorical_accuracy: 0.9715 - val_loss: 2.0954 - val_categorical_accuracy: 0.6264

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Bidirectional(GRU(256)))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 512)               548352
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,092,282
# Trainable params: 2,092,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 97s 9ms/step - loss: 1.1326 - categorical_accuracy: 0.6294 - val_loss: 0.8253 - val_categorical_accuracy: 0.7289
# Epoch 2/20
# 10649/10649 [==============================] - 96s 9ms/step - loss: 0.5275 - categorical_accuracy: 0.8317 - val_loss: 0.5711 - val_categorical_accuracy: 0.8239
# Epoch 3/20
# 10649/10649 [==============================] - 96s 9ms/step - loss: 0.4285 - categorical_accuracy: 0.8711 - val_loss: 0.5553 - val_categorical_accuracy: 0.8250
# Epoch 4/20
# 10649/10649 [==============================] - 96s 9ms/step - loss: 0.2541 - categorical_accuracy: 0.9168 - val_loss: 0.5536 - val_categorical_accuracy: 0.8310
# Epoch 5/20
# 10649/10649 [==============================] - 96s 9ms/step - loss: 0.1742 - categorical_accuracy: 0.9413 - val_loss: 0.5356 - val_categorical_accuracy: 0.8494
# Epoch 6/20
# 10649/10649 [==============================] - 97s 9ms/step - loss: 0.1107 - categorical_accuracy: 0.9653 - val_loss: 0.6909 - val_categorical_accuracy: 0.8351
# Epoch 7/20
# 10649/10649 [==============================] - 98s 9ms/step - loss: 0.0623 - categorical_accuracy: 0.9802 - val_loss: 0.7144 - val_categorical_accuracy: 0.8400
# Epoch 8/20
# 10649/10649 [==============================] - 98s 9ms/step - loss: 0.0892 - categorical_accuracy: 0.9810 - val_loss: 1.0510 - val_categorical_accuracy: 0.7991
# Epoch 9/20
# 10649/10649 [==============================] - 98s 9ms/step - loss: 0.0467 - categorical_accuracy: 0.9869 - val_loss: 0.8140 - val_categorical_accuracy: 0.8430
# Epoch 10/20
# 10649/10649 [==============================] - 99s 9ms/step - loss: 0.0211 - categorical_accuracy: 0.9939 - val_loss: 0.8222 - val_categorical_accuracy: 0.8475
# Epoch 11/20
# 10649/10649 [==============================] - 99s 9ms/step - loss: 0.0132 - categorical_accuracy: 0.9968 - val_loss: 0.9455 - val_categorical_accuracy: 0.8415
# Epoch 12/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0094 - categorical_accuracy: 0.9977 - val_loss: 0.9500 - val_categorical_accuracy: 0.8509
# Epoch 13/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0080 - categorical_accuracy: 0.9975 - val_loss: 1.0659 - val_categorical_accuracy: 0.8430
# Epoch 14/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0056 - categorical_accuracy: 0.9991 - val_loss: 1.1193 - val_categorical_accuracy: 0.8430
# Epoch 15/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0106 - categorical_accuracy: 0.9978 - val_loss: 1.2946 - val_categorical_accuracy: 0.8250
# Epoch 16/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0053 - categorical_accuracy: 0.9985 - val_loss: 1.1923 - val_categorical_accuracy: 0.8453
# Epoch 17/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0051 - categorical_accuracy: 0.9988 - val_loss: 1.1421 - val_categorical_accuracy: 0.8453
# Epoch 18/20
# 10649/10649 [==============================] - 100s 9ms/step - loss: 0.0030 - categorical_accuracy: 0.9992 - val_loss: 1.2225 - val_categorical_accuracy: 0.8472
# Epoch 19/20
# 10649/10649 [==============================] - 101s 9ms/step - loss: 0.0025 - categorical_accuracy: 0.9996 - val_loss: 1.3265 - val_categorical_accuracy: 0.8487
# Epoch 20/20
# 10649/10649 [==============================] - 99s 9ms/step - loss: 0.0036 - categorical_accuracy: 0.9993 - val_loss: 1.2961 - val_categorical_accuracy: 0.8532

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(Bidirectional(LSTM(256)))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 512)               731136
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,275,066
# Trainable params: 2,275,066
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 127s 12ms/step - loss: 1.2238 - categorical_accuracy: 0.5926 - val_loss: 1.0035 - val_categorical_accuracy: 0.6748
# Epoch 2/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.6745 - categorical_accuracy: 0.7864 - val_loss: 0.8356 - val_categorical_accuracy: 0.7356
# Epoch 3/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.4630 - categorical_accuracy: 0.8523 - val_loss: 0.6615 - val_categorical_accuracy: 0.8085
# Epoch 4/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.3419 - categorical_accuracy: 0.8941 - val_loss: 0.7166 - val_categorical_accuracy: 0.8032
# Epoch 5/20
# 10649/10649 [==============================] - 127s 12ms/step - loss: 0.2689 - categorical_accuracy: 0.9149 - val_loss: 0.5816 - val_categorical_accuracy: 0.8351
# Epoch 6/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.1924 - categorical_accuracy: 0.9358 - val_loss: 0.6242 - val_categorical_accuracy: 0.8340
# Epoch 7/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.1343 - categorical_accuracy: 0.9574 - val_loss: 0.6635 - val_categorical_accuracy: 0.8370
# Epoch 8/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.0908 - categorical_accuracy: 0.9710 - val_loss: 0.7328 - val_categorical_accuracy: 0.8318
# Epoch 9/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.0651 - categorical_accuracy: 0.9790 - val_loss: 0.7526 - val_categorical_accuracy: 0.8445
# Epoch 10/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.0394 - categorical_accuracy: 0.9892 - val_loss: 0.7868 - val_categorical_accuracy: 0.8438
# Epoch 11/20
# 10649/10649 [==============================] - 129s 12ms/step - loss: 0.0250 - categorical_accuracy: 0.9925 - val_loss: 0.9223 - val_categorical_accuracy: 0.8340
# Epoch 12/20
# 10649/10649 [==============================] - 123s 12ms/step - loss: 0.0347 - categorical_accuracy: 0.9909 - val_loss: 0.9736 - val_categorical_accuracy: 0.8367
# Epoch 13/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0126 - categorical_accuracy: 0.9968 - val_loss: 1.1152 - val_categorical_accuracy: 0.8273
# Epoch 14/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0093 - categorical_accuracy: 0.9977 - val_loss: 1.1332 - val_categorical_accuracy: 0.8340
# Epoch 15/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0085 - categorical_accuracy: 0.9978 - val_loss: 1.0496 - val_categorical_accuracy: 0.8464
# Epoch 16/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0072 - categorical_accuracy: 0.9982 - val_loss: 1.1267 - val_categorical_accuracy: 0.8419
# Epoch 17/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0168 - categorical_accuracy: 0.9969 - val_loss: 1.1279 - val_categorical_accuracy: 0.8487
# Epoch 18/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0048 - categorical_accuracy: 0.9986 - val_loss: 1.1874 - val_categorical_accuracy: 0.8490
# Epoch 19/20
# 10649/10649 [==============================] - 126s 12ms/step - loss: 0.0051 - categorical_accuracy: 0.9988 - val_loss: 1.1826 - val_categorical_accuracy: 0.8547
# Epoch 20/20
# 10649/10649 [==============================] - 125s 12ms/step - loss: 0.0036 - categorical_accuracy: 0.9988 - val_loss: 1.3399 - val_categorical_accuracy: 0.8442

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(128))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 200, 100)          1538800
# _________________________________________________________________
# gru_4 (GRU)                  (None, 128)               87936
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,628,026
# Trainable params: 1,628,026
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 1.1807 - categorical_accuracy: 0.6059 - val_loss: 1.0647 - val_categorical_accuracy: 0.6526
# Epoch 2/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.5818 - categorical_accuracy: 0.8126 - val_loss: 0.6682 - val_categorical_accuracy: 0.7890
# Epoch 3/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.3911 - categorical_accuracy: 0.8729 - val_loss: 0.6085 - val_categorical_accuracy: 0.8137
# Epoch 4/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2818 - categorical_accuracy: 0.9099 - val_loss: 0.5520 - val_categorical_accuracy: 0.8336
# Epoch 5/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2018 - categorical_accuracy: 0.9357 - val_loss: 0.5729 - val_categorical_accuracy: 0.8303
# Epoch 6/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.1431 - categorical_accuracy: 0.9541 - val_loss: 0.5742 - val_categorical_accuracy: 0.8434
# Epoch 7/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0965 - categorical_accuracy: 0.9704 - val_loss: 0.6225 - val_categorical_accuracy: 0.8385
# Epoch 8/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0587 - categorical_accuracy: 0.9818 - val_loss: 0.6594 - val_categorical_accuracy: 0.8423
# Epoch 9/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0356 - categorical_accuracy: 0.9894 - val_loss: 0.7775 - val_categorical_accuracy: 0.8412
# Epoch 10/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0225 - categorical_accuracy: 0.9943 - val_loss: 0.8144 - val_categorical_accuracy: 0.8453
# Epoch 11/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0138 - categorical_accuracy: 0.9966 - val_loss: 0.9299 - val_categorical_accuracy: 0.8355
# Epoch 12/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0085 - categorical_accuracy: 0.9977 - val_loss: 0.9434 - val_categorical_accuracy: 0.8464
# Epoch 13/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.9988 - val_loss: 1.0061 - val_categorical_accuracy: 0.8449
# Epoch 14/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0056 - categorical_accuracy: 0.9988 - val_loss: 1.2569 - val_categorical_accuracy: 0.8152
# Epoch 15/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0060 - categorical_accuracy: 0.9990 - val_loss: 1.1332 - val_categorical_accuracy: 0.8355
# Epoch 16/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0055 - categorical_accuracy: 0.9988 - val_loss: 1.1219 - val_categorical_accuracy: 0.8404
# Epoch 17/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0042 - categorical_accuracy: 0.9992 - val_loss: 1.1928 - val_categorical_accuracy: 0.8438
# Epoch 18/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0040 - categorical_accuracy: 0.9993 - val_loss: 1.2260 - val_categorical_accuracy: 0.8423
# Epoch 19/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0043 - categorical_accuracy: 0.9991 - val_loss: 1.2910 - val_categorical_accuracy: 0.8419
# Epoch 20/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0041 - categorical_accuracy: 0.9989 - val_loss: 1.1947 - val_categorical_accuracy: 0.8483

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(64))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_5 (GRU)                  (None, 64)                31680
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,571,130
# Trainable params: 1,571,130
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 1.2914 - categorical_accuracy: 0.5668 - val_loss: 1.0646 - val_categorical_accuracy: 0.6549
# Epoch 2/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.7155 - categorical_accuracy: 0.7705 - val_loss: 0.7722 - val_categorical_accuracy: 0.7540
# Epoch 3/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.4787 - categorical_accuracy: 0.8514 - val_loss: 0.6873 - val_categorical_accuracy: 0.7863
# Epoch 4/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.3514 - categorical_accuracy: 0.8893 - val_loss: 0.5996 - val_categorical_accuracy: 0.8167
# Epoch 5/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2640 - categorical_accuracy: 0.9189 - val_loss: 0.6269 - val_categorical_accuracy: 0.8141
# Epoch 6/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2006 - categorical_accuracy: 0.9380 - val_loss: 0.5641 - val_categorical_accuracy: 0.8423
# Epoch 7/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.1472 - categorical_accuracy: 0.9547 - val_loss: 0.6199 - val_categorical_accuracy: 0.8209
# Epoch 8/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.1073 - categorical_accuracy: 0.9686 - val_loss: 0.6762 - val_categorical_accuracy: 0.8291
# Epoch 9/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0759 - categorical_accuracy: 0.9784 - val_loss: 0.6458 - val_categorical_accuracy: 0.8427
# Epoch 10/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0517 - categorical_accuracy: 0.9858 - val_loss: 0.8172 - val_categorical_accuracy: 0.8152
# Epoch 11/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0364 - categorical_accuracy: 0.9906 - val_loss: 0.7423 - val_categorical_accuracy: 0.8355
# Epoch 12/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0237 - categorical_accuracy: 0.9943 - val_loss: 0.8908 - val_categorical_accuracy: 0.8306
# Epoch 13/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0168 - categorical_accuracy: 0.9957 - val_loss: 0.8295 - val_categorical_accuracy: 0.8457
# Epoch 14/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0108 - categorical_accuracy: 0.9975 - val_loss: 0.9487 - val_categorical_accuracy: 0.8321
# Epoch 15/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0069 - categorical_accuracy: 0.9982 - val_loss: 0.9815 - val_categorical_accuracy: 0.8344
# Epoch 16/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0061 - categorical_accuracy: 0.9981 - val_loss: 1.1122 - val_categorical_accuracy: 0.8194
# Epoch 17/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0045 - categorical_accuracy: 0.9985 - val_loss: 1.0988 - val_categorical_accuracy: 0.8348
# Epoch 18/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0035 - categorical_accuracy: 0.9989 - val_loss: 1.1962 - val_categorical_accuracy: 0.8318
# Epoch 19/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0045 - categorical_accuracy: 0.9994 - val_loss: 1.2467 - val_categorical_accuracy: 0.8273
# Epoch 20/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0032 - categorical_accuracy: 0.9992 - val_loss: 1.3556 - val_categorical_accuracy: 0.8216

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(512))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_6 (GRU)                  (None, 512)               941568
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,485,498
# Trainable params: 2,485,498
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 59s 6ms/step - loss: 1.1489 - categorical_accuracy: 0.6313 - val_loss: 0.7766 - val_categorical_accuracy: 0.7503
# Epoch 2/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.4761 - categorical_accuracy: 0.8431 - val_loss: 0.6214 - val_categorical_accuracy: 0.8040
# Epoch 3/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2992 - categorical_accuracy: 0.9006 - val_loss: 0.5037 - val_categorical_accuracy: 0.8457
# Epoch 4/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.1937 - categorical_accuracy: 0.9358 - val_loss: 0.5967 - val_categorical_accuracy: 0.8243
# Epoch 5/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.3701 - categorical_accuracy: 0.9168 - val_loss: 0.5842 - val_categorical_accuracy: 0.8430
# Epoch 6/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.1038 - categorical_accuracy: 0.9698 - val_loss: 0.6177 - val_categorical_accuracy: 0.8468
# Epoch 7/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0424 - categorical_accuracy: 0.9879 - val_loss: 0.7305 - val_categorical_accuracy: 0.8539
# Epoch 8/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0218 - categorical_accuracy: 0.9933 - val_loss: 0.9414 - val_categorical_accuracy: 0.8351
# Epoch 9/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0179 - categorical_accuracy: 0.9948 - val_loss: 0.9480 - val_categorical_accuracy: 0.8442
# Epoch 10/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0384 - categorical_accuracy: 0.9959 - val_loss: 0.9893 - val_categorical_accuracy: 0.8453
# Epoch 11/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0079 - categorical_accuracy: 0.9975 - val_loss: 1.0578 - val_categorical_accuracy: 0.8528
# Epoch 12/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0103 - categorical_accuracy: 0.9980 - val_loss: 1.1046 - val_categorical_accuracy: 0.8502
# Epoch 13/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0068 - categorical_accuracy: 0.9984 - val_loss: 1.1648 - val_categorical_accuracy: 0.8472
# Epoch 14/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0069 - categorical_accuracy: 0.9985 - val_loss: 1.2945 - val_categorical_accuracy: 0.8344
# Epoch 15/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0068 - categorical_accuracy: 0.9986 - val_loss: 1.1884 - val_categorical_accuracy: 0.8412
# Epoch 16/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0034 - categorical_accuracy: 0.9993 - val_loss: 1.2101 - val_categorical_accuracy: 0.8554
# Epoch 17/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0016 - categorical_accuracy: 0.9996 - val_loss: 1.4852 - val_categorical_accuracy: 0.8295
# Epoch 18/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0063 - categorical_accuracy: 0.9993 - val_loss: 1.3950 - val_categorical_accuracy: 0.8412
# Epoch 19/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0060 - categorical_accuracy: 0.9991 - val_loss: 1.3496 - val_categorical_accuracy: 0.8479
# Epoch 20/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0055 - categorical_accuracy: 0.9990 - val_loss: 1.3064 - val_categorical_accuracy: 0.8494

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(128, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_7 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,847,162
# Trainable params: 1,847,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 1.1634 - categorical_accuracy: 0.6098 - val_loss: 0.8392 - val_categorical_accuracy: 0.7293
# Epoch 2/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.5258 - categorical_accuracy: 0.8285 - val_loss: 0.6488 - val_categorical_accuracy: 0.7871
# Epoch 3/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.3460 - categorical_accuracy: 0.8906 - val_loss: 0.6635 - val_categorical_accuracy: 0.7878
# Epoch 4/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.2225 - categorical_accuracy: 0.9284 - val_loss: 0.5400 - val_categorical_accuracy: 0.8427
# Epoch 5/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.1404 - categorical_accuracy: 0.9514 - val_loss: 0.5896 - val_categorical_accuracy: 0.8427
# Epoch 6/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0785 - categorical_accuracy: 0.9740 - val_loss: 0.7575 - val_categorical_accuracy: 0.8228
# Epoch 7/20
# 10649/10649 [==============================] - 59s 6ms/step - loss: 0.0462 - categorical_accuracy: 0.9865 - val_loss: 0.8826 - val_categorical_accuracy: 0.8295
# Epoch 8/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0259 - categorical_accuracy: 0.9918 - val_loss: 1.0874 - val_categorical_accuracy: 0.8340
# Epoch 9/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.2900 - categorical_accuracy: 0.9605 - val_loss: 1.1570 - val_categorical_accuracy: 0.8126
# Epoch 10/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0166 - categorical_accuracy: 0.9951 - val_loss: 1.5171 - val_categorical_accuracy: 0.7837
# Epoch 11/20
# 10649/10649 [==============================] - 59s 6ms/step - loss: 0.0213 - categorical_accuracy: 0.9942 - val_loss: 1.1905 - val_categorical_accuracy: 0.8393
# Epoch 12/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0109 - categorical_accuracy: 0.9973 - val_loss: 1.3150 - val_categorical_accuracy: 0.8378
# Epoch 13/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0090 - categorical_accuracy: 0.9979 - val_loss: 1.3199 - val_categorical_accuracy: 0.8412
# Epoch 14/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0100 - categorical_accuracy: 0.9975 - val_loss: 1.2915 - val_categorical_accuracy: 0.8453
# Epoch 15/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0054 - categorical_accuracy: 0.9987 - val_loss: 1.4188 - val_categorical_accuracy: 0.8393
# Epoch 16/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0055 - categorical_accuracy: 0.9994 - val_loss: 1.4577 - val_categorical_accuracy: 0.8430
# Epoch 17/20
# 10649/10649 [==============================] - 60s 6ms/step - loss: 0.0065 - categorical_accuracy: 0.9989 - val_loss: 1.7219 - val_categorical_accuracy: 0.8284
# Epoch 18/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0032 - categorical_accuracy: 0.9993 - val_loss: 1.5352 - val_categorical_accuracy: 0.8415
# Epoch 19/20
# 10649/10649 [==============================] - 62s 6ms/step - loss: 0.0036 - categorical_accuracy: 0.9991 - val_loss: 1.6874 - val_categorical_accuracy: 0.8389
# Epoch 20/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0045 - categorical_accuracy: 0.9992 - val_loss: 1.6362 - val_categorical_accuracy: 0.8427

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(64, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_8 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                650
# =================================================================
# Total params: 1,830,074
# Trainable params: 1,830,074
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 60s 6ms/step - loss: 1.1905 - categorical_accuracy: 0.6094 - val_loss: 0.9209 - val_categorical_accuracy: 0.7101
# Epoch 2/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.5466 - categorical_accuracy: 0.8212 - val_loss: 0.6637 - val_categorical_accuracy: 0.7987
# Epoch 3/20
# 10649/10649 [==============================] - 60s 6ms/step - loss: 0.3555 - categorical_accuracy: 0.8839 - val_loss: 0.5983 - val_categorical_accuracy: 0.8100
# Epoch 4/20
# 10649/10649 [==============================] - 62s 6ms/step - loss: 0.2368 - categorical_accuracy: 0.9219 - val_loss: 0.6360 - val_categorical_accuracy: 0.8126
# Epoch 5/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.1459 - categorical_accuracy: 0.9506 - val_loss: 0.7251 - val_categorical_accuracy: 0.8183
# Epoch 6/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0885 - categorical_accuracy: 0.9715 - val_loss: 0.8215 - val_categorical_accuracy: 0.8220
# Epoch 7/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1406 - categorical_accuracy: 0.9680 - val_loss: 0.7145 - val_categorical_accuracy: 0.8445
# Epoch 8/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0441 - categorical_accuracy: 0.9856 - val_loss: 0.8590 - val_categorical_accuracy: 0.8408
# Epoch 9/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0215 - categorical_accuracy: 0.9931 - val_loss: 0.9708 - val_categorical_accuracy: 0.8351
# Epoch 10/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0188 - categorical_accuracy: 0.9959 - val_loss: 1.0985 - val_categorical_accuracy: 0.8273
# Epoch 11/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0093 - categorical_accuracy: 0.9981 - val_loss: 1.2194 - val_categorical_accuracy: 0.8355
# Epoch 12/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0795 - categorical_accuracy: 0.9915 - val_loss: 1.3321 - val_categorical_accuracy: 0.8419
# Epoch 13/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0086 - categorical_accuracy: 0.9976 - val_loss: 1.2165 - val_categorical_accuracy: 0.8412
# Epoch 14/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1153 - categorical_accuracy: 0.9845 - val_loss: 1.3468 - val_categorical_accuracy: 0.8243
# Epoch 15/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0049 - categorical_accuracy: 0.9992 - val_loss: 1.3285 - val_categorical_accuracy: 0.8303
# Epoch 16/20
# 10649/10649 [==============================] - 59s 6ms/step - loss: 0.0042 - categorical_accuracy: 0.9992 - val_loss: 1.3243 - val_categorical_accuracy: 0.8333
# Epoch 17/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0044 - categorical_accuracy: 0.9992 - val_loss: 1.5598 - val_categorical_accuracy: 0.8284
# Epoch 18/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0048 - categorical_accuracy: 0.9992 - val_loss: 1.4936 - val_categorical_accuracy: 0.8374
# Epoch 19/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0122 - categorical_accuracy: 0.9981 - val_loss: 1.7397 - val_categorical_accuracy: 0.8306
# Epoch 20/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 0.0076 - categorical_accuracy: 0.9986 - val_loss: 1.6378 - val_categorical_accuracy: 0.8310

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(32, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_9 (GRU)                  (None, 256)               274176
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                330
# =================================================================
# Total params: 1,821,530
# Trainable params: 1,821,530
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 58s 5ms/step - loss: 1.2168 - categorical_accuracy: 0.5940 - val_loss: 0.8186 - val_categorical_accuracy: 0.7360
# Epoch 2/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.5556 - categorical_accuracy: 0.8205 - val_loss: 0.6552 - val_categorical_accuracy: 0.7890
# Epoch 3/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.3598 - categorical_accuracy: 0.8837 - val_loss: 0.5441 - val_categorical_accuracy: 0.8250
# Epoch 4/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.2407 - categorical_accuracy: 0.9199 - val_loss: 0.5348 - val_categorical_accuracy: 0.8430
# Epoch 5/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.1732 - categorical_accuracy: 0.9443 - val_loss: 0.6806 - val_categorical_accuracy: 0.8081
# Epoch 6/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.1028 - categorical_accuracy: 0.9659 - val_loss: 0.6836 - val_categorical_accuracy: 0.8239
# Epoch 7/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0580 - categorical_accuracy: 0.9820 - val_loss: 0.7689 - val_categorical_accuracy: 0.8340
# Epoch 8/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0310 - categorical_accuracy: 0.9900 - val_loss: 0.8051 - val_categorical_accuracy: 0.8438
# Epoch 9/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0182 - categorical_accuracy: 0.9952 - val_loss: 0.9575 - val_categorical_accuracy: 0.8370
# Epoch 10/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0749 - categorical_accuracy: 0.9884 - val_loss: 0.9502 - val_categorical_accuracy: 0.8573
# Epoch 11/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0100 - categorical_accuracy: 0.9975 - val_loss: 1.1225 - val_categorical_accuracy: 0.8329
# Epoch 12/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0862 - categorical_accuracy: 0.9851 - val_loss: 1.1835 - val_categorical_accuracy: 0.8374
# Epoch 13/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0081 - categorical_accuracy: 0.9978 - val_loss: 1.1862 - val_categorical_accuracy: 0.8393
# Epoch 14/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0086 - categorical_accuracy: 0.9984 - val_loss: 1.2136 - val_categorical_accuracy: 0.8442
# Epoch 15/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 0.0062 - categorical_accuracy: 0.9990 - val_loss: 1.3518 - val_categorical_accuracy: 0.8419
# Epoch 16/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0050 - categorical_accuracy: 0.9991 - val_loss: 1.3767 - val_categorical_accuracy: 0.8340
# Epoch 17/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0033 - categorical_accuracy: 0.9993 - val_loss: 1.3862 - val_categorical_accuracy: 0.8438
# Epoch 18/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0054 - categorical_accuracy: 0.9991 - val_loss: 1.4621 - val_categorical_accuracy: 0.8393
# Epoch 19/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0038 - categorical_accuracy: 0.9990 - val_loss: 1.5106 - val_categorical_accuracy: 0.8336
# Epoch 20/20
# 10649/10649 [==============================] - 56s 5ms/step - loss: 0.0042 - categorical_accuracy: 0.9993 - val_loss: 1.6271 - val_categorical_accuracy: 0.8280

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# W0815 02:04:12.279198 140582074754880 deprecation.py:506] From /home/leonardo/anaconda3/envs/gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_10 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 66s 6ms/step - loss: 1.2637 - categorical_accuracy: 0.5808 - val_loss: 0.9423 - val_categorical_accuracy: 0.6951
# Epoch 2/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.6337 - categorical_accuracy: 0.7922 - val_loss: 0.6923 - val_categorical_accuracy: 0.7743
# Epoch 3/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.4525 - categorical_accuracy: 0.8531 - val_loss: 0.5263 - val_categorical_accuracy: 0.8291
# Epoch 4/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.3431 - categorical_accuracy: 0.8859 - val_loss: 0.5117 - val_categorical_accuracy: 0.8378
# Epoch 5/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.2720 - categorical_accuracy: 0.9094 - val_loss: 0.5409 - val_categorical_accuracy: 0.8363
# Epoch 6/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.2246 - categorical_accuracy: 0.9268 - val_loss: 0.5676 - val_categorical_accuracy: 0.8306
# Epoch 7/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.1764 - categorical_accuracy: 0.9414 - val_loss: 0.5249 - val_categorical_accuracy: 0.8520
# Epoch 8/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.1401 - categorical_accuracy: 0.9528 - val_loss: 0.5191 - val_categorical_accuracy: 0.8603
# Epoch 9/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.1084 - categorical_accuracy: 0.9652 - val_loss: 0.5703 - val_categorical_accuracy: 0.8509
# Epoch 10/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0866 - categorical_accuracy: 0.9708 - val_loss: 0.5910 - val_categorical_accuracy: 0.8566
# Epoch 11/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0672 - categorical_accuracy: 0.9781 - val_loss: 0.6983 - val_categorical_accuracy: 0.8502
# Epoch 12/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0472 - categorical_accuracy: 0.9851 - val_loss: 0.7066 - val_categorical_accuracy: 0.8524
# Epoch 13/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0451 - categorical_accuracy: 0.9859 - val_loss: 0.6988 - val_categorical_accuracy: 0.8566
# Epoch 14/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0332 - categorical_accuracy: 0.9893 - val_loss: 0.7555 - val_categorical_accuracy: 0.8520
# Epoch 15/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0272 - categorical_accuracy: 0.9920 - val_loss: 0.7696 - val_categorical_accuracy: 0.8517
# Epoch 16/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0207 - categorical_accuracy: 0.9942 - val_loss: 0.8077 - val_categorical_accuracy: 0.8535
# Epoch 17/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0199 - categorical_accuracy: 0.9941 - val_loss: 0.8450 - val_categorical_accuracy: 0.8539
# Epoch 18/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0161 - categorical_accuracy: 0.9945 - val_loss: 0.8510 - val_categorical_accuracy: 0.8573
# Epoch 19/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0141 - categorical_accuracy: 0.9952 - val_loss: 0.9346 - val_categorical_accuracy: 0.8427
# Epoch 20/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0133 - categorical_accuracy: 0.9961 - val_loss: 0.9585 - val_categorical_accuracy: 0.8528

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.1, recurrent_dropout=0.5))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_17 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_11 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 65s 6ms/step - loss: 1.3159 - categorical_accuracy: 0.5654 - val_loss: 1.0998 - val_categorical_accuracy: 0.6466
# Epoch 2/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.6600 - categorical_accuracy: 0.7855 - val_loss: 0.7376 - val_categorical_accuracy: 0.7570
# Epoch 3/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.4605 - categorical_accuracy: 0.8504 - val_loss: 0.5833 - val_categorical_accuracy: 0.8228
# Epoch 4/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.3590 - categorical_accuracy: 0.8830 - val_loss: 0.4923 - val_categorical_accuracy: 0.8378
# Epoch 5/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.2827 - categorical_accuracy: 0.9060 - val_loss: 0.4604 - val_categorical_accuracy: 0.8487
# Epoch 6/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.2300 - categorical_accuracy: 0.9247 - val_loss: 0.5114 - val_categorical_accuracy: 0.8472
# Epoch 7/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1814 - categorical_accuracy: 0.9378 - val_loss: 0.5458 - val_categorical_accuracy: 0.8487
# Epoch 8/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1477 - categorical_accuracy: 0.9520 - val_loss: 0.5333 - val_categorical_accuracy: 0.8517
# Epoch 9/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1155 - categorical_accuracy: 0.9628 - val_loss: 0.5581 - val_categorical_accuracy: 0.8543
# Epoch 10/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0958 - categorical_accuracy: 0.9695 - val_loss: 0.6048 - val_categorical_accuracy: 0.8513
# Epoch 11/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0784 - categorical_accuracy: 0.9758 - val_loss: 0.5856 - val_categorical_accuracy: 0.8629
# Epoch 12/20
# 10649/10649 [==============================] - 64s 6ms/step - loss: 0.0568 - categorical_accuracy: 0.9822 - val_loss: 0.5995 - val_categorical_accuracy: 0.8622
# Epoch 13/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0506 - categorical_accuracy: 0.9844 - val_loss: 0.6636 - val_categorical_accuracy: 0.8611
# Epoch 14/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0407 - categorical_accuracy: 0.9866 - val_loss: 0.7042 - val_categorical_accuracy: 0.8622
# Epoch 15/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0319 - categorical_accuracy: 0.9905 - val_loss: 0.7423 - val_categorical_accuracy: 0.8584
# Epoch 16/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0254 - categorical_accuracy: 0.9917 - val_loss: 0.7461 - val_categorical_accuracy: 0.8596
# Epoch 17/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0225 - categorical_accuracy: 0.9928 - val_loss: 0.7763 - val_categorical_accuracy: 0.8569
# Epoch 18/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0195 - categorical_accuracy: 0.9949 - val_loss: 0.8264 - val_categorical_accuracy: 0.8573
# Epoch 19/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0156 - categorical_accuracy: 0.9957 - val_loss: 0.8091 - val_categorical_accuracy: 0.8551
# Epoch 20/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0114 - categorical_accuracy: 0.9962 - val_loss: 0.8669 - val_categorical_accuracy: 0.8596

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_18 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_12 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 1.1139 - categorical_accuracy: 0.6325 - val_loss: 0.8058 - val_categorical_accuracy: 0.7469
# Epoch 2/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.4618 - categorical_accuracy: 0.8563 - val_loss: 0.5444 - val_categorical_accuracy: 0.8299
# Epoch 3/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.2557 - categorical_accuracy: 0.9211 - val_loss: 0.5318 - val_categorical_accuracy: 0.8273
# Epoch 4/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.1333 - categorical_accuracy: 0.9588 - val_loss: 0.5705 - val_categorical_accuracy: 0.8389
# Epoch 5/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0671 - categorical_accuracy: 0.9810 - val_loss: 0.7540 - val_categorical_accuracy: 0.8284
# Epoch 6/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0332 - categorical_accuracy: 0.9915 - val_loss: 0.7823 - val_categorical_accuracy: 0.8250
# Epoch 7/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0151 - categorical_accuracy: 0.9961 - val_loss: 0.8385 - val_categorical_accuracy: 0.8370
# Epoch 8/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0083 - categorical_accuracy: 0.9981 - val_loss: 0.9383 - val_categorical_accuracy: 0.8291
# Epoch 9/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0215 - categorical_accuracy: 0.9949 - val_loss: 0.8256 - val_categorical_accuracy: 0.8344
# Epoch 10/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0106 - categorical_accuracy: 0.9972 - val_loss: 0.9431 - val_categorical_accuracy: 0.8209
# Epoch 11/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0163 - categorical_accuracy: 0.9958 - val_loss: 0.9275 - val_categorical_accuracy: 0.8276
# Epoch 12/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0042 - categorical_accuracy: 0.9988 - val_loss: 0.9968 - val_categorical_accuracy: 0.8370
# Epoch 13/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0084 - categorical_accuracy: 0.9979 - val_loss: 0.9577 - val_categorical_accuracy: 0.8194
# Epoch 14/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0052 - categorical_accuracy: 0.9987 - val_loss: 0.9615 - val_categorical_accuracy: 0.8348
# Epoch 15/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0034 - categorical_accuracy: 0.9992 - val_loss: 1.0671 - val_categorical_accuracy: 0.8303
# Epoch 16/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0109 - categorical_accuracy: 0.9973 - val_loss: 1.1823 - val_categorical_accuracy: 0.8111
# Epoch 17/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0063 - categorical_accuracy: 0.9987 - val_loss: 1.0276 - val_categorical_accuracy: 0.8329
# Epoch 18/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0043 - categorical_accuracy: 0.9987 - val_loss: 1.0566 - val_categorical_accuracy: 0.8243
# Epoch 19/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0094 - categorical_accuracy: 0.9973 - val_loss: 1.2140 - val_categorical_accuracy: 0.8160
# Epoch 20/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0116 - categorical_accuracy: 0.9968 - val_loss: 1.2495 - val_categorical_accuracy: 0.7923

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adadelta',  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_13 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 57s 5ms/step - loss: 1.2950 - categorical_accuracy: 0.5663 - val_loss: 1.1309 - val_categorical_accuracy: 0.6125
# Epoch 2/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.6661 - categorical_accuracy: 0.7845 - val_loss: 0.7309 - val_categorical_accuracy: 0.7548
# Epoch 3/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.4767 - categorical_accuracy: 0.8464 - val_loss: 0.6920 - val_categorical_accuracy: 0.7811
# Epoch 4/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.3738 - categorical_accuracy: 0.8768 - val_loss: 0.6483 - val_categorical_accuracy: 0.7833
# Epoch 5/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.2987 - categorical_accuracy: 0.9046 - val_loss: 0.6435 - val_categorical_accuracy: 0.7991
# Epoch 6/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.2310 - categorical_accuracy: 0.9249 - val_loss: 0.6493 - val_categorical_accuracy: 0.8085
# Epoch 7/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.1733 - categorical_accuracy: 0.9440 - val_loss: 0.6342 - val_categorical_accuracy: 0.8190
# Epoch 8/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.1217 - categorical_accuracy: 0.9612 - val_loss: 0.6634 - val_categorical_accuracy: 0.8276
# Epoch 9/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0767 - categorical_accuracy: 0.9778 - val_loss: 0.7631 - val_categorical_accuracy: 0.8333
# Epoch 10/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0478 - categorical_accuracy: 0.9860 - val_loss: 0.7752 - val_categorical_accuracy: 0.8295
# Epoch 11/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0319 - categorical_accuracy: 0.9915 - val_loss: 0.8833 - val_categorical_accuracy: 0.8291
# Epoch 12/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0163 - categorical_accuracy: 0.9967 - val_loss: 0.8957 - val_categorical_accuracy: 0.8419
# Epoch 13/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0112 - categorical_accuracy: 0.9977 - val_loss: 1.0373 - val_categorical_accuracy: 0.8284
# Epoch 14/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0070 - categorical_accuracy: 0.9987 - val_loss: 1.0563 - val_categorical_accuracy: 0.8295
# Epoch 15/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0056 - categorical_accuracy: 0.9988 - val_loss: 1.0837 - val_categorical_accuracy: 0.8344
# Epoch 16/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0043 - categorical_accuracy: 0.9992 - val_loss: 1.1298 - val_categorical_accuracy: 0.8288
# Epoch 17/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0062 - categorical_accuracy: 0.9987 - val_loss: 1.0866 - val_categorical_accuracy: 0.8393
# Epoch 18/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0024 - categorical_accuracy: 0.9992 - val_loss: 1.1587 - val_categorical_accuracy: 0.8378
# Epoch 19/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0023 - categorical_accuracy: 0.9995 - val_loss: 1.1618 - val_categorical_accuracy: 0.8336
# Epoch 20/20
# 10649/10649 [==============================] - 55s 5ms/step - loss: 0.0023 - categorical_accuracy: 0.9994 - val_loss: 1.2490 - val_categorical_accuracy: 0.8284

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, return_sequences=True))
model.add(GRU(32))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_20 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_14 (GRU)                 (None, 200, 256)          274176
# _________________________________________________________________
# gru_15 (GRU)                 (None, 32)                27744
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                330
# =================================================================
# Total params: 1,841,050
# Trainable params: 1,841,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 111s 10ms/step - loss: 1.1626 - categorical_accuracy: 0.6144 - val_loss: 0.9095 - val_categorical_accuracy: 0.7116
# Epoch 2/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.5427 - categorical_accuracy: 0.8290 - val_loss: 0.6414 - val_categorical_accuracy: 0.8040
# Epoch 3/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.3653 - categorical_accuracy: 0.8849 - val_loss: 0.5985 - val_categorical_accuracy: 0.8171
# Epoch 4/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.2527 - categorical_accuracy: 0.9199 - val_loss: 0.5993 - val_categorical_accuracy: 0.8224
# Epoch 5/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.1711 - categorical_accuracy: 0.9483 - val_loss: 0.6183 - val_categorical_accuracy: 0.8213
# Epoch 6/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.1058 - categorical_accuracy: 0.9676 - val_loss: 0.6016 - val_categorical_accuracy: 0.8408
# Epoch 7/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0657 - categorical_accuracy: 0.9816 - val_loss: 0.7090 - val_categorical_accuracy: 0.8397
# Epoch 8/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0369 - categorical_accuracy: 0.9901 - val_loss: 0.7505 - val_categorical_accuracy: 0.8427
# Epoch 9/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0228 - categorical_accuracy: 0.9930 - val_loss: 0.7353 - val_categorical_accuracy: 0.8490
# Epoch 10/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0153 - categorical_accuracy: 0.9957 - val_loss: 0.8538 - val_categorical_accuracy: 0.8479
# Epoch 11/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0091 - categorical_accuracy: 0.9973 - val_loss: 1.0688 - val_categorical_accuracy: 0.8145
# Epoch 12/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0087 - categorical_accuracy: 0.9974 - val_loss: 0.9728 - val_categorical_accuracy: 0.8494
# Epoch 13/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0074 - categorical_accuracy: 0.9981 - val_loss: 1.0398 - val_categorical_accuracy: 0.8359
# Epoch 14/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0864 - categorical_accuracy: 0.9882 - val_loss: 1.0909 - val_categorical_accuracy: 0.8374
# Epoch 15/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0060 - categorical_accuracy: 0.9988 - val_loss: 1.2292 - val_categorical_accuracy: 0.8374
# Epoch 16/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0047 - categorical_accuracy: 0.9990 - val_loss: 1.3052 - val_categorical_accuracy: 0.8318
# Epoch 17/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0064 - categorical_accuracy: 0.9989 - val_loss: 1.2914 - val_categorical_accuracy: 0.8445
# Epoch 18/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0035 - categorical_accuracy: 0.9992 - val_loss: 1.3602 - val_categorical_accuracy: 0.8427
# Epoch 19/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0030 - categorical_accuracy: 0.9992 - val_loss: 1.4087 - val_categorical_accuracy: 0.8419
# Epoch 20/20
# 10649/10649 [==============================] - 109s 10ms/step - loss: 0.0021 - categorical_accuracy: 0.9992 - val_loss: 1.4728 - val_categorical_accuracy: 0.8404

# %%
from keras.layers.core import Dropout

model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256, dropout=0.1, recurrent_dropout=0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=32, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_21 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_16 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,847,162
# Trainable params: 1,847,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 66s 6ms/step - loss: 1.4427 - categorical_accuracy: 0.5169 - val_loss: 1.0823 - val_categorical_accuracy: 0.6519
# Epoch 2/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.7985 - categorical_accuracy: 0.7446 - val_loss: 0.7054 - val_categorical_accuracy: 0.7766
# Epoch 3/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.5559 - categorical_accuracy: 0.8220 - val_loss: 0.6004 - val_categorical_accuracy: 0.8122
# Epoch 4/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.4262 - categorical_accuracy: 0.8623 - val_loss: 0.5619 - val_categorical_accuracy: 0.8254
# Epoch 5/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.3470 - categorical_accuracy: 0.8900 - val_loss: 0.5354 - val_categorical_accuracy: 0.8288
# Epoch 6/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.2685 - categorical_accuracy: 0.9134 - val_loss: 0.5382 - val_categorical_accuracy: 0.8393
# Epoch 7/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.2222 - categorical_accuracy: 0.9282 - val_loss: 0.5337 - val_categorical_accuracy: 0.8513
# Epoch 8/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1786 - categorical_accuracy: 0.9399 - val_loss: 0.5500 - val_categorical_accuracy: 0.8584
# Epoch 9/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1525 - categorical_accuracy: 0.9502 - val_loss: 0.6080 - val_categorical_accuracy: 0.8412
# Epoch 10/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1196 - categorical_accuracy: 0.9623 - val_loss: 0.6550 - val_categorical_accuracy: 0.8483
# Epoch 11/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.1018 - categorical_accuracy: 0.9657 - val_loss: 0.6838 - val_categorical_accuracy: 0.8543
# Epoch 12/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0860 - categorical_accuracy: 0.9706 - val_loss: 0.7659 - val_categorical_accuracy: 0.8397
# Epoch 13/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0763 - categorical_accuracy: 0.9749 - val_loss: 0.7572 - val_categorical_accuracy: 0.8494
# Epoch 14/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0672 - categorical_accuracy: 0.9786 - val_loss: 0.8444 - val_categorical_accuracy: 0.8490
# Epoch 15/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0532 - categorical_accuracy: 0.9819 - val_loss: 1.0018 - val_categorical_accuracy: 0.8336
# Epoch 16/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0461 - categorical_accuracy: 0.9847 - val_loss: 1.0718 - val_categorical_accuracy: 0.8344
# Epoch 17/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0434 - categorical_accuracy: 0.9872 - val_loss: 1.0460 - val_categorical_accuracy: 0.8348
# Epoch 18/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0307 - categorical_accuracy: 0.9907 - val_loss: 1.0749 - val_categorical_accuracy: 0.8505
# Epoch 19/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0306 - categorical_accuracy: 0.9913 - val_loss: 1.2291 - val_categorical_accuracy: 0.8472
# Epoch 20/20
# 10649/10649 [==============================] - 63s 6ms/step - loss: 0.0298 - categorical_accuracy: 0.9919 - val_loss: 1.2075 - val_categorical_accuracy: 0.8524

# %%
model = Sequential()
model.add(Embedding(vocabulario, dim_vetor, weights=[embedding_matrix], input_length=limite_texto, trainable=True))
model.add(GRU(256))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),  metrics=["categorical_accuracy"])
model.summary()

history = model.fit(x, y, epochs=20, batch_size=64, validation_split=0.2, verbose=1, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_22 (Embedding)     (None, 200, 100)          1538800
# _________________________________________________________________
# gru_17 (GRU)                 (None, 256)               274176
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,815,546
# Trainable params: 1,815,546
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10649 samples, validate on 2663 samples
# Epoch 1/20
# 10649/10649 [==============================] - 30s 3ms/step - loss: 1.2959 - categorical_accuracy: 0.5693 - val_loss: 0.9541 - val_categorical_accuracy: 0.6793
# Epoch 2/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.6356 - categorical_accuracy: 0.7932 - val_loss: 0.7265 - val_categorical_accuracy: 0.7627
# Epoch 3/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.4298 - categorical_accuracy: 0.8585 - val_loss: 0.7743 - val_categorical_accuracy: 0.7465
# Epoch 4/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.3037 - categorical_accuracy: 0.9004 - val_loss: 0.5558 - val_categorical_accuracy: 0.8216
# Epoch 5/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.2185 - categorical_accuracy: 0.9290 - val_loss: 0.6942 - val_categorical_accuracy: 0.8119
# Epoch 6/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.1507 - categorical_accuracy: 0.9497 - val_loss: 0.6380 - val_categorical_accuracy: 0.8333
# Epoch 7/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.1014 - categorical_accuracy: 0.9666 - val_loss: 0.6434 - val_categorical_accuracy: 0.8288
# Epoch 8/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0630 - categorical_accuracy: 0.9807 - val_loss: 0.6861 - val_categorical_accuracy: 0.8494
# Epoch 9/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0350 - categorical_accuracy: 0.9896 - val_loss: 0.7352 - val_categorical_accuracy: 0.8490
# Epoch 10/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0208 - categorical_accuracy: 0.9940 - val_loss: 0.9680 - val_categorical_accuracy: 0.8171
# Epoch 11/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0131 - categorical_accuracy: 0.9967 - val_loss: 0.9299 - val_categorical_accuracy: 0.8404
# Epoch 12/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.1140 - categorical_accuracy: 0.9864 - val_loss: 0.9186 - val_categorical_accuracy: 0.8442
# Epoch 13/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0879 - categorical_accuracy: 0.9844 - val_loss: 1.0256 - val_categorical_accuracy: 0.8355
# Epoch 14/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.1337 - categorical_accuracy: 0.9753 - val_loss: 1.0719 - val_categorical_accuracy: 0.8111
# Epoch 15/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0272 - categorical_accuracy: 0.9920 - val_loss: 1.0423 - val_categorical_accuracy: 0.8231
# Epoch 16/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0086 - categorical_accuracy: 0.9975 - val_loss: 0.9638 - val_categorical_accuracy: 0.8427
# Epoch 17/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0070 - categorical_accuracy: 0.9978 - val_loss: 0.9567 - val_categorical_accuracy: 0.8363
# Epoch 18/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0049 - categorical_accuracy: 0.9986 - val_loss: 1.1338 - val_categorical_accuracy: 0.8333
# Epoch 19/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0135 - categorical_accuracy: 0.9958 - val_loss: 1.1215 - val_categorical_accuracy: 0.8378
# Epoch 20/20
# 10649/10649 [==============================] - 28s 3ms/step - loss: 0.0056 - categorical_accuracy: 0.9983 - val_loss: 1.0857 - val_categorical_accuracy: 0.8457
